# %% [markdown]
# # FIT5196 Task 1 in Assessment 2
# #### Student Name: Chuangfu Xie
# #### Student ID: 27771539
#
# Date: 28/04/2018
#
# Version: 1.0
#
# Environment: Pandas 0.22.0, Python 3.6.4 and Jupyter notebook

# %%
import sys
print (sys.version_info)
# Out:
# sys.version_info(major=3, minor=6, micro=4, releaselevel='final', serial=0)

# %% [markdown]
# ## 1.  Import libraries

# %%
import pandas as pd
import numpy as np
import re
print("Your Pandas version: " + pd.__version__)
# Out:
# Your Pandas version: 0.22.0

# %% [markdown]
# ## 2. Auditing

# %% [markdown]
# First, read CSV file from current directory by `read_csv()`:

# %%
df = pd.read_csv("./dataset1_with_error.csv")
# Take a peek at data 
df.head()
# Out:
#          Id                                              Title   Location  \
# 0  12612628                        Engineering Systems Analyst    Dorking
# 1  12612830                            Stress Engineer Glasgow    Glasgow
# 2  12612844                   Modelling and simulation analyst  Hampshire
# 3  12613049  Engineering Systems Analyst / Mathematical Mod...     Surrey
# 4  12613647         Pioneer, Miser Engineering Systems Analyst     Surrey
#
#     ContractType ContractTime                       Company          Category  \
# 0  not available    permanent  Gregory Martin International  Engineering Jobs
# 1  not available    permanent  Gregory Martin International  Engineering Jobs
# 2  not available    permanent  Gregory Martin International  Engineering Jobs
# 3  not available    permanent  Gregory Martin International  Engineering Jobs
# 4  not available    permanent  Gregory Martin International  Engineering Jobs
#
#   Salary per annum        SourceName         OpenDate        CloseDate
# 0            24996  cv-library.co.uk  20121103T000000  20121203T000000
# 1            30000  cv-library.co.uk  20130108T150000  20130408T150000
# 2            30000  cv-library.co.uk  20130726T150000  20130924T150000
# 3            27504  cv-library.co.uk  20121214T000000  20130314T000000
# 4            24996  cv-library.co.uk  20131025T000000  20131224T000000

# %% [markdown]
# Since <font color='blue'>**Id**</font> are identifiers of these data, let's check whether it contains duplicated records:

# %%
sum(df['Id'].duplicated())
# Out:
# 0

# %% [markdown]
# No duplicated record is great. Then, let's have a overview of this dataframe:

# %%
# Check overall info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25077 entries, 0 to 25076
# Data columns (total 11 columns):
# Id                  25077 non-null int64
# Title               25077 non-null object
# Location            25077 non-null object
# ContractType        25077 non-null object
# ContractTime        25077 non-null object
# Company             21242 non-null object
# Category            25077 non-null object
# Salary per annum    25077 non-null object
# SourceName          25077 non-null object
# OpenDate            25077 non-null object
# CloseDate           25077 non-null object
# dtypes: int64(1), object(10)
# memory usage: 2.1+ MB

# %% [markdown]
# ### 2.1 Check on Date data: `OpenDate` and `CloseDate`

# %% [markdown]
# In this section, we intend to find out **whether any data contains anomalies** in <font color='blue'>**OpenDate**</font> and <font color='blue'>**CloseDate**</font>. It can be syntactical anomalies, semantic anomalies, or coverage anomalies. From output above, we can find that value stored in these two colums are both in `object` type. However, if we want to check whether the date are valid, we need to convert these data from `object` type to `datetime` type.
# First. let's start from its **format**:

# %%
def check_date(data, col):
    '''
    With common sense, this function applies constraints on each data, 
    then return a list of indices of all errors.
    > Arguments:
    data: DataFrame. Pandas.DataFrame object
    col: str. Target column, 'OpenDate', 'CloseDate'
    > Return:
    error_list: a list of indices of all errors
    '''
    #initialise a set for storing indices(avoid duplicate)
    errors = []
    # Check every record
    for i,each in enumerate(data[col]):
        try:
            pd.to_datetime(each)
        except ValueError:
            errors.append(i)
    return errors

error_list = check_date(df, 'OpenDate')
# Have a look at those error
df.iloc[error_list]['OpenDate']
# Out:
# 1102     20131803T120000
# 2104     20132606T000000
# 2839     20122003T150000
# 5707     20121512T150000
# 10881    20133004T150000
# 11948    20131908T000000
# 15353    20121406T120000
# 22918    20131509T000000
# 23007    20132901T150000
# 23169    20132108T120000
# Name: OpenDate, dtype: object

# %% [markdown]
# As shown above, these **10 records** fail to convert into `datetime` type, which means these data format are <font color='red'>**inconsistent**</font> with normal date value format. We should invert the position of day and month.
# With `check_date` function, now we have anomalies index. Let's create another function as `rectify_date` to rectify these errors:

# %%
def rectify_date(data, col):
    '''
    This function is to rectify date format error in place.
    > Arguments:
    data: DataFrame. Pandas.DataFrame object
    col: str. Target column, 'OpenDate', 'CloseDate'
    '''
    re_pattern = r'^(?P<year>\d{4})(?P<month>\d{2})(?P<day>\d{2})(?P<time>T\d{6})'
    error_list = check_date(data, col)
    for i in error_list:
        datedict = re.match(re_pattern, data[col][i]).groupdict()
        # construct replaced date
        rep_d = datedict['year']+datedict['day']+datedict['month']+datedict['time']
        # rectify format in place.
        data.at[i,col] = rep_d

# Rectify data in 'OpenDate' and 'CloseDate'
rectify_date(df, 'OpenDate')
# Double-check on those errors
df.iloc[error_list]['OpenDate']
# Out:
# 1102     20130318T120000
# 2104     20130626T000000
# 2839     20120320T150000
# 5707     20121215T150000
# 10881    20130430T150000
# 11948    20130819T000000
# 15353    20120614T120000
# 22918    20130915T000000
# 23007    20130129T150000
# 23169    20130821T120000
# Name: OpenDate, dtype: object

# %%
# Apply same process on 'CloseDate'
rectify_date(df,'CloseDate')

# %% [markdown]
# Having all date in correct format, now we can check whether data spread in <font color='blue'>**OpenDate**</font> and <font color='blue'>**CloseDate**</font> have **violate the integrity constraint**: the date value on <font color='blue'>**OpenDate**</font> should be **preceding to** that on <font color='blue'>**CloseDate**</font>.
# To find out if there any, we first need to convert <font color='blue'>**OpenDate**</font> and <font color='blue'>**CloseDate**</font> into `datatime` type.

# %%
df['OpenDate'] = pd.to_datetime(df['OpenDate'])
df['CloseDate'] = pd.to_datetime(df['CloseDate'])
# Any violation?
df[df['OpenDate']>df['CloseDate']].loc[:,['OpenDate','CloseDate']]
# Out:
#                  OpenDate           CloseDate
# 6659  2013-07-03 00:00:00 2013-04-04 00:00:00
# 9568  2012-03-06 00:00:00 2012-02-05 00:00:00
# 11043 2013-11-05 00:00:00 2013-10-06 00:00:00
# 12473 2013-12-22 15:00:00 2013-10-23 15:00:00
# 19142 2012-08-03 15:00:00 2012-05-05 15:00:00
# 24206 2013-06-22 15:00:00 2013-03-24 15:00:00
# 24297 2013-01-16 00:00:00 2012-10-18 00:00:00
# 25039 2013-07-08 12:00:00 2013-06-08 12:00:00

# %% [markdown]
# We have found **8 violations**. It seems like data in <font color='blue'>**OpenDate**</font> have been carelessly put into <font color='blue'>**CloseDate**</font> column. Let's change it back:

# %%
open_d = df[df['OpenDate']>df['CloseDate']]['OpenDate']
close_d = df[df['OpenDate']>df['CloseDate']]['CloseDate']
error_list = df[df['OpenDate']>df['CloseDate']].index.tolist()
for i,o,c in zip(error_list, open_d, close_d):
    df.at[i,"OpenDate"]=c
    df.at[i,"CloseDate"]=o
# Double-check
sum(df['OpenDate']>df['CloseDate'])
# Out:
# 0

# %% [markdown]
# ### 2.2 Checking on numeric data: `Salary per annum`

# %% [markdown]
# The aforementioned process have shown how to rectify anomalies occour in date value, now we turn to numeric data: <font color='blue'>**Salary per annum**</font>.
# Before we closely examine these data, we know data in column <font color='blue'>**Salary per annum**</font> are stored in `object` type. let's define a function to check whether data are in numberic format by conversion function `int()`:

# %%
def check_numeric(data, col):
    errors=[]
    for i,d in enumerate(data[col]):
        try:
            int(d)
        except ValueError:
            errors.append(i)
    return errors

alist = check_numeric(df, 'Salary per annum')
df.iloc[alist]
# Out:
#              Id                                              Title  \
# 133    46626860            Registered Home Manager Job Bournemouth
# 238    46627928           Care Home Manager Job North London ****K
# 305    46628805                     Home Care Workers Berkhampsted
# 596    46634306                  Home Manager Mental Health 11 bed
# 647    46634923        RGN Nurse Hull Days or Nights **** per hour
# 830    46637596                     Staff Nurse South Shields ****
# 896    48082563  Senior Chef de Partie  One AA Rosette Hotel  T...
# 952    49065458              Service Manager Learning Disabilities
# 980    49689021                                 Assessment Officer
# 996    49845058  Chef de Partie  Fresh Food Pub  Good Reputatio...
# 1062   51061201              Community Home Workers Melton Mowbray
# 1081   51285942                     Senior Social Worker Fostering
# 1141   52489008                                      RGN Care Home
# 1292   55400384                    Live in Care Worker Jobs Exeter
# 1379   55408955                      Senior Applications Developer
# 1410   55409587                          MVNO Enterprise Architect
# 1525   56209766                                 Nurse Advisor COPD
# 1621   56814478                   Chef de Partie  **** AA Rosettes
# 1797   58533485          Senior Embedded Controls Systems Engineer
# 1822   58759123  Helpdesk / Desktop Support analystExcel, Word,...
# 2051   60684270              Door to door / Field Sales Canvassers
# 2063   60685515          Staff Nurse Elderly Care Stockton on Tees
# 2118   61445890                              Mental Health Advisor
# 2602   64145428                             DEPUTY MANAGER READING
# 2724   64573377                 Deputy Care Manager / Care Manager
# 2889   64809245  Contract Mechanical Draughtsperson (Huddersfield)
# 2923   64813318  Manufacturing Engineer (Mechanical / Pumps / CNC)
# 3057   65171402                                 Complaints Manager
# 3186   65188754       Technical Sales Engineer (ElectroMechanical)
# 3274   65317743  Assistant General Manager  New Opening  Aberde...
# ...         ...                                                ...
# 21666  69012121                    Adult Speech Language Therapist
# 21734  69017589  BI Manager, SQL Server Financial ServicesHertf...
# 21744  69018023  PHP WEB DEVELOPER / PHP PROGRAMMER / SOFTWARE ...
# 23815                    UK      full_time      permanent
# 23984       Tunbridge Wells  not available      permanent
# 24008  Edinburgh Technopole  not available       contract
# 24027     South East London  not available      permanent
# 24113             Tonbridge  not available      permanent
# 24170     South East London  not available       contract
# 24319           Oxfordshire  not available  not available
# 24352                London  not available  not available
# 24364                London  not available  not available
# 24427                London  not available  not available
# 24462                London  not available  not available
# 24736         Wolverhampton      full_time      permanent
# 24917                    UK      full_time      permanent
#
#                                       Company  \
# 133                                       NaN
# 238                                       NaN
# 305                                       NaN
# 596                                       NaN
# 647                                       NaN
# 830                                       NaN
# 896                              Chef Results
# 952                                       NaN
# 980                                       NaN
# 996                              Chef Results
# 1062                                      NaN
# 1081                                      NaN
# 1141                                      NaN
# 1292                                      NaN
# 1379                                    JOBG8
# 1410                                    JOBG8
# 1525                                      NaN
# 1621                    Gold Leaf Recruitment
# 1797           Executive Recruitment Services
# 1822          Information Technology Services
# 2051                  Zenith Renewable Energy
# 2063                                      NaN
# 2118                                      NaN
# 2602                   CHERRY RED RECRUITMENT
# 2724                                      NaN
# 2889   Perpetual Engineering Partnerships Ltd
# 2923           Rise Technical Recruitment Ltd
# 3057                                      NaN
# 3186           Rise Technical Recruitment Ltd
# 3274                     The Recruitment Room
# ...                                       ...
# 21666                               MedicsPro
# 21734             Parallel Consulting Limited
# 21744                             hiredonline
# 21951        Kendall Poole Consulting Limited
# 22029                     Pursuit Recruitment
# 22283                              Ashdown IT
# 22418                 Hays Finance Technology
# 22420                            ANSON MCCADE
# 22465                             Newton Blue
# 22493              ENTERPRISE RECRUITMENT LTD
# 23111              Rise Technical Recruitment
# 23152             Connections Recruitment Ltd
# 23207                     RGB Recruitment Ltd
# 23365                             Barker Ross
# 23478                              VanRath IT
# 23557                             London4Jobs
# 23619                      Venn Group Limited
# 23815                               CVbrowser
# 23984                 Sirius Executive Search
# 24008              Carlisle Managed Solutions
# 24027        The Graduate Recruitment Company
# 24113                Ashdown Appointments Ltd
# 24170                      Tempest Resourcing
# 24319                  Appetite 4 Recruitment
# 24352   Berkeley Scott Pubs, Bars Restaurants
# 24364                       Aston Recruitment
# 24427                   Cherryred Recruitment
# 24462                   Loch Fyne Restaurants
# 24736        Forces Recruitment Services  Ltd
# 24917                       Hays   North West
#
#                                Category  \
# 133           Healthcare & Nursing Jobs
# 238           Healthcare & Nursing Jobs
# 305           Healthcare & Nursing Jobs
# 596           Healthcare & Nursing Jobs
# 647           Healthcare & Nursing Jobs
# 830           Healthcare & Nursing Jobs
# 896         Hospitality & Catering Jobs
# 952           Healthcare & Nursing Jobs
# 980           Healthcare & Nursing Jobs
# 996         Hospitality & Catering Jobs
# 1062          Healthcare & Nursing Jobs
# 1081          Healthcare & Nursing Jobs
# 1141          Healthcare & Nursing Jobs
# 1292          Healthcare & Nursing Jobs
# 1379                            IT Jobs
# 1410                            IT Jobs
# 1525          Healthcare & Nursing Jobs
# 1621        Hospitality & Catering Jobs
# 1797                            IT Jobs
# 22029                cv-library.co.uk 2013-12-13 00:00:00 2014-02-11 00:00:00
# 22283                    cwjobs.co.uk 2012-11-22 12:00:00 2012-12-22 12:00:00
# 22418                    cwjobs.co.uk 2012-10-18 15:00:00 2012-11-17 15:00:00
# 22420                    cwjobs.co.uk 2012-06-28 15:00:00 2012-09-26 15:00:00
# 22465                    cwjobs.co.uk 2012-05-10 12:00:00 2012-06-09 12:00:00
# 22493                    cwjobs.co.uk 2012-12-09 15:00:00 2013-01-08 15:00:00
# 23111                cv-library.co.uk 2012-02-25 00:00:00 2012-05-25 00:00:00
# 23152                cv-library.co.uk 2013-04-28 12:00:00 2013-07-27 12:00:00
# 23207                cv-library.co.uk 2012-05-07 12:00:00 2012-06-06 12:00:00
# 23365                cv-library.co.uk 2013-06-27 12:00:00 2013-07-27 12:00:00
# 23478                      nijobs.com 2013-10-24 15:00:00 2013-12-23 15:00:00
# 23557               london4jobs.co.uk 2012-09-11 15:00:00 2012-12-10 15:00:00
# 23619                    cityjobs.com 2012-08-18 12:00:00 2012-09-17 12:00:00
# 23815                   cvbrowser.com 2012-02-16 00:00:00 2012-04-16 00:00:00
# 23984                   totaljobs.com 2013-07-06 00:00:00 2013-08-05 00:00:00
# 24008                   totaljobs.com 2012-07-20 00:00:00 2012-09-18 00:00:00
# 24027                   totaljobs.com 2013-01-08 15:00:00 2013-02-07 15:00:00
# 24113                   totaljobs.com 2012-01-06 00:00:00 2012-03-06 00:00:00
# 24170                   totaljobs.com 2013-09-11 12:00:00 2013-10-11 12:00:00
# 24319  jobs.catererandhotelkeeper.com 2013-01-09 15:00:00 2013-01-23 15:00:00
# 24352  jobs.catererandhotelkeeper.com 2013-06-18 00:00:00 2013-07-18 00:00:00
# 24364  jobs.catererandhotelkeeper.com 2012-06-06 00:00:00 2012-06-20 00:00:00
# 24427  jobs.catererandhotelkeeper.com 2012-06-19 12:00:00 2012-07-19 12:00:00
# 24462  jobs.catererandhotelkeeper.com 2012-03-15 00:00:00 2012-04-14 00:00:00
# 24736                     fish4.co.uk 2012-11-10 12:00:00 2013-01-09 12:00:00
# 24917                     fish4.co.uk 2013-05-27 00:00:00 2013-06-26 00:00:00
#
# [200 rows x 11 columns]

# %% [markdown]
# Now, we can easily find there are 3 different format in column <font color='blue'>**Salary per annum**</font>:
#
# ```Python
# '24996'	                <-- numeric
# '22K'                      <-- 'K' abbrevated for 1000
# '24646.8 - 27241.2'        <-- givn a range
# ```
# These irregularities need to be uniformed. Especially, as to those range data, we use the mean of that range as the substitution data.
# Here, we assume that after cleansing we only need interger value in salary. All data after processing by function `extract_salary()` would be converted to integer.

# %%
def extract_salary(data, col):
    range_pattern = r'(\d+.\d+) - (\d+.\d+)'
    k_pattern = r'(\d+)K'
    errors = check_numeric(data,col)
    for i,s in zip(errors, data.iloc[errors][col]):
        if 'K' in s:
            rep_n = 1000*int(re.match(k_pattern, s).group(1))
            data.at[i,col] = rep_n
        else:
            rep_n = 0.5*(float(re.match(range_pattern, s).group(1)) + float(re.match(range_pattern, s).group(2)))
            data.at[i,col] = int(round(rep_n))

# %%
extract_salary(df, 'Salary per annum')
# Convert 'Salary per annum' to numeric type
df['Salary per annum'] = pd.to_numeric(df['Salary per annum'])

# %% [markdown]
# ### 2.3 Checking on others columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25077 entries, 0 to 25076
# Data columns (total 11 columns):
# Id                  25077 non-null int64
# Title               25077 non-null object
# Location            25077 non-null object
# ContractType        25077 non-null object
# ContractTime        25077 non-null object
# Company             21242 non-null object
# Category            25077 non-null object
# Salary per annum    25077 non-null int64
# SourceName          25077 non-null object
# OpenDate            25077 non-null datetime64[ns]
# CloseDate           25077 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 2.1+ MB

# %% [markdown]
# Previously we have done our anormalies detection in column <font color='blue'>**OpenDate**</font>, <font color='blue'>**CloseDate**</font> and <font color='blue'>**Salary per annum**</font>. Now let's have a look at other columns:

# %%
df.ContractType.value_counts()
# Out:
# not available    19499
# full_time         4883
# part_time          695
# Name: ContractType, dtype: int64

# %% [markdown]
# Column <font color='blue'>**ContractType**</font> only have 3 possible value: `not available`, `full_time`, `part_time`.
# However, the underscore "\_" seem to be some typing error, we need to replace it with dash "-":

# %%
def rectify_contractType(data):
    for i,t in enumerate(data['ContractType']):
        if '_' in t:
            rep = t.replace('_','-')
            data.at[i,'ContractType'] = rep
rectify_contractType(df)
df.ContractType.value_counts()
# Out:
# not available    19499
# full-time         4883
# part-time          695
# Name: ContractType, dtype: int64

# %% [markdown]
# Better.
# Then, let's look at column <font color='blue'>**ContractTime**</font>:

# %%
df.ContractTime.value_counts()
# Out:
# permanent        16194
# not available     6212
# contract          2671
# Name: ContractTime, dtype: int64

# %% [markdown]
# Nothing special. How about data in column <font color='blue'>**Category**</font>:

# %%
df.Category.value_counts()
# Out:
# IT Jobs                             7085
# Healthcare & Nursing Jobs           4334
# Engineering Jobs                    3458
# Accounting & Finance Jobs           3099
# Sales Jobs                          2609
# Hospitality & Catering Jobs         2124
# Teaching Jobs                       1378
# PR, Advertising & Marketing Jobs     990
# Name: Category, dtype: int64

# %% [markdown]
# How about column <font color='blue'>**Title**</font>, <font color='blue'>**Location**</font>, <font color='blue'>**Company**</font> and <font color='blue'>**SourceName**</font>?
# Data in these corresponding column are naturally diverse with seldom similarity, we just keep what they are.

# %% [markdown]
# ## 3. Export output

# %% [markdown]
# Export the dataframe to `CSV` without indexing:

# %%
df.to_csv('./dataset1_solution.csv', index=False)

# %% [markdown]
# ## 4. Summary

# %% [markdown]
# Following the instructions, I have find data problems included:
# 1. Lexical errors: 'full_time' instead of 'full-time' in  <font color='blue'>**ContractType**</font>.
# 2. Irregularities: '24996','22K','24646.8 - 27241.2' in <font color='blue'>**Salary per annum**</font>.
# 3. Violation of the Integrity constraint: <font color='blue'>**CloseDate**</font> preceding to <font color='blue'>**OpenDate**</font>.
# 4. Inconsistency: '20180428T150000' against '20182804T150000' in <font color='blue'>**OpenDate**</font>
