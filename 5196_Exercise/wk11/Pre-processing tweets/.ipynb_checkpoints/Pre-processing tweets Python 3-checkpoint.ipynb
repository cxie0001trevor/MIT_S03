# %% [markdown]
# # Pre-processing tweets
#
# Twitter is a popular micro blogging service where Twitter users communicate with short, 140-character status messages (called "tweets"), with which users can share links, pictures, and thoughts or opinions about different topics, journalists comment on live events, companies promote products and engage with customers and so on.
#
# With about a half a billion tweets per day, there’s a lot of data to analyse and to play with.
# Twitter data has been used in various analysis tasks, such as **sentiment analysis**, **social network analysis**, etc.
# Topics that you will learn about in this chapter include:
# * Collecting tweets via **API** requests, and storing them in **JSON** files
# * Extracting **emoticons**
# * Tokenizing **tweets**
# * Generating **word feature vectors**

# %% [markdown]
# ## 1. Collecting Tweets with Python
# Many web services provide APIs to developers to interact with their services and to access data in a programmatic way.
# Twitter is one of them.
# It has taken great care to maintain a well-documented and elegantly simple API that is intuitive and easy to use.
#
# There are **two types** of APIs, i.e., [the Streaming API](https://dev.twitter.com/streaming/overview) and [the REST API](https://dev.twitter.com/rest/public/search), available for Twitter developers.
#
# According to the documentation on the Twitter developers' website,
# the former only sends out real-time tweets.
# It gives developers low latency access to Twitter’s global stream of Tweet data.
#
# The later searches against a sample of recent Tweets published in the past 7 days.
# It is more suitable for singular searches, such as searching historic tweets, reading user profile information, or posting Tweets.
# While the Streaming API is focused on matching for **completeness**, the REST API, like the Twitter search API, is focused on **relevance**.
# In this section, you will learn the basic usage of the Twitter search API.

# %% [markdown]
# There are [many great libraries available]((https://dev.twitter.com/overview/api/twitter-libraries) in different programming languages to further ease the work involved in making API requests.
# Using those libraries, you can easily make API requests without having to know too much
# about the Twitter API details.
# Here we will use [TwitterSearch](https://github.com/ckoepp/TwitterSearch),
# a Python library to easily iterate tweets found by the [Twitter search API](https://dev.twitter.com/rest/public/search),
# to demonstrate how to make Twitter API requests and download data of our interest,
# we chose the TwitterSearch library, because it is **simple to use**, yet supports the Twitter search API well.
# If you don't have TwitterSearch installed in your machine, go to its Github website and follow
# the installation instructions.

# %% [markdown]
# To start with, you need to have a Twitter account and obtain credentials (i.e., consumer key, consumer secret, access token and access token secret) on the Twitter developer site to access the Twitter API.
# Follow the steps below to get all the 4 credentials:
# * Create a Twitter user account if you do not already have one.
# * Go to https://apps.twitter.com/ and log in with your Twitter user account. This step gives you a Twitter developer account under the same name as your user account.
# * Click “Create New App”, and then fill out the form (i.e., App name, App description, and so on), agree to the terms, and click “Create your Twitter application”.
# Creating an application is the standard way for a developer to gain API access.
# The process of creating an application is simple, and all that's needed is read-only access to the API.
# * In the next page, click on “Keys and Access Tokens” tab on the top,
#     and copy your “consumer key” and “consumer secret”.
# * Scroll down if necessary and click “Create my access token”, and copy your “Access token” and “Access token secret”.
#
# Below is example code to search Twitter for tweets that have keyword 'metrotrains',
# and save all the retrieved tweets in list.
# In order to run the code, you should substituting your own account credentials that you just got above in order to create the TwitterSearch object.
# <font color="red">Note: if you don't have a Twitter API access and you don't want to apply for one, you can escape the following scripts and go to section 2.</font>

# %%
from TwitterSearch import *

# %%
tweets = []

try:
    # create a TwitterSearchOrder object
    tso = TwitterSearchOrder() 
    # let's define all words we would like to have a look for
    tso.set_keywords(['metrotrains']) 
    # or is English the default
    tso.set_language('en') 
    # and give us all those entity information
    tso.set_include_entities(False) 

    # create a TwitterSearch object with your own credentials
    ts = TwitterSearch(
        consumer_key = 'W6CzuJsRdPCrBSqYxqemSuOUd',
        consumer_secret = 'RG99f2M24zMJrCgZxAUf4D3xZmsRmC32fx1YqPVEKlgnV2QJEl',
        access_token = '756165158091657216-g9GirSewDxiPKPSAIVnGLjVmaMwWiac',
        access_token_secret = 'zSSikztIaLDyKj61sxrhP0X3pgBNrwL8A6JIiPUMveH7z'
     )

    for tweet in ts.search_tweets_iterable(tso):
        tweets.append(tweet) 
        
# take care of all those ugly errors if there are some        
except TwitterSearchException as e: 
    print(e)

# %% [markdown]
# If you run the program above, you will retrieve about 2,300 tweets that contain 'metrotrains'.
# Note that the number of tweets retrieved might vary from time to time,
# as the whole Twitter database is dynamic due to thousands of tweets being posted every second.
# Each tweet is stored in a huge Python dictionary.
# An example of what such a tweet looks like is the following dictionary, which
# corresponds to the first tweet returned by the code above.

# %%
len(tweets)
# Out:
# 2548

# %%
for k,v in tweets[0].items():
    if v!=None:
        print(k,':',v,'\n')
# try the following print out, what do you find?
# print tweets[0]
# Out:
# created_at : Sat Jun 02 00:47:11 +0000 2018
#
# id : 1002713203929804800
#
# id_str : 1002713203929804800
#
# text : RT @metrotrains: Frankston line: Buses replace trains FlindersSt - Moorabbin until 4:00pm Sat 2 June due to @levelcrossings works at Caulfi…
#
# truncated : False
#
# metadata : {'iso_language_code': 'en', 'result_type': 'recent'}
#
# source : <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
#
# user : {'id': 924085684712833024, 'id_str': '924085684712833024', 'name': 'Dank Trains Of Melbourne', 'screen_name': 'Thetramspotter', 'location': 'Melbourne, Victoria', 'description': '15 y.o. bisexual boy🏳️\u200d🌈, likes Trains and trams and makes cancerous memes', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 93, 'friends_count': 599, 'listed_count': 0, 'created_at': 'Sat Oct 28 01:29:30 +0000 2017', 'favourites_count': 6440, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1517, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/993746064711692288/izMH4XcS_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/993746064711692288/izMH4XcS_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/924085684712833024/1525762547', 'profile_link_color': '0079A5', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}
#
# retweeted_status : {'created_at': 'Sat Jun 02 00:38:24 +0000 2018', 'id': 1002710991866482688, 'id_str': '1002710991866482688', 'text': 'Frankston line: Buses replace trains FlindersSt - Moorabbin until 4:00pm Sat 2 June due to @levelcrossings works at… https://t.co/kMRFC5zTmm', 'truncated': True, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 40561535, 'id_str': '40561535', 'name': 'Metro Trains', 'screen_name': 'metrotrains', 'location': 'Melbourne, Australia', 'description': "We're here 5am-11pm Mon-Fri & 24 hours Sat-Sun.\nIn an emergency, contact Triple Zero (000) or our staff via the intercom. Social policy: https://t.co/ettZSIXwkg", 'url': 'http://t.co/9ct4ZD5UuB', 'entities': {'url': {'urls': [{'url': 'http://t.co/9ct4ZD5UuB', 'expanded_url': 'http://metrotrains.com.au', 'display_url': 'metrotrains.com.au', 'indices': [0, 22]}]}, 'description': {'urls': [{'url': 'https://t.co/ettZSIXwkg', 'expanded_url': 'http://bit.ly/19VZu9V', 'display_url': 'bit.ly/19VZu9V', 'indices': [137, 160]}]}}, 'protected': False, 'followers_count': 263468, 'friends_count': 511, 'listed_count': 868, 'created_at': 'Sat May 16 23:07:55 +0000 2009', 'favourites_count': 4568, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 77630, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'CEE0EB', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/879921545375653888/dNet64mq_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/879921545375653888/dNet64mq_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40561535/1527566514', 'profile_link_color': '0072CF', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '9295A8', 'profile_text_color': '3C3940', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 3, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}
#
# is_quote_status : False
#
# retweet_count : 1
#
# favorite_count : 0
#
# favorited : False
#
# retweeted : False
#
# lang : en

# %% [markdown]
# From the above example, you can see that the Twitter search API returns not only the content of tweets but also rich meta information, e.g., user information, when the tweet posted, the number of retweets and so on.
# All the data is stored in **JSON format**.
#
# It is clear that each tweet object contains far more data than the 140 characters of text that is normally thought of as a tweet!
# Click [here](http://www.slaw.ca/wp-content/uploads/2011/11/map-of-a-tweet-copy.pdf) to view the map made by Raffi Krikorian, which explains a tweet in JSON format.
# This map is a good visualization of tweet’s JSON format even though it is a bit out-of-date.
# You can find the up-to-date information of tweet’s format [here](https://dev.twitter.com/overview/api/tweets).
# We will discuss the tweet structure in a bit more detail later.
# The following code uses Python library **json** or **simplejson** to dump all the tweets into a JSON file.

# %%
# Import the necessary package to process data in JSON format
try:
    import json
except ImportError:
    import simplejson as json

# %%
# dump all the tweets into a JSON file
jsonFile = open('tweetSamples_1.json', 'w')
for tweet in tweets:
    # Twitter Python Tool wraps the data returned by Twitter as a Dictionary object.
    # We first convert it back to the JSON format, and then save all tweets in a JSON file
    jsonFile.write(json.dumps(tweet)+"\n")
jsonFile.close()

# %% [markdown]
# Note that Twitter imposes rate limits on how many requests an application can make to any given API resource within a given time window.
# Twitter's rate limits are well documented (see [here](https://dev.twitter.com/rest/public/rate-limits)).
# For the purpose of following along in this chapter, it is unlikely that you will hit the rate limits.
# We have introduced the use of the Twitter search API. As we mentioned early in this section, there are other APIs that you can use, the Twitter stream API for example.
# If you would like to learn more on Twitter APIs, you can go to
# [Twitter's website for developers](https://dev.twitter.com/overview/documentation),
# or read some online tutorials such as [3].
# - - -

# %% [markdown]
# ## 2. Reading and Processing Tweets in JSON formats
# Here we demonstrate how to read and process tweets in a bit more detail.
# We will use `json` library to parse the dumped tweets (please refer to chapter 2 of Module 2 on the detailed discussion of JSON), and then show how to pre-process the text content, which includes handling emoticons, tokenizing tweets, and generating feature words.
#
# ### 2.1. Loading Tweets from a Dump File
# Let's first load the tweets from a dump file,

# %%
# Import the necessary package to process data in JSON format
try:
    import json
except ImportError:
    import simplejson as json

# %%
import codecs
tweets = []
f = codecs.open("tweetSamples.json", "r", "utf-8")
for line in f:
    tweet = json.loads(line)
    tweets.append(tweet) 
f.close()

# %% [markdown]
# In the previous section, we have seen that each tweet object contains not only the text content but also
# other related information.
# Let's have a look at the structure of a tweet.
# Recall that each tweet is stored in a Python dictionary.
# Thus, to view all the attributes (or fields), simply type:

# %%
tweets[0].keys()
# Out:
# dict_keys(['contributors', 'truncated', 'text', 'is_quote_status', 'in_reply_to_status_id', 'id', 'favorite_count', 'retweeted', 'coordinates', 'source', 'in_reply_to_screen_name', 'in_reply_to_user_id', 'retweet_count', 'id_str', 'favorited', 'user', 'geo', 'in_reply_to_user_id_str', 'lang', 'created_at', 'in_reply_to_status_id_str', 'place', 'metadata'])

# %% [markdown]
# The key fields are the following:
# * **text**: the text content of the tweet itself
# * **created_at**: when the tweet was posted
# * **favorite_count, retweet_count**: the number of favourites and retweets
# * **favorited, retweeted**: Boolean stating whether the authenticated user has favourited or retweeted this tweet
# * **lang**: the language used for the tweet (e.g. “en” for English)
# * **id**: the unique tweet identifier
# * **id_str**: The string representation of the tweet identifier
# * **place, coordinates, geo**: geo-location information if available
# * **user**: the full profile of the user, which contains user's id, name,  screen_name and so on.
# * **entities**: list of entities like URLs, @-mentions, hashtags and symbols
#
# As you can see there’s a lot of information we can use in analysing tweets.
# You can imagine how the data stored in those fields already allows for some interesting analysis,
# for example, you can check who is most favourited/retweeted, what are the most popular hashtags, etc.
# Assume we are going to extract data stored in the following fields
# * id: `tweet['id']`
# * created_at: `tweet['created_at']`
# * text: `tweet['text']`
# * user's id: `tweet['id']`
# * user's name: `tweet['user']['name']`
# * user's screen_name: `tweet['user']['screen_name']`
#
# and store them in a Pandas DataFrame.

# %%
tweets[0]['user']['screen_name']
# Out:
# 'luke_sabatini'

# %%
import pandas as pd
tweets_pddf = pd.DataFrame()
tweets_pddf['id'] = list(map(lambda tweet: tweet['id'], tweets))
tweets_pddf['user_id'] = list(map(lambda tweet: tweet['user']['id'], tweets))
tweets_pddf['user_name'] = list(map(lambda tweet: tweet['user']['name'], tweets))
tweets_pddf['user_sname'] = list(map(lambda tweet: tweet['user']['screen_name'], tweets))
tweets_pddf['created_at'] = list(map(lambda tweet: tweet['created_at'], tweets))
tweets_pddf['text'] = list(map(lambda tweet: tweet['text'], tweets))

# %%
tweets_pddf.head()
# Out:
#                    id    user_id       user_name       user_sname  \
# 0  710240637497380864  534729059   Luke Sabatini    luke_sabatini
# 1  710240382311731200  215322466  Sina Marandian          myCroon
# 2  710239778554257408  947522706   Brett Keleher  thebrickcleaner
# 3  710238746688364545  215322466  Sina Marandian          myCroon
# 4  710238698428706816   94544311             Ant           AntB77
#
#                        created_at  \
# 0  Wed Mar 16 23:05:38 +0000 2016
# 1  Wed Mar 16 23:04:37 +0000 2016
# 2  Wed Mar 16 23:02:13 +0000 2016
# 3  Wed Mar 16 22:58:07 +0000 2016
# 4  Wed Mar 16 22:57:55 +0000 2016
#
#                                                 text
# 0  .@metrotrains, another day another diverted la...
# 1  @metrotrains 12 mins delay YET AGAIN on Flinde...
# 2  @danielbowen @VLine @jimbob_prod @metrotrains ...
# 3  @metrotrains not sure if guys who run Melbourn...
# 4            @metrotrains and we're away 10 min late

# %% [markdown]
# Most of the material we’re looking for, i.e. the content of a tweet, is embedded in the text, and that’s where we’re starting our analysis.
# Twitter only allows 140 characters of textual content for each tweet, which can roughly correspond to thoughts or ideas of Twitter users.
# The 140 characters may include one or more entities and reference one or more places that map to locations in the real world.
# To make it a bit more concrete, let's have a look at the textual content of the first tweet:

# %%
print (tweets_pddf['text'][0])
# Out:
# .@metrotrains, another day another diverted late city loop train from Caulfield straight to Flinders! @9NewsMelb! #cheers

# %% [markdown]
# The tweet is 121 characters long and contains three tweet entities: the user mentions '@metrotrains' and '@9NewsMelb', and the hashtag '#cheers'. Besides user mentions and hashtags, most tweets also contain emoticons, for instance

# %%
print (tweets_pddf['text'][2162])
# Out:
# Less than 10kms from the city and it has taken @metrotrains an hour and 20 minutes to get me there. Hats off all 🎩👏🏻 keep up the good work

# %% [markdown]
# Unlike formally written English, e.g., newswire-like text,
# tweets do often not confirm to rules of spelling, grammar, and punctuation.
# They often contain acronyms, typos, emoticons and other characters that express special meanings.
# Therefore, pre-processing tweets needs special treatment, compared with pre-processing formally written English text.
# In the rest of this section, you will learn how to manipulate tweets into a form that can be digested by text analysis algorithms used in tasks, such as sentiment analysis.

# %% [markdown]
# ### 2.2. Looking for Emoticons
# [Emoticons](https://en.wikipedia.org/wiki/Emoticon), such as 😂,😊,😡,😀, etc. are frequently used tweets and other kinds of online social iterations. They are designed to add emotional flavor to plain text messages, especially in short messages like tweets.
# Because they are often direct signals of sentiment, emoticons in text have been widely used as features in
# sentiment analysis or as entries of sentiment lexicons.
# Given a large amount of tweets posted every day, it would be interesting for businesses and researchers
# to understand the prevalence of emoticons on Twitter, how users express and perceive sentiment
# through emoticons, and whether emoticons can be used as a reliable cue for identifying sentiment polarity.
# In many of the existing sentiment analysis algorithms, emoticons played an important
# role in both building sentiment lexicons and in training classifiers.
# Discussing sentiment analysis iteself however goes beyond our scope.
# Instead we will focus on identifying emoticons while pre-processing tweets.
#
# Let's start with looking for a tweet that contains "Hats off all 🎩👏🏻":

# %%
tweets_text = list(map(lambda tweet: tweet['text'], tweets))

# %%
t =''
for text in tweets_text:
    if "Hats off all" in text:
        t = text
print (t)
# Out:
# Less than 10kms from the city and it has taken @metrotrains an hour and 20 minutes to get me there. Hats off all 🎩👏🏻 keep up the good work

# %% [markdown]
# What do the emotcons really look like?

# %%
'👏'.encode('unicode_escape')
# Out:
# b'\\U0001f44f'

# %%
'👏'.encode('unicode_escape').decode("utf-8")
# Out:
# '\\U0001f44f'

# %%
t.encode('unicode_escape').decode("utf-8")
# Out:
# 'Less than 10kms from the city and it has taken @metrotrains an hour and 20 minutes to get me there. Hats off all \\U0001f3a9\\U0001f44f\\U0001f3fb keep up the good work'

# %%
print(t.encode("raw_unicode_escape").decode("utf-8"))
# Out:
# Less than 10kms from the city and it has taken @metrotrains an hour and 20 minutes to get me there. Hats off all \U0001f3a9\U0001f44f\U0001f3fb keep up the good work

# %% [markdown]
# Emoticons are conventionally represented by punctuation marks, numbers and letters, such as :-), :D, :(, etc.
# See Wikipedia entry on "[List of emoticons](https://en.wikipedia.org/wiki/List_of_emoticons)".
# They have been introduced in Unicode since 2010.
# As you can see above, all the emoticons are represented by Unicode strings, such as '\U0001f44f' corresponding to 👏.
# [The standard emoticons](http://www.unicode.org/charts/PDF/U1F600.pdf ) covers Unicode range from 1F600 to 1F64F,
# i.e., \u0001F600 to \u0001F64F. For example,

# %%
print(u'\U0001f600')
print(u'\U0001f601')
print(u'\U0001f60A')
print(u'\U0001f640')
print(u'\U0001f64f')
print(u'\U0001f3a9')
# Out:
# 😀
# 😁
# 😊
# 🙀
# 🙏
# 🎩

# %%
print(u'\U0001f3a9')
print(u'\U0001f44f')
print(u'\U0001f3fb')
# Out:
# 🎩
# 👏
# 🏻

# %% [markdown]
# A set of emoticons that can be used by Twitter users can be found [here](http://www.secret-emoticons.com/twitter-emoticons). It contains far more rich emoticons than the standard set.
# We have known how emoticons are represented in tweets.
# Next, we are going to **extract emoticons** and save it in one column in our DataFrame `tweets_pddf`.
#
# Instead of matching the unicode strings, we found `emoji`, a Python library that **supports the entire set of Emoji codes** as defined by [the Unicode consortium](http://www.unicode.org/emoji/charts/full-emoji-list.html).
# This library can run with Python 2.7.
#
# To install this package, type the following `pip` into your command window:
# ```
#     pip install emoji --upgrade
# ```
# Try to print some emoticons from its [Cheat Sheet](http://www.emoji-cheat-sheet.com/):

# %%
import emoji 

print(emoji.emojize('simle :smile:', use_aliases=True))
print(emoji.emojize('heart_eyes :heart_eyes:', use_aliases=True))
print(emoji.emojize('smiling_imp :smiling_imp:', use_aliases=True))
print(emoji.emojize('book :book:', use_aliases=True))
# Out:
# simle 😄
# heart_eyes 😍
# smiling_imp 😈
# book 📖

# %% [markdown]
# To extract all the emoticons in a tweet, we are going to use the `emoji.get_emoji_regexp()` method
# that returns a compiled regular expression that matches all the emoticons defined in `emoji`,
# and then pass this regular expression to the `findall` method as follows:

# %%
import re

emoticon_regexp = emoji.get_emoji_regexp() # get the regular expressions for all emoticons
ems = re.findall(emoticon_regexp, t) # find all emoticons
for e in ems:
    print (e, ":", e.encode('unicode_escape').decode("utf-8"))
# Out:
# 🎩 : \U0001f3a9
# 👏🏻 : \U0001f44f\U0001f3fb

# %% [markdown]
# Now wrap the first two lines of the code above in a Python function, and make it a callable function.

# %%
def findEmoticons(text):
    emoticon_regexp = emoji.get_emoji_regexp() # RegExp pattern
    emoticons = re.findall(emoticon_regexp, text) # re.findall(ptn, text)
    return emoticons

# %% [markdown]
# This function can be applied to each tweet and check if it contains any emoticons.
# Let's find all tweets that contain one or more emoticons:

# %%
count = 0
for tweet in tweets_text:
    emoticons = findEmoticons(tweet)
    if len(emoticons) > 0:
        print (tweet)
        print (', '.join(emoticons))
        count = count + 1
print ("\n#tweets containing emoticon: ", count)
# Out:
# @metrotrains every night at like 1am?! 😂 scares me to death. Theres a brand new apartment block close by. Could they stop sounding the horn?
# 😂
# @nudge87 @metrotrains it sounds like it 🤓
# 🤓
# @nudge87 @metrotrains tell them what you really think of them, don't hold back 😉😉
# 😉, 😉
# @teganvictoria @metrotrains oh perfect 😒😒
# 😒, 😒
# @sassypastry @metrotrains day I left work early specifically to make it to an appointment on time 😤
# 😤
# @metrotrains broken glass on the floor of the 9.58 south morang leaving from Parliament. Carriage no. is 124m 😊 https://t.co/4Peh3isFC6
# 😊
# @metrotrains this is the train at noble park station at at 9:07 or so. Just letting you know the lights are out 😊 https://t.co/krTahmhE1l
# 😊
# @metrotrains I think there's a better chance of hell freezing over than you running a service on time.... 👎🏻💩
# 👎🏻, 💩
# Really @metrotrains? Really?🖕🏼
# 🖕🏼
# @metrotrains thanks to the driver on the 7.31 Sandy to city service - great hump day commentary, especially liked the dad joke 👍
# 👍
# Melbourne CBD 😆.. (at @metrotrains) [pic] — https://t.co/fKwPl5UTOq
# 😆
# @Juz1093 @metrotrains @ptv_official @JacintaAllanMP clearly so are they 😋
# 😋
# @metrotrains Well, what do you know? Another morning of major delays! 3 city bound trains stationary on the Pakenham line! So fed up 😡😡😡
# 😡, 😡, 😡
# @metrotrains Thank you for the coffee this morning :-) 👍
# 👍
# @metrotrains Middle Brighton at midnight. Crazy loud for hours. 😩
# 😩
# @metrotrains Nope, downloading now 😊
# 😊
# @metrotrains @beijingbecky @fakemetrotrains any reason for the canx? Driver sleep in? 😁
# 😁
# @metrotrains ha if u can pay for 3 inspectors may b you could afford a few cleaners P.s inspectors very nice !👌🏽 https://t.co/8sIYX4e0qg
# 👌🏽
# Way to Bundoora 🚉 (@ Melbourne Central Station - @metrotrains in Melbourne, VIC) https://t.co/wFaGfBbBvk
# 🚉
# @AaronRichOnAir @metrotrains @SthCrossStation would be awesome if there were more but definitely saw more than 1 there yesterday 🤔
# 🤔
# Seriously @metrotrains 1 myki machine at @SthCrossStation 😡
# 😡
# @metrotrains thanks for sharing Metro Trains, have a great Saturday :) (Want this 🆓? &gt;&gt; https://t.co/awLfk1Ri2f)
# 🆓
# @metrotrains 6am train already delayed 5 minutes 😑 wtf
# 😑
# @metrotrains not all clear now stuck at Westall 5mins! What man. Dog needs food 🐕
# 🐕
# @metrotrains you are a fucking moron! A game tonight and no extra trains, what a shame 💩💩💩💩
# 💩, 💩, 💩, 💩
# @onetui @metrotrains just makes u crazy ⚡️⚡️⚡️⚡️⚡️⚡️
# ⚡, ⚡, ⚡, ⚡, ⚡, ⚡
# @l_teare @metrotrains I heard a passenger say she'd waited an hour at Flagstaff, sent to Melbourne Central and then to Flinders St. 😡
# 😡
# To be told a train isn't stopping at a station, only to hear, "oh actually, it is", as the doors close. 😡 #metrofail @metrotrains 2/2
# 😡
# Not my photo, just came across it...love trains!! Second long weekend in a row? Don't mind if I do! 😎 #metrotrains #trains #melbournetrains…
# 😎
# @metrotrains @jeffw0303 trains are now back running in both directions 😊
# 😊
# @HawthornFC Howz this?? 💪🏼 #PTV #metrotrains #hawthornalways https://t.co/LECNCiTcN5
# 💪🏼
# RT @danielbowen: Train was on time / got a seat / driver announcements both informative and amusing. Hopefully the curse is lifted?🚂 #metro…
# 🚂
# Train was on time / got a seat / driver announcements both informative and amusing. Hopefully the curse is lifted?🚂 #metrotrains
# 🚂
# @metrotrains your service sucks😀😀
# 😀, 😀
# @metrotrains please thank the driver of the 7.07am Berwick to City service fir waiting for me.  Really appreciate it ☺
# ☺
# @burnsie67 @JacintaAllanMP @metrotrains - Victoria is stuffed. There isn't hope for the State. Over populated and growing 😂😂😂
# 😂, 😂, 😂
# Dear @metrotrains, I want a refund on my Myki charge this evening. Call it compensation* for your inadequacy. Apply 2 all on Pak,Cran&amp;Fran😡
# 😡
# Good god, a drop of rain &amp; @metrotrains terminate not 1 but 2 Cranbourne trains at Dandenong 😡
# 😡
# Dear @metrotrains pakenham driver, I know you have to make all stops but if you could hurry up that would be great 😜#WantToBeHome
# 😜
# @metrotrains never mind 😊
# 😊
# @sophbenj @metrotrains mine to was 6 mins late, then stationary b/w stations, then route altered to flinders &amp; skip loop. 2 days in a row 😡
# 😡
# Forgot 😅 (@ Flinders Street Station - @metrotrains in Melbourne, VIC) https://t.co/25woyGsTA5
# 😅
# The worst service ever @metrotrains! No announcements,  no courtesy 😡😡
# 😡, 😡
# @metrotrains #metrofail strikes again 👎
# Too humid this morning for Metro ???
# 👎
# @metrotrains thanks forthe free coffee at kananook this morning 👍
# 👍
# Free coffee's today compliments of @metrotrains Now that's a nice gesture ! Totally appreciated and your really trying THANKS 😆
# 😆
# @theheraldsun Fantastic, just before the footy season starts @metrotrains 👊🏻
# 👊🏻
# @metrotrains I have no doubt my tweet has zero to do with the fact the train was two minutes later today but thank you all the same 😊
# 😊
# Tap on at Hawksburn at 8.05am. Pull into Flinders St (3 stops) at 9.13am. Good job again @metrotrains 👎🏻
# 👎🏻
# @metrotrains thanks for the signal faults on Frankston line again. Late two days in a row 👏
# 👏
# @NStaikos @JacintaAllanMP @metrotrains @ptv_official We need to talk about the Frankston Line #NotHappy 😡
# 😡
# @metrotrains yeah got the app, it's going mental with notifications. This line has killed me two days in a row now so just a hit and hope 😖
# 😖
# Nah I honestly feel like @ptv_official or @metrotrains should give out free water when the trains are delayed in extreme heat 🔥
# 🔥
# Being held prisoner on a faulty @metrotrains train, metres trom Caulfield. Where's an @ostrichpillow when you need one?!? 🚉💤 👎🏻
# 🚉, 💤, 👎🏻
# Why am I sitting at Flinders Street for 18 minutes before this Frankston train moves? 😡 It's like you want me to move to Tokyo @metrotrains
# 😡
# @metrotrains so in just over an hour you've moved me about 1.5 km. well done 👍
# 👍
# @metrotrains thanks! Just signed up to Twitter to ask 😊
# 😊
# @metrotrains have pumped the AC on the Upfield line #thankyou 😎
# 😎
# Seriously air con not working on the 418 Sunbury from Parliament @metrotrains ? It's 38 💦💦😡😡
# 💦, 💦, 😡, 😡
# Less than 10kms from the city and it has taken @metrotrains an hour and 20 minutes to get me there. Hats off all 🎩👏🏻 keep up the good work
# 🎩, 👏🏻
# @metrotrains How many standing people can a carriage legally carry? #OHS 🚋👭👬👫🚋👫👬👭🚋
# 🚋, 👭, 👬, 👫, 🚋, 👫, 👬, 👭, 🚋
# Wondering when the 8.45 Sth Morang train at Parliament Stn will actually get there at 8.45 😳 . Always seems like it doesn't #metrotrains
# 😳
# @metrotrains - congratulations on yet another day of cataclysmic failure on the Frankston line. No really - thanks! 😡
# 😡
# Thanks for the free coffee ☕️ @metrotrains
# ☕
# 7.35 Carrum stuck between aspendale and mordi. Might wanna turn the aircon on at least. 👍 @metrotrains
# 👍
# @metrotrains Good work on meeting 100% passenger capacity on the 7:32 Heidelberg train at Dennis station this morning! 👍👍👍👍
# 👍, 👍, 👍, 👍
# @metrotrains 15 min to get from Footscray to Sth kensIngton. Sharp l, dangerous stopping = track faults. 😬
# 😬
#
# #tweets containing emoticon:  67

# %% [markdown]
# The total number of tweets containing at least one emoticon defined in `emoji` is 67.
# Given the total number of tweets that we have, it seems that there are not many tweets containing emoticons.
# We might also need to consider the emoticons that are represented by punctuation marks, numbers and letters, such as :-), :D, :(, etc. We will leave it as an exercise for you to extract all those conventional emoticons.
#
# **Counting observable things** is the start point for any kind of statistical analysis or manipulation that strives to find what may be a faint signal in raw data [1]. Whereas we just extracted all the emoticons in all the tweets loaded from the dump file, let's now take a closer look at **the frequency distribution** of those emoticons and print out **the most frequent emoticons**.
#
# In the previous chapter, you have learnt how to use the `FreqDist` class in NLTK.
# Here we are going to use the `collections` module in Python, which provides a `Counter` class that
# can compute a frequency distribution of a given data.
# Indeed, the `FreqDist` class is implemented with the `Counter` class.
# The code below demonstrates how to use a `Counter` object to compute frequency distribution as a ranked list of emoticons.
#
# Counting frequency distributions is **the simplest technique** used in analysing Twitter data.

# %%
import collections
em_list = []
for tweet in tweets_text:
     em_list += findEmoticons(tweet)
print(em_list)
em_counter = collections.Counter(em_list)
em_counter.most_common(20)
# Out:
# ['😂', '🤓', '😉', '😉', '😒', '😒', '😤', '😊', '😊', '👎🏻', '💩', '🖕🏼', '👍', '😆', '😋', '😡', '😡', '😡', '👍', '😩', '😊', '😁', '👌🏽', '🚉', '🤔', '😡', '🆓', '😑', '🐕', '💩', '💩', '💩', '💩', '⚡', '⚡', '⚡', '⚡', '⚡', '⚡', '😡', '😡', '😎', '😊', '💪🏼', '🚂', '🚂', '😀', '😀', '☺', '😂', '😂', '😂', '😡', '😡', '😜', '😊', '😡', '😅', '😡', '😡', '👎', '👍', '😆', '👊🏻', '😊', '👎🏻', '👏', '😡', '😖', '🔥', '🚉', '💤', '👎🏻', '😡', '👍', '😊', '😎', '💦', '💦', '😡', '😡', '🎩', '👏🏻', '🚋', '👭', '👬', '👫', '🚋', '👫', '👬', '👭', '🚋', '😳', '😡', '☕', '👍', '👍', '👍', '👍', '👍', '😬']
# [('😡', 16),
#  ('👍', 9),
#  ('😊', 7),
#  ('⚡', 6),
#  ('💩', 5),
#  ('😂', 4),
#  ('👎🏻', 3),
#  ('🚋', 3),
#  ('😉', 2),
#  ('😒', 2),
#  ('😆', 2),
#  ('🚉', 2),
#  ('😎', 2),
#  ('🚂', 2),
#  ('😀', 2),
#  ('💦', 2),
#  ('👭', 2),
#  ('👬', 2),
#  ('👫', 2),
#  ('🤓', 1)]

# %% [markdown]
# As shown above, the frequency distribution is represented by a list of key/value pairs corresponding to emoticons in Unicode and their frequencies.
# Following [1], let's make reviewing the distribution a litte easier for eyeballing by tabulating those key/value pairs.
# To emit a tabular or table format, you can install a Python package, called [`prettytable`](https://pypi.python.org/pypi/PrettyTable) by typing
# ```
#     pip install prettytable
# ```
# in your command window.
# It is a simple Python library designed to make it **quick and easy to represent tabular data** in visually appealing ASCII tables.
# The following code shows how to display the same result in a nicely formatted text-based table that
# is easy to skim by humans.

# %%
em_counter.most_common(5)
# Out:
# [('😡', 16), ('👍', 9), ('😊', 7), ('⚡', 6), ('💩', 5)]

# %%
from prettytable import PrettyTable
pt = PrettyTable(field_names=['Emoticons','Count'])
[pt.add_row(kv) for kv in em_counter.most_common(5)]
#pt.align['Emoticon'], pt.align['Count'] = 'l', 'r'
print (pt)
# Out:
# +-----------+-------+
# | Emoticons | Count |
# +-----------+-------+
# |     😡     |   16  |
# |     👍     |   9   |
# |     😊     |   7   |
# |     ⚡     |   6   |
# |     💩     |   5   |
# +-----------+-------+

# %% [markdown]
# A quick skim of the result could reveal that the most frequent emoticon is 😡, an angry face.
# Among those tweets containing at least one emoticon, there are more than 25 of them that have negative sentiment on metrotrains, where we assume 💩 indicates negative sentiment.
# It is quite common in sentiment analysis to use emoticons as clues in determining the sentiment polarity of tweets.
# However, some research work [4] on the relationship between emoticons and sentiment polarity shows that
# a few emoticons are strong and reliable signals of sentiment polarity and a large group of the emoticons
# coveys complicated sentiment where they should be treated carefully,
# see Figure 1 of [4], a survey of emotion expressed by emoticons.
#
# Our last step is to save those emoticons in one column in the DataFrame, `tweets_pddf`, so that the downstream text analyser can directly make use of them.

# %%
tweets_pddf.head()
# Out:
#                    id    user_id       user_name       user_sname  \
# 0  710240637497380864  534729059   Luke Sabatini    luke_sabatini
# 1  710240382311731200  215322466  Sina Marandian          myCroon
# 2  710239778554257408  947522706   Brett Keleher  thebrickcleaner
# 3  710238746688364545  215322466  Sina Marandian          myCroon
# 4  710238698428706816   94544311             Ant           AntB77
#
#                        created_at  \
# 0  Wed Mar 16 23:05:38 +0000 2016
# 1  Wed Mar 16 23:04:37 +0000 2016
# 2  Wed Mar 16 23:02:13 +0000 2016
# 3  Wed Mar 16 22:58:07 +0000 2016
# 4  Wed Mar 16 22:57:55 +0000 2016
#
#                                                 text emoticons
# 0  .@metrotrains, another day another diverted la...       NaN
# 1  @metrotrains 12 mins delay YET AGAIN on Flinde...       NaN
# 2  @danielbowen @VLine @jimbob_prod @metrotrains ...       NaN
# 3  @metrotrains not sure if guys who run Melbourn...       NaN
# 4            @metrotrains and we're away 10 min late       NaN

# %%
import numpy as np
emoticon_list = []
for tweet in tweets_text:
    em = findEmoticons(tweet)
    if len(em) is 0:
        em = np.nan
    emoticon_list.append(em)
tweets_pddf['emoticons'] = emoticon_list
#view tweet record in the dataframe, which contain at least one emoticon.
tweets_pddf.dropna(subset=['emoticons'])
# Out:
#                       id             user_id             user_name  \
# 114   710033743679922176          2954409301                 Lee P
# 147   709996461098967040           618374806           John Murray
# 149   709995610074644480           618374806           John Murray
# 167   709976740320382977           128062445  ~*~~luxury witch~~*~
# 168   709976646053466113            29664096        Tegan Victoria
# 199   709884186081951744            27848004        Jessica Falzon
# 217   709868580339187712          3225947413           Aaron Quick
# 220   709867747593703424            33170156         jason mcmahon
# 234   709862278145806337          2208982531            Haze Soboh
# 279   709846711678599168           719612448                   p13
# 314   709742282598064128            83320940       Investalia Dewi
# 345   709636532617879552          2861941951                 Donna
# 430   709487132948074496           414698399                 Emy V
# 432   709485808932093952           161179702        Jacques Theron
# 443   709476444238254080            20122186                 kimco
# 451   709473159452299264            88899131        Shanal Uduwana
# 468   709458168326193153           447588807           Manuel Bouw
# 602   708836327513436160          2290894069                    Me
# 626   708625144781139970           754787773                  آلاء
# 656   708462399272005632          2396215244       Forever_we_grow
# 657   708461377053011968           101981552            Aaron Rich
# 676   708417176563134464           777771373    Emagod Co. limited
# 687   708368309402542080          2197112286                Rodney
# 690   708251597411778560            25532421                  Cris
# 707   708232375621148673          4633325772          Lucky Punter
# 713   708226820512944128          2290894069                    Me
# 715   708226224078725120           232380737         Roslyn Grundy
# 777   708187225788325888           240981926          Rachel Jones
# 786   708179768038928384          2177267498               R. Hobo
# 824   708137229516845057          4506028033          Luke Hildred
# ...                  ...                 ...                   ...
# 998   707826204355784704          3341024598     Narelle Butteriss
# 999   707825782077444097            35084541          Dame Vaxalot
# 1011  707815981498941440           257160692                 Mel H
# 1028  707810141194854400           413779729   Turn&FaceTheStrange
# 1068  707753569571594240           312794926      Cañas Al-Moosawi
# 1157  707706671301169153            94206493    Gregory J Williams
# 1454  707669435398492160           207835793           ⚫⚪ David ⚪⚫
# 1497  707658223185072128          1313217092       Keren Robertson
# 1499  707657074621067265          1509460274        serveandvolley
# 1516  707533454859116544          2647441508                BluBoy
# 1549  707460829118144514          2884719129       Lizzie Thompson
# 1654  707328737381998592            61871540            Tom Heddon
# 1717  707318398774943744           205625422          Chris Tanner
# 1741  707316094004924418           622786187         sally fairlam
# 1788  707310900240211968           330959558          Daniel Maleš
# 1905  707187579909591040          2890030249               Meaghan
# 1907  707180954855444481           589693159         Andrew Powell
# 1983  707110979704782850            43664952                   Dan
# 1984  707110586471940097          1124784426        Dean Wickenton
# 2034  707098112486088708  707096612447719424                 Sasha
# 2046  707094545180143617            41543550       Lyndon Phillips
# 2081  707079890307194880            27338574       CarolsBumbleBee
# 2162  706968062809939969           330959558          Daniel Maleš
# 2180  706965674401206272          3005707343             { Sally }
# 2195  706960949563957248            20304045        Nick Ivanovski
# 2199  706960521300303872           377958521            David Lawn
# 2282  706950333163970560          2587244365        Aaron Donaghue
# 2316  706946608789790720           613362313           Yoongi-baby
# 2323  706945041864859650            14506011             Ryan Bigg
# 2326  706942491832889344           398474575          Laura Rouhan
#
#            user_sname                      created_at  \
# 114           leelufc  Wed Mar 16 09:23:30 +0000 2016
# 147        SidebySide  Wed Mar 16 06:55:22 +0000 2016
# 149        SidebySide  Wed Mar 16 06:51:59 +0000 2016
# 167       sassypastry  Wed Mar 16 05:37:00 +0000 2016
# 168     teganvictoria  Wed Mar 16 05:36:37 +0000 2016
# 199        jesssicaef  Tue Mar 15 23:29:13 +0000 2016
# 217           Azzmang  Tue Mar 15 22:27:12 +0000 2016
# 220       jasemcmahon  Tue Mar 15 22:23:54 +0000 2016
# 234         HazeSoboh  Tue Mar 15 22:02:10 +0000 2016
# 279         pietsch13  Tue Mar 15 21:00:19 +0000 2016
# 314          inees_ia  Tue Mar 15 14:05:21 +0000 2016
# 345       Donna_Lee_G  Tue Mar 15 07:05:08 +0000 2016
# 430            MsEmyV  Mon Mar 14 21:11:28 +0000 2016
# 432     jacquestheron  Mon Mar 14 21:06:13 +0000 2016
# 443         kim_cowen  Mon Mar 14 20:29:00 +0000 2016
# 451     ShanalUduwana  Mon Mar 14 20:15:57 +0000 2016
# 468        manuelbouw  Mon Mar 14 19:16:23 +0000 2016
# 602           l_teare  Sun Mar 13 02:05:24 +0000 2016
# 626          alaa_wah  Sat Mar 12 12:06:14 +0000 2016
# 656   forever_we_grow  Sat Mar 12 01:19:33 +0000 2016
# 657    AaronRichOnAir  Sat Mar 12 01:15:29 +0000 2016
# 676   EmagodColimited  Fri Mar 11 22:19:51 +0000 2016
# 687       rodneyrondo  Fri Mar 11 19:05:40 +0000 2016
# 690              vs0p  Fri Mar 11 11:21:54 +0000 2016
# 707       puntawakens  Fri Mar 11 10:05:31 +0000 2016
# 713           l_teare  Fri Mar 11 09:43:26 +0000 2016
# 715            onetui  Fri Mar 11 09:41:04 +0000 2016
# 777       miss_rach_j  Fri Mar 11 07:06:06 +0000 2016
# 786      RailYardHobo  Fri Mar 11 06:36:28 +0000 2016
# 824       LukeHildred  Fri Mar 11 03:47:26 +0000 2016
# ...               ...                             ...
# 998          bnelly63  Thu Mar 10 07:11:32 +0000 2016
# 999          nursereb  Thu Mar 10 07:09:51 +0000 2016
# 1011     MelHsayswhat  Thu Mar 10 06:30:55 +0000 2016
# 1028       PollyMaeve  Thu Mar 10 06:07:42 +0000 2016
# 1068         muntherx  Thu Mar 10 02:22:55 +0000 2016
# 1157   Pastorgregoryw  Wed Mar 09 23:16:33 +0000 2016
# 1454    turtlemagpies  Wed Mar 09 20:48:35 +0000 2016
# 1497   RobertsonKeren  Wed Mar 09 20:04:02 +0000 2016
# 1499  serveandvolley3  Wed Mar 09 19:59:28 +0000 2016
# 1516         blu_boys  Wed Mar 09 11:48:15 +0000 2016
# 1549       Lizziet124  Wed Mar 09 06:59:40 +0000 2016
# 1654      tommyheddon  Tue Mar 08 22:14:47 +0000 2016
# 1717       cjtanntann  Tue Mar 08 21:33:42 +0000 2016
# 1741       salsasslly  Tue Mar 08 21:24:32 +0000 2016
# 1788         danofage  Tue Mar 08 21:03:54 +0000 2016
# 1905         meagss29  Tue Mar 08 12:53:52 +0000 2016
# 1907      andyjpowell  Tue Mar 08 12:27:33 +0000 2016
# 1983        _DanHamer  Tue Mar 08 07:49:29 +0000 2016
# 1984       deanpwicko  Tue Mar 08 07:47:55 +0000 2016
# 2034  sashaja97928039  Tue Mar 08 06:58:21 +0000 2016
# 2046   Lyndonphillips  Tue Mar 08 06:44:11 +0000 2016
# 2081       Carol_Bond  Tue Mar 08 05:45:57 +0000 2016
# 2162         danofage  Mon Mar 07 22:21:35 +0000 2016
# 2180     diagon_sally  Mon Mar 07 22:12:06 +0000 2016
# 2195       nivanovski  Mon Mar 07 21:53:19 +0000 2016
# 2199          Lawnzie  Mon Mar 07 21:51:37 +0000 2016
# 2282    aarond0naghue  Mon Mar 07 21:11:08 +0000 2016
# 2316       yoongibaby  Mon Mar 07 20:56:20 +0000 2016
# 2323         ryanbigg  Mon Mar 07 20:50:07 +0000 2016
# 2326  aminotwittyenuf  Mon Mar 07 20:39:59 +0000 2016
#
#                                                    text  \
# 114   @metrotrains every night at like 1am?! 😂 scare...
# 147           @nudge87 @metrotrains it sounds like it 🤓
# 149   @nudge87 @metrotrains tell them what you reall...
# 167           @teganvictoria @metrotrains oh perfect 😒😒
# 168   @sassypastry @metrotrains day I left work earl...
# 199   @metrotrains broken glass on the floor of the ...
# 217   @metrotrains this is the train at noble park s...
# 220   @metrotrains I think there's a better chance o...
# 234                      Really @metrotrains? Really?🖕🏼
# 279   @metrotrains thanks to the driver on the 7.31 ...
# 314   Melbourne CBD 😆.. (at @metrotrains) [pic] — ht...
# 345   @Juz1093 @metrotrains @ptv_official @JacintaAl...
# 430   @metrotrains Well, what do you know? Another m...
# 432   @metrotrains Thank you for the coffee this mor...
# 443   @metrotrains Middle Brighton at midnight. Craz...
# 451                @metrotrains Nope, downloading now 😊
# 468   @metrotrains @beijingbecky @fakemetrotrains an...
# 602   @metrotrains ha if u can pay for 3 inspectors ...
# 626   Way to Bundoora 🚉 (@ Melbourne Central Station...
# 656   @AaronRichOnAir @metrotrains @SthCrossStation ...
# 657   Seriously @metrotrains 1 myki machine at @SthC...
# 676   @metrotrains thanks for sharing Metro Trains, ...
# 687   @metrotrains 6am train already delayed 5 minut...
# 690   @metrotrains not all clear now stuck at Westal...
# 707   @metrotrains you are a fucking moron! A game t...
# 713   @onetui @metrotrains just makes u crazy ⚡️⚡️⚡️...
# 715   @l_teare @metrotrains I heard a passenger say ...
# 777   To be told a train isn't stopping at a station...
# 786   Not my photo, just came across it...love train...
# 824   @metrotrains @jeffw0303 trains are now back ru...
# ...                                                 ...
# 998   Good god, a drop of rain &amp; @metrotrains te...
# 999   Dear @metrotrains pakenham driver, I know you ...
# 1011                          @metrotrains never mind 😊
# 1028  @sophbenj @metrotrains mine to was 6 mins late...
# 1068  Forgot 😅 (@ Flinders Street Station - @metrotr...
# 1157  The worst service ever @metrotrains! No announ...
# 1454  @metrotrains #metrofail strikes again 👎 \nToo ...
# 1497  @metrotrains thanks forthe free coffee at kana...
# 1499  Free coffee's today compliments of @metrotrain...
# 1516  @theheraldsun Fantastic, just before the footy...
# 1549  @metrotrains I have no doubt my tweet has zero...
# 1654  Tap on at Hawksburn at 8.05am. Pull into Flind...
# 1717  @metrotrains thanks for the signal faults on F...
# 1741  @NStaikos @JacintaAllanMP @metrotrains @ptv_of...
# 1788  @metrotrains yeah got the app, it's going ment...
# 1905  Nah I honestly feel like @ptv_official or @met...
# 1907  Being held prisoner on a faulty @metrotrains t...
# 1983  Why am I sitting at Flinders Street for 18 min...
# 1984  @metrotrains so in just over an hour you've mo...
# 2034  @metrotrains thanks! Just signed up to Twitter...
# 2046  @metrotrains have pumped the AC on the Upfield...
# 2081  Seriously air con not working on the 418 Sunbu...
# 2162  Less than 10kms from the city and it has taken...
# 2180  @metrotrains How many standing people can a ca...
# 2195  Wondering when the 8.45 Sth Morang train at Pa...
# 2199  @metrotrains - congratulations on yet another ...
# 2282         Thanks for the free coffee ☕️ @metrotrains
# 2316  7.35 Carrum stuck between aspendale and mordi....
# 2323  @metrotrains Good work on meeting 100% passeng...
# 2326  @metrotrains 15 min to get from Footscray to S...
#
#                         emoticons
# 114                           [😂]
# 147                           [🤓]
# 149                        [😉, 😉]
# 167                        [😒, 😒]
# 168                           [😤]
# 199                           [😊]
# 217                           [😊]
# 220                       [👎🏻, 💩]
# 234                          [🖕🏼]
# 279                           [👍]
# 314                           [😆]
# 345                           [😋]
# 430                     [😡, 😡, 😡]
# 432                           [👍]
# 443                           [😩]
# 451                           [😊]
# 468                           [😁]
# 602                          [👌🏽]
# 626                           [🚉]
# 656                           [🤔]
# 657                           [😡]
# 676                           [🆓]
# 687                           [😑]
# 690                           [🐕]
# 707                  [💩, 💩, 💩, 💩]
# 713            [⚡, ⚡, ⚡, ⚡, ⚡, ⚡]
# 715                           [😡]
# 777                           [😡]
# 786                           [😎]
# 824                           [😊]
# ...                           ...
# 998                           [😡]
# 999                           [😜]
# 1011                          [😊]
# 1028                          [😡]
# 1068                          [😅]
# 1157                       [😡, 😡]
# 1454                          [👎]
# 1497                          [👍]
# 1499                          [😆]
# 1516                         [👊🏻]
# 1549                          [😊]
# 1654                         [👎🏻]
# 1717                          [👏]
# 1741                          [😡]
# 1788                          [😖]
# 1905                          [🔥]
# 1907                   [🚉, 💤, 👎🏻]
# 1983                          [😡]
# 1984                          [👍]
# 2034                          [😊]
# 2046                          [😎]
# 2081                 [💦, 💦, 😡, 😡]
# 2162                      [🎩, 👏🏻]
# 2180  [🚋, 👭, 👬, 👫, 🚋, 👫, 👬, 👭, 🚋]
# 2195                          [😳]
# 2199                          [😡]
# 2282                          [☕]
# 2316                          [👍]
# 2323                 [👍, 👍, 👍, 👍]
# 2326                          [😬]
#
# [67 rows x 7 columns]

# %% [markdown]
# ### 2.2 Tokenizing Tweet Text
# We have discussed the basic steps in pre-processing text in chapter 1.
# Can those steps be directly applied to Tweet tokenization?
# Let's see some examples, using the popular NLTK library to tokenise the following tweet:
# ```
# u'@HawthornFC Howz this?? \U0001f4aa\U0001f3fc #PTV #metrotrains #hawthornalways https://t.co/LECNCiTcN5'
# ```

# %%
import nltk
tweet = u'@HawthornFC Howz this?? \U0001f4aa\U0001f3fc #PTV #metrotrains #hawthornalways https://t.co/LECNCiTcN5'
print(nltk.tokenize.word_tokenize(tweet))
# Out:
# ['@', 'HawthornFC', 'Howz', 'this', '?', '?', '💪🏼', '#', 'PTV', '#', 'metrotrains', '#', 'hawthornalways', 'https', ':', '//t.co/LECNCiTcN5']

# %% [markdown]
# You will notice some peculiarities that are not captured by the NTLK built-in English tokenizer.
# For instance, @usernames, emoticons, hash tags and URLs **are not recognised as single tokens**.
# "@HawthornFC" was split into two parts, i.e., "@" and "HawthornFC", both emoticons' Unicode strings are put together as one token, and the URL has been split into three parts.
#
# Therefore, general-purpose English tokenizers are not applicable to tweets.
# Furthermore, there is another NTLK built-in tokenizer, which is called `TweetTokenizer`.
# Let's try it out,

# %%
from nltk.tokenize import TweetTokenizer
tt = TweetTokenizer()
tt.tokenize(tweet)
# Out:
# ['@HawthornFC',
#  'Howz',
#  'this',
#  '?',
#  '?',
#  '💪',
#  '🏼',
#  '#PTV',
#  '#metrotrains',
#  '#hawthornalways',
#  'https://t.co/LECNCiTcN5']

# %% [markdown]
# `TweetTokenizer(preserve_case=True, reduce_len=False, strip_handles=False)`
#
# **Three arguments**:
# * **preserve_case**: `True` by default. If False, then the tokenizer will downcase everything except for emoticons.
# * **reduce_len**: `False` by default. The tokenizer will **replace repeated character sequences** of length >= 3, if it is set to `True`. For example, "waaaaayyyy" is going to be repleced with "waaayyy", and "cooooool" with "coool".
# * **strip_handles**: `False` by default. All the `@usernames` will be **removed** if it is set to `True`
#
# Is `TweetTokenizer` good enough?
# It works much better than the general-purpose English tokenizer. It tokenizes @usernames, hashtags and URLs **as single tokens**. However, Unicode strings for emoticons are still a problem for `TweetTokenizer`.
# If we would like to preserve @usernames, emoticons, URLs and hash-tags as individual tokens,
# Let's try the code discussed in Part 2 of [2] with some modification.

# %% [markdown]
# > flag `(?x)`:
#   This flag allows you to write regular expressions that **look nicer and are more readable** by allowing you to **visually separate logical sections of the pattern** and **add comments**. Whitespace within the pattern is ignored. When a line contains a # that is not in a character class and is not preceded by an unescaped backslash, **all characters from the leftmost such # through the end of the line are ignored**.

# %%
token_re = r'''(?x)
            (?:@[\w_]+) # matches @username
            |(?:\#+[\w_]+[\w\'_\-]*[\w_]+) # matches hash-tags
            |http[s]?://(?:[a-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+ # matches URLs
            |(?:(?:\d+,?)+(?:\.?\d+)?) # matches numbers
            |(?:[a-z][a-z'\-_]+[a-z]) # matches words with hyphens and apostrophes 
            |(?:[\w_]+) # mathes other words
'''

def tokenize(s):
    tokens = re.findall(emoji.get_emoji_regexp(), s) # first find all the emoticons
    tokens += re.findall(token_re, s)
    return tokens
print(tweet)
tokenize(tweet)
# Out:
# @HawthornFC Howz this?? 💪🏼 #PTV #metrotrains #hawthornalways https://t.co/LECNCiTcN5
# ['💪🏼',
#  '@HawthornFC',
#  'Howz',
#  'this',
#  '#PTV',
#  '#metrotrains',
#  '#hawthornalways',
#  'https://t.co/LECNCiTcN5']

# %% [markdown]
# Compared with the results given by the general purpose tokenizer and the tweet tokenizer in NLTK, the customised tokenizer gave much better tokenization of the tweet.
# Please do take a moment to observe those regular expressions to check if you can understand all of them.
#
# Note that the tokenizer is probably far from perfect for handling tweets, as the language used in tweets is very informal. Twitter users often use arbitrary abbreviations, repeat letters in words, and so on. It is very challenging to develop a tokenizer that can perfectly tokenize tweets.
#
# After tokenizing the tweets, we can use some procedures introduced in Chapter 2 to further customise
# the list of tokens we are interested in by counting word frequencies, removing stopwords, generating bigram or even n-grams, etc.

# %% [markdown]
# ### 2.3 Pre-processing Tweet for Sentiment Analysis
# We have been mentioning sentiment analysis since the beginning of this chapter.
# Now let's have a look at a simple example of how to pre-process tweets for sentiment analysis by adapting the Python code in [5].
#
# As in [5], we assume that:
# 1. all the words in tweets should be converted to lower case;
# 2. all URLs and @username are eliminated by replacing them with "URL" and "at_USER" respectively;
# 3. hastags are replaced with the exact name without the hash symbol;
# 4. remove punctuation at the start and ending of the tweets.
#
# The following Python function should implement all the above tasks.

# %% [markdown]
# `re.sub(pattern, repl, string, count=0, flags=0)`:
# Return the string obtained by replacing the leftmost non-overlapping occurrences of the pattern in string by the replacement `repl`.  `repl` can be either a string or a callable;
# 1. If a string, backslash escapes in it are processed.
# 2. If a callable, it's passed the match object and must return a replacement string to be used.

# %%
def processTweet(tweet): #pre-processing
    #Convert to lower case
    tweet = tweet.lower()
    #remove emoticons
    tweet = re.sub(emoji.get_emoji_regexp(),'',tweet)
    #Convert www.* or https?://* to URL
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',tweet)
    #Convert @username to AT_USER
    tweet = re.sub('@[^\s]+','AT_USER',tweet)
    #Remove additional white spaces, single space only
    tweet = re.sub('[\s]+', ' ', tweet)
    #Replace #username with username
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)\
    #trim
    tweet = tweet.strip('\'"')
    return tweet

# %% [markdown]
# You might have noticed the regular expression used to replace "#username" with "username".
# What does `"r'\1'"`** mean?
#
# It indicates a **backreference** in regular expressions.
# `'\1'` means **replacing** it with the subtring matched by **the first group** in the pattern, i.e., '[^\s]+'.
# Instead of using a backreference with a sequence number, you can use named groups, such as
# ```python
#       tweet = re.sub(r'#(?P<name>[^\s]+)', r'\g<name>', tweet)
# ```
# Let's try the function on the tweet we have been using so far as follows:

# %%
print (tweet)
processTweet(tweet)
# Out:
# @HawthornFC Howz this?? 💪🏼 #PTV #metrotrains #hawthornalways https://t.co/LECNCiTcN5
# 'AT_USER howz this?? ptv metrotrains hawthornalways URL'

# %% [markdown]
# In order to generate a good word vector for a sentiment analysis algorithm,
# we need to **filter the tweet words that are not of interest**.
# These words may include **stop words**, words **with repeated letters**,
# words **not starting with an alphabet**, and so on.
# Let's start with handling repeating letters.
# If we set `'reduce_len'` to True, `TweetTokenizer` can automatically reduce the number of time a letter repeats in a single token.
#
# Here we show you how to do it with regular expressions.

# %% [markdown]
# `re.compile(pattern, flags=0)`

# %%
#look for 2 or more repetitions of character and replace with the character itself
def replaceTwoOrMore(s):
    pattern = re.compile(r"(.)\1{1,}", re.DOTALL)
    return pattern.sub(r"\1\1", s)

# %% [markdown]
# The pattern matches substrings that contain the same letter be repeated at least two times.
# The `re.DOTALL` flag tells python to make the ‘.’ special character match all characters, including newline characters.

# %%
print (replaceTwoOrMore('cooooool'))
print (replaceTwoOrMore('oooooooooops'))
print (replaceTwoOrMore('gooooood'))
print (replaceTwoOrMore('coooooold'))
# Out:
# cool
# oops
# good
# coold

# %% [markdown]
# As you can see, the `replaceTwoOrMore` function is **not perfect**. The words recovered by this function do not always have correct lexical forms, such as "coold".
#
# Mapping **"ill-formed" out-of-vocabulary words** to their standard lexical forms is known as **lexical normalization**, which is a very challenging research problem in natural language processing.
#
# It has similarities with **spell checking**, but differs in that ill-formedness in tweets for example is often **intentional due to the 140-characters limit**.
#
# If you would like to know more about lexical normalization, you should read the research paper on "[Lexical Normalisation of Short Text Messages: Makn Sens a #twitter](http://www.aclweb.org/anthology/P11-1038)" by Bo Han and Timothy Baldwin.
#
# Let's now move to removing stopwords from tweets. We will use the same stopword list used in the previous two chapters, and load and store all the stopwords in a Python set object.

# %%
stopwords = []
with open('./stopwords_en.txt') as f:
    stopwords = f.read().splitlines()
stopwords = set(stopwords)

# %% [markdown]
# We further remove punctuation such as comma, single/double quote, question marks at the start and end of each word. For example, "this??" will be replaced with "this", and remove words starting with non-alphabets, e.g., "124m" and "7.07am".
# Put all the code together, we derive the following function for extracting feature words from a tweet:

# %%
def getFeatureVector(tweet):
    featureVector = []
    #split tweet into a list of words
    words = tweet.split()
    for w in words:
        #replace two or more with two occurrences
        w = replaceTwoOrMore(w)
        #strip punctuation
        w = w.strip('\'"?,.')
        #check if the word starts with an alphabet
        val = re.search(r"^[a-zA-Z][a-zA-Z0-9]*$", w)
        #ignore if it is a stop word or a word starts with non-alphabetic
        if(w in stopwords or val is None):
            #ignore, go for the next
            continue
        else:
            #store it as featureVector
            featureVector.append(w.lower())
    return list(set(featureVector))

# %% [markdown]
# Let's look at the feature words extracted for the tweets.

# %%
for t in tweets_text:
    print (t)
    print (getFeatureVector(processTweet(t)), "\n")
# Out:
# .@metrotrains, another day another diverted late city loop train from Caulfield straight to Flinders! @9NewsMelb! #cheers
# ['caulfield', 'late', 'train', 'straight', 'cheers', 'city', 'diverted', 'loop', 'day']
#
# @metrotrains 12 mins delay YET AGAIN on Flinders service in Belgrave/Lilydale line which initially was supposed to be 5 mins.
# ['flinders', 'service', 'initially', 'line', 'mins', 'supposed', 'delay']
#
# @danielbowen @VLine @jimbob_prod @metrotrains LMAO but a skyrail will make the trains run more efficiently! Oh deary me!
# ['lmao', 'run', 'deary', 'trains', 'skyrail', 'make']
#
# @metrotrains not sure if guys who run Melbourne train services have "shame" in their dictionary. Sick of apologizing 2 my boss 4 being late.
# ['train', 'run', 'late', 'shame', 'apologizing', 'sick', 'dictionary', 'services', 'melbourne', 'boss', 'guys']
#
# @metrotrains and we're away 10 min late
# ['late', 'min']
#
# Amateur hr by @metrotrains  Flinders st, 9:49 Southern cross train on Platform 1 has no driver.
# ['train', 'southern', 'hr', 'flinders', 'cross', 'driver', 'platform', 'amateur', 'st']
#
# @danielbowen @jimbob_prod @metrotrains @VLine Not the first time its happened. I can recall them doing on at Narre a good decade ago.
# ['ago', 'happened', 'good', 'decade', 'narre', 'time', 'recall']
#
# @metrotrains hope our train driver's day gets better after his huge spray at Richmond for not keeping the doorways clear. #notcool #angryman
# ['hope', 'notcool', 'clear', 'train', 'angryman', 'spray', 'richmond', 'keeping', 'doorways', 'day', 'huge']
#
# @metrotrains can you ever have trains running on time?
# ['trains', 'time', 'running']
#
# @esayche Thanks for your feedback! Just do what everyone else does and vandalise a train. #MetroTrains
# ['metrotrains', 'vandalise', 'train']
#
# .@metrotrains should subsidise this for Lilydale passengers today https://t.co/BrouHk6tDa
# ['subsidise', 'lilydale', 'passengers', 'url', 'today']
#
# @littlesandieago Thanks for your feedback! You’re most welcome. #MetroTrains
# ['metrotrains']
#
# @metrotrains Thnx for delivering an express train. Because it wasn't so express, I missed the connecting train
#
# And now I'm late for work.
# ['train', 'late', 'work', 'express', 'missed', 'delivering', 'connecting', 'thnx']
#
# @metrotrains very poor service blgrave line. This is becoming a regular affair!! And yet you meet 94% targets!!
# ['service', 'meet', 'line', 'regular', 'poor', 'blgrave']
#
# @metrotrains you'd think you'd be able to respond to a simple tweet
# ['tweet', 'respond', 'simple']
#
# RT @metrotrains: Werribee line delays: Please check https://t.co/fE9E9HQ0pA for information.
# ['rt', 'check', 'url', 'line', 'information', 'werribee']
#
# RT @metrotrains: Cranbourne/Pakenham line delays: Please check https://t.co/fE9E9Hyp10 for information.
# ['rt', 'check', 'url', 'line', 'information']
#
# @metrotrains @ptv_official @DanielAndrewsMP there is no point in ordering for new trains if the current infrastructure cannot handle it !
# ['point', 'ordering', 'infrastructure', 'handle', 'trains', 'current']
#
# RT @fakemetrotrains: Good morning Melbourne! It’s St Patrick’s Day, and to get into the spirit of things all our train drivers today will b…
# ['morning', 'rt', 'spirit', 'things', 'train', 'drivers', 'good', 'st', 'day', 'today']
#
# @metrotrains is without a doubt is the worst PT system I've experienced. Operationally that is. https://t.co/WDtuT2lyjY
# ['doubt', 'experienced', 'url', 'system', 'worst', 'pt', 'operationally']
#
# @ptv_official @metrotrains are worst then connex . Delayed trains , longer travel time, skipping stations, longer wait approaching flinders
# ['stations', 'approaching', 'flinders', 'travel', 'connex', 'longer', 'delayed', 'worst', 'wait', 'trains', 'time', 'skipping']
#
# @metrotrains @CityLinkMelb to cost @DanielAndrewsMP the next election! Total mismanagement and chaos caused by Labour!
# ['total', 'cost', 'mismanagement', 'caused', 'chaos']
#
# RT @fakemetrotrains: Good morning Melbourne! It’s St Patrick’s Day, and to get into the spirit of things all our train drivers today will b…
# ['morning', 'rt', 'spirit', 'things', 'train', 'drivers', 'good', 'st', 'day', 'today']
#
# RT @LissanneOliver: Sweet @metrotrains blokes offering hot drinks and biscuits this morning at Dennis station. Lovely!! @NoHeDaily https://…
# ['morning', 'rt', 'hot', 'biscuits', 'url', 'drinks', 'sweet', 'dennis', 'station', 'offering', 'blokes']
#
# Sweet @metrotrains blokes offering hot drinks and biscuits this morning at Dennis station. Lovely!! @NoHeDaily https://t.co/0tSqYN8Mur
# ['morning', 'biscuits', 'hot', 'url', 'drinks', 'sweet', 'dennis', 'station', 'offering', 'blokes']
#
# @jimbob_prod @metrotrains Seems like odd place for driver change. Let's see if @vline can explain.
# ['place', 'change', 'explain', 'driver', 'odd']
#
# @othiSA Thanks for your feedback! We’re so scared. Totes just shat our pants in fear. #MetroTrains
# ['scared', 'totes', 'shat', 'metrotrains', 'pants', 'fear']
#
# @metrotrains 3/3 trains for me this week skipping the loop. That’s 7 times in 2 wks. Either I’m extremely unlucky or your stats are fiction
# ['unlucky', 'stats', 'extremely', 'week', 'wks', 'loop', 'times', 'trains', 'fiction', 'skipping']
#
# Train is going direct to flinders and skipping the city loop for the third day in a row. Get it together @metrotrains!
# ['train', 'flinders', 'city', 'row', 'loop', 'skipping', 'day', 'direct']
#
# @metrotrains previously connex used to get from huntingdale to city in 25 mins and now u take more than 35 mins
# ['connex', 'city', 'mins', 'previously', 'huntingdale']
#
# @metrotrains why not u run a train as per schedule - ridiculous with the schedule being altered every day - same train ! Pick up ur game
# ['game', 'train', 'run', 'altered', 'schedule', 'pick', 'ur', 'ridiculous', 'day']
#
# A touch of red did suffuse the Line Information page this morning, reflecting the morning sky. #MetroTrains 15:91 https://t.co/6DI8rFrP2u
# ['morning', 'red', 'reflecting', 'sky', 'url', 'line', 'page', 'touch', 'information', 'suffuse', 'metrotrains']
#
# RT @fakemetrotrains: Good morning Melbourne! It’s St Patrick’s Day, and to get into the spirit of things all our train drivers today will b…
# ['morning', 'rt', 'spirit', 'things', 'train', 'drivers', 'good', 'st', 'day', 'today']
#
# RT @fakemetrotrains: Good morning Melbourne! It’s St Patrick’s Day, and to get into the spirit of things all our train drivers today will b…
# ['morning', 'rt', 'spirit', 'things', 'train', 'drivers', 'good', 'st', 'day', 'today']
#
# RT @metrotrains: Werribee line delays: Please check https://t.co/fE9E9HQ0pA for information.
# ['rt', 'check', 'url', 'line', 'information', 'werribee']
#
# @metrotrains great idea free coffees at random stations, except Q of school kids getting theirs. Not one adult @mentone.
# ['great', 'free', 'stations', 'random', 'coffees', 'school', 'adult', 'kids', 'idea']
#
# RT @fakemetrotrains: Good morning Melbourne! It’s St Patrick’s Day, and to get into the spirit of things all our train drivers today will b…
# ['morning', 'rt', 'spirit', 'things', 'train', 'drivers', 'good', 'st', 'day', 'today']
#
# @mmmhotbreakfast surely on a massive weekend in melbourne we need the trains actually running! @metrotrains what a fail in service!! #fail
# ['weekend', 'massive', 'fail', 'trains', 'melbourne', 'surely']
#
# Hey @metrotrains stickers on handrails to show there r for hands not butts would b g8 as ppl just sit on them
# ['hands', 'handrails', 'hey', 'show', 'butts', 'stickers', 'ppl', 'sit', 'g8']
#
# Just another city loop service diverted to Flinders Street! 3rd in two weeks! .@metrotrains is useless! .@JacintaAllanMP .@DanielAndrewsMP
# ['flinders', 'service', 'city', 'diverted', 'loop']
#
# @metrotrains Carriage 97M on the South Morang line inbound is like an oven.
# ['line', 'south', 'oven', 'carriage', 'morang', 'inbound']
#
# @metrotrains When you say 2-3mins late, do you mean arriving or departing?
# ['departing', 'arriving', 'late']
#
# @metrotrains @tw8_69 @JacintaAllanMP @3AW693 it's a joke!!! You expect us to pay you but do we get paid for being late to work? Idiots
# ['late', 'idiots', 'paid', 'work', 'expect', 'pay']
#
# The Lord V/Line did seek to subvert the services of the Lord Metro, to the dismay of all. #Vline #MetroTrains 15:90 https://t.co/bsNP4OuCEu
# ['metro', 'lord', 'url', 'subvert', 'metrotrains', 'seek', 'services', 'dismay', 'vline']
#
# @metrotrains consistently late since last week and still their performance is above benchmark
# ['late', 'benchmark', 'week', 'performance', 'consistently']
#
# @metrotrains why are the trains so cold? Aircon always on full power.
# ['cold', 'full', 'power', 'aircon', 'trains']
#
# RT @JoshiBiren: @metrotrains please please turn on AC on train to city . Just reached at Carnegie
# ['carnegie', 'train', 'rt', 'city', 'reached', 'ac', 'turn']
#
# @metrotrains @JacintaAllanMP @3AW693 BOOM right on cue, this train will run direct to Flinders Street' who is regulating these muppets?
# ['train', 'run', 'flinders', 'muppets', 'street', 'boom', 'regulating', 'direct', 'cue']
#
# @metrotrains please please turn on AC on train to city . Just reached at Carnegie
# ['carnegie', 'train', 'city', 'reached', 'ac', 'turn']
#
# @metrotrains could have told us 30 mins ago since that's how long this train has been going at snails pace
# ['ago', 'train', 'told', 'pace', 'mins', 'snails', 'long']
#
# @CaitlinSyrett @metrotrains And then comes a crush loaded 'service' for Carnegie.
# ['crush', 'carnegie', 'service', 'loaded']
#
# You cannot push anyone up the Station steps unless he is willing to travel on a train. #MetroTrains 15:89
# ['train', 'push', 'travel', 'station', 'metrotrains', 'steps']
#
# The secret of happiness is to count your #myki balance while others are adding up their delays and cancellations. #MetroTrains 15:88
# ['delays', 'happiness', 'secret', 'myki', 'cancellations', 'metrotrains', 'balance', 'count', 'adding']
#
# @metrotrains skipping the loop 3 days in a row is not good enough. The ombudsman will be hearing from me.
# ['hearing', 'days', 'ombudsman', 'good', 'row', 'loop', 'skipping']
#
# RT @CaitlinSyrett: 3-4 minute delays onthe Pakenham line don't bother me @metrotrains, but ordering half-empty trains to not stop at my sta…
# ['delays', 'stop', 'minute', 'rt', 'ordering', 'line', 'pakenham', 'trains', 'bother', 'onthe']
#
# Many hopes were raised that t' ill passenger was successfully attended, &amp; other journeys resumed. #MetroTrains 15:87 https://t.co/V9gF6uTblN
# ['passenger', 'journeys', 'url', 'ill', 'hopes', 'successfully', 'resumed', 'raised', 'metrotrains', 'attended']
#
# @metrotrains Yet another day of delays on the Pak/Cran lines. It really isnt good enough.
# ['isnt', 'delays', 'lines', 'good', 'day']
#
# 3-4 minute delays onthe Pakenham line don't bother me @metrotrains, but ordering half-empty trains to not stop at my station does.
# ['delays', 'stop', 'minute', 'ordering', 'line', 'pakenham', 'station', 'trains', 'bother', 'onthe']
#
# @metrotrains disgusting service. Not a single day i have travelled on this line had no issues at all. A
# ['travelled', 'service', 'line', 'issues', 'disgusting', 'single', 'day']
#
# RT @swishtter: @metrotrains how do trains disappear on the way to Caulfield platform 3 #farce #wheredidtheygo #hopeless
# ['caulfield', 'hopeless', 'rt', 'farce', 'platform', 'trains', 'wheredidtheygo', 'disappear']
#
# @metrotrains how do we sue vline for this nonsense?
# ['sue', 'vline', 'nonsense']
#
# @metrotrains how can an train just skip auburn station about 60 passengers stranded and late to work/school?
# ['auburn', 'train', 'late', 'passengers', 'station', 'skip', 'stranded']
#
# Cranbourne/Pakenham line delays: Please check https://t.co/fE9E9Hyp10 for information.
# ['url', 'information', 'line', 'check']
#
# Please tell the @metrotrains staff at Caulfield to stop being so condescending, moving down the train/platform will not solve this issue
# ['caulfield', 'stop', 'solve', 'condescending', 'issue', 'moving', 'staff']
#
# How much money a month to I pay @metrotrains to constantly delay, inconvenience and frustrate me?
# ['month', 'money', 'inconvenience', 'constantly', 'frustrate', 'delay', 'pay']
#
# Good morning Melbourne! It’s St Patrick’s Day, and to get into the spirit of things all our train drivers today will be drunk. #MetroTrains
# ['morning', 'spirit', 'things', 'train', 'drivers', 'good', 'metrotrains', 'drunk', 'st', 'day', 'today']
#
# 18 minutes at Caulfield station, platform is overcrowded and we're advised the next 2 services won't be city loop. Thanks  @metrotrains
# ['caulfield', 'advised', 'minutes', 'city', 'station', 'loop', 'overcrowded', 'platform', 'services']
#
# Werribee line delays: Please check https://t.co/fE9E9HQ0pA for information.
# ['check', 'url', 'line', 'information', 'werribee']
#
# Normally in 7am, slept in, the 8am Flinders st people traffic is hectic .@metrotrains bring on new @VicGovAu station! Good ppl watching
# ['traffic', 'flinders', 'hectic', 'good', 'bring', 'watching', 'people', 'st', 'ppl', 'slept']
#
# @metrotrains sick &amp; tired of your pathetic service. So many staff at station, but no one knows what's going on. Staff Service Reliability???
# ['tired', 'reliability', 'service', 'sick', 'station', 'pathetic', 'staff']
#
# @metrotrains how do trains disappear on the way to Caulfield platform 3 #farce #wheredidtheygo #hopeless
# ['caulfield', 'hopeless', 'farce', 'platform', 'trains', 'wheredidtheygo', 'disappear']
#
# Although freely admit that desire for free coffee overruled principles @metrotrains. #thatcheap https://t.co/50uv899DpX
# ['thatcheap', 'url', 'principles', 'overruled', 'freely', 'desire', 'coffee', 'admit', 'free']
#
# @metrotrains @JacintaAllanMP @3AW693 every train I have caught into the City this week diverted straight to Flinders St. #shambles
# ['train', 'straight', 'flinders', 'shambles', 'city', 'caught', 'week', 'diverted', 'st']
#
# Hmm... Proposed changes must be bad @metrotrains #melbourne https://t.co/ubLLwGAxRD
# ['hmm', 'bad', 'proposed', 'url', 'melbourne']
#
# @metrotrains they where here handing out pamphlets and coffees at 7 yum
# ['pamphlets', 'handing', 'yum', 'coffees']
#
# @metrotrains @danielbowen nett result is metro service fucked for 2 hours.
# ['fucked', 'metro', 'service', 'result', 'hours', 'nett']
#
# @metrotrains @danielbowen this vline stopped all Metro serv on pak line for 10 mins to do a driver change. https://t.co/oXTdwgFUYM
# ['metro', 'pak', 'url', 'line', 'mins', 'change', 'stopped', 'driver', 'serv', 'vline']
#
# @imarockstaa @ptv_official We'll pass on your suggestion to the area concerned. We value your feedback. Thanks.
# ['feedback', 'pass', 'area', 'concerned', 'suggestion']
#
# @metrotrains where are the Werribee replacement busses?
# ['busses', 'werribee', 'replacement']
#
# @muffanface We have an ill passenger at Laverton that is delaying services, we do expect movement soon, please listen for announcements.
# ['passenger', 'laverton', 'movement', 'delaying', 'ill', 'expect', 'announcements', 'listen', 'services']
#
# @Boga1972 Yes Yasar, there are two services running express Caulfield-South Yarra at 7.28 &amp; 7.34 from platform #2 between these times.
# ['yasar', 'yarra', 'express', 'platform', 'times', 'services', 'running']
#
# @metrotrains why is the train packed by Berwick? Standing room only seems to be a continuing problem on the PakenJam line
# ['train', 'problem', 'line', 'pakenjam', 'berwick', 'continuing', 'standing', 'room', 'packed']
#
# @metrotrains #metrotrains been advised no trains in or out of Altona until further notice.  Where are our replacement bus's then??
# ['advised', 'trains', 'notice', 'altona', 'metrotrains', 'replacement']
#
# @metrotrains thankyou!
# []
#
# @metrotrains @ptv_official how about 2 additional readers to bring it to 4 in total. Approx 90 people and 2 readers is a poor ratio
# ['readers', 'approx', 'total', 'bring', 'ratio', 'people', 'additional', 'poor']
#
# @heytherehoran_ This link will help with info: https://t.co/DqmUvhBfTx this Friday is ok for trains.
# ['trains', 'url', 'link', 'friday']
#
# @metrotrains all talk no action. I've raised this issue 6 times in 2 years. Nothing done. Perhaps some pics of the chaos, newspapers?
# ['action', 'talk', 'issue', 'chaos', 'newspapers', 'raised', 'times', 'pics', 'years']
#
# @metrotrains is there an express from Caulfield station between 7.25 - 7.40 to city ?
# ['caulfield', 'station', 'city', 'express']
#
# @imarockstaa Thanks for the info, we have advised @ptv_official to get the readers checked, sorry for the issue.
# ['advised', 'info', 'readers', 'checked', 'issue']
#
# Our staff will be at Mentone and Mordialloc stations till 9am today to provide   info on changes due to level crossing works.
# ['stations', 'mentone', 'info', 'crossing', 'level', 'mordialloc', 'provide', 'works', 'till', 'staff', 'due', 'today']
#
# @imarockstaa We'll have a check on this device &amp; get it fixed as soon as possible. Sorry for this inconvenience.
# ['inconvenience', 'device', 'fixed', 'check']
#
# @metrotrains I'm so angry with Metro today. 90 people trying to use 1 myki reader. Another reader working sometimes. Platform 1 Craigieburn
# ['craigieburn', 'metro', 'myki', 'reader', 'working', 'people', 'platform', 'angry', 'today']
#
# @metrotrains are these all day on Friday or what time?
# ['time', 'day', 'friday']
#
# @metrotrains this overcrowding is completely unacceptable, leaving commuters stuck at Kensington #craigieburnline https://t.co/iS53vjRlwa
# ['completely', 'overcrowding', 'kensington', 'url', 'unacceptable', 'craigieburnline', 'commuters', 'stuck', 'leaving']
#
# @braddodemond Hi Brad, thanks for your good thoughts, have a good day.
# ['brad', 'day', 'thoughts', 'good']
#
# @metrotrains who ever was driving 6:49 train box hill to city today was incredible! His announcements and jokes were hilarious! Thanks metro
# ['jokes', 'train', 'metro', 'city', 'hill', 'announcements', 'box', 'driving', 'today']
#
# @tw8_69 @JacintaAllanMP @3AW693 Hi, we currently have delays up to 5 mins to select services after a late V/line train has caused congestion
# ['delays', 'late', 'train', 'select', 'mins', 'congestion', 'services', 'caused']
#
# @metrotrains @JacintaAllanMP @3AW693 3rd day in row that there have been delays on the Pakenham line! What are we paying for???
# ['delays', 'paying', 'pakenham', 'row', 'day']
#
# @generalp Hi, unfortunately the train has a fault and was unable to come into service from the sidings, sorry for the cancellation.
# ['train', 'unable', 'service', 'sidings', 'fault', 'cancellation']
#
# Previous train cancelled yet current train late. How do you work that shit out @metrotrains ?
# ['previous', 'late', 'train', 'work', 'cancelled', 'shit', 'current']
#
# Jesus fucking Christ @metrotrains what's the bullshit excuses today? Fucking useless cunts.
# ['useless', 'cunts', 'fucking', 'bullshit', 'excuses', 'christ', 'today', 'jesus']
#
# @metrotrains this causes extreme overcrowding stop routinely cancelling peak services on the Craigieburn line https://t.co/3uOx1TF4no
# ['peak', 'overcrowding', 'stop', 'craigieburn', 'url', 'line', 'extreme', 'routinely', 'cancelling', 'services']
#
# @cadland @metrotrains that requires the state gov't to properly invest the correct amount of money to get it there
# ['money', 'invest', 'properly', 'state', 'correct', 'amount', 'requires']
#
# RT @danielbowen: Slow #Myki readers at Caulfield are constantly overwhelmed by the numbers of people changing platforms. #MetroTrains https…
# ['caulfield', 'platforms', 'readers', 'rt', 'overwhelmed', 'numbers', 'constantly', 'myki', 'people', 'metrotrains', 'changing', 'slow']
#
# @smiddygate Hi Michael, thanks for the photo, we have maintenance staff on the way, thanks again.
# ['maintenance', 'photo', 'michael', 'staff']
#
# @smiddygate @metrotrains Just a little bit of a safety issue. Here's hoping it's fixed before the morning peak!
# ['morning', 'fixed', 'issue', 'hoping', 'bit', 'safety']
#
# .@metrotrains pedestrian gate at Yarraville not closing properly https://t.co/4DvUAaz7W2
# ['pedestrian', 'closing', 'properly', 'url', 'yarraville', 'gate']
#
# @ibuildrockets @metrotrains @vine What a jerk!
# []
#
# I'm at Southern Cross Station - @metrotrains in Melbourne, VIC https://t.co/oseAsyV4VR
# ['vic', 'southern', 'url', 'cross', 'station', 'melbourne']
#
# @ynotds @yarra_campaign @metrotrains @VLine @VicTrack_Vic What, and make someone accountable?  What about all those bonuses?
# ['make', 'bonuses', 'accountable']
#
# RT @ynotds: &lt; Time to merge @metrotrains @VLine AOs, PSOs, @VicTrack_Vic et al back into revitalized Victorian Railways. End bullshit excus…
# ['end', 'al', 'rt', 'merge', 'railways', 'psos', 'back', 'revitalized', 'aos', 'time', 'victorian', 'bullshit']
#
# @the_panicwave @metrotrains surrey hills! had to work pretty hard to take my grumpy pants off! I can only hope @metrotrains learn from this
# ['hope', 'pretty', 'hard', 'learn', 'grumpy', 'work', 'surrey', 'pants']
#
# How happy are people who don’t follow the advice of the freeloader. #MetroTrains 15:86
# ['follow', 'happy', 'metrotrains', 'advice', 'people', 'freeloader']
#
# @B_Hope_ @metrotrains what? Where did you end up?
# ['end']
#
# @metrotrains every night at like 1am?! 😂 scares me to death. Theres a brand new apartment block close by. Could they stop sounding the horn?
# ['stop', 'brand', 'horn', 'block', 'sounding', 'night', 'death', 'apartment', 'scares', 'close']
#
# RT @fakemetrotrains: @rodstraks Thanks for your feedback! Shit’s fucked. #MetroTrains
# ['metrotrains', 'fucked', 'rt']
#
# @sirianni42 @metrotrains are we getting the Sydney style double deckers?
# ['deckers', 'sydney', 'style', 'double']
#
# @metrotrains letting us down again #noidea
# ['noidea', 'letting']
#
# Another peak hour Sandringham train cancellation. Thanks @metrotrains
# ['peak', 'train', 'hour', 'sandringham', 'cancellation']
#
# OMFG. Finally.. after 75 mins on this train .. a seat, at Hallam. You're killing me @metrotrains @ptv_official #longesttripever
# ['killing', 'train', 'finally', 'mins', 'longesttripever', 'omfg', 'seat', 'hallam']
#
# How can @metrotrains fine someone for not paying for a service, but @metrotrains gets away with not providing a service? @DanielAndrewsMP
# ['service', 'paying', 'fine', 'providing']
#
# I'm at Carrum Station - @metrotrains in Carrum, VIC https://t.co/NfDfnILCnd
# ['vic', 'carrum', 'station', 'url']
#
# If I jump on a Cranbourne train, I expect it to terminate at Cranbourne @metrotrains Dandenong is not Cranbourne
# ['train', 'jump', 'expect', 'terminate', 'dandenong', 'cranbourne']
#
# @metrotrains what's the story with the Craigieburn cancellations this week?
# ['week', 'story', 'craigieburn', 'cancellations']
#
# Had to put up with this on my @MetroTrains ride home tonight :( https://t.co/zhlXXsxKjF
# ['tonight', 'ride', 'url', 'home', 'put']
#
# I'm at Flinders Street Station - @metrotrains in Melbourne, VIC https://t.co/oMfOJZlcao
# ['vic', 'flinders', 'url', 'street', 'station', 'melbourne']
#
# @danielbowen why should people have to exit the station to change platforms? @ptv_official &amp; @metrotrains should be encouraging transfers
# ['platforms', 'transfers', 'encouraging', 'change', 'exit', 'station', 'people']
#
# Slow #Myki readers at Caulfield are constantly overwhelmed by the numbers of people changing platforms. #MetroTrains https://t.co/mHMrFjrbNC
# ['caulfield', 'platforms', 'readers', 'overwhelmed', 'numbers', 'constantly', 'url', 'myki', 'people', 'metrotrains', 'changing', 'slow']
#
# @ynotds Old school vertical integration required for @metrotrains @VLine @VicTrack_Vic ?
# ['school', 'vertical', 'integration', 'required']
#
# @metrotrains So I've missed my PT session because of train delays and am still charged for the session. I want a reimbursement.
# ['delays', 'charged', 'train', 'session', 'missed', 'pt', 'reimbursement']
#
# RT @ynotds: &lt; Time to merge @metrotrains @VLine AOs, PSOs, @VicTrack_Vic et al back into revitalized Victorian Railways. End bullshit excus…
# ['end', 'al', 'rt', 'merge', 'railways', 'psos', 'back', 'revitalized', 'aos', 'time', 'victorian', 'bullshit']
#
# For those of us living on the Cranbourne line, the train system is pretty disappointing. @metrotrains
# ['pretty', 'train', 'line', 'system', 'living', 'disappointing', 'cranbourne']
#
# @metrotrains how is not moving for 20 minutes a minor delay? Cranbourne Pakenham lines always rooted
# ['rooted', 'minutes', 'lines', 'moving', 'pakenham', 'cranbourne', 'minor', 'delay']
#
# @metrotrains also lets get the station name changed permanently to lemon meringue I'll pay for the new signs xx
# ['changed', 'signs', 'xx', 'lemon', 'permanently', 'station', 'meringue', 'lets', 'pay']
#
# @danielbowen @metrotrains Will do Daniel
# ['daniel']
#
# the driver of the 6:05 to south morang deserves a pay rise for calling it lemon meringue thanks @metrotrains
# ['deserves', 'rise', 'south', 'driver', 'calling', 'meringue', 'lemon', 'morang', 'pay']
#
# @PuntReturner Send a tweet to @metrotrains with the carriage number with the faulty PA.
# ['tweet', 'number', 'pa', 'faulty', 'send', 'carriage']
#
# Hey @metrotrains no point making an In train announcement about the train breaking down if the speakers in the carriages are broken -
# ['train', 'making', 'point', 'hey', 'speakers', 'carriages', 'announcement', 'breaking', 'broken']
#
# Thanks @metrotrains for changing the platform of my train at the last minute so I miss it completely #useless
# ['completely', 'train', 'minute', 'useless', 'platform', 'miss', 'changing']
#
# ...and yes I know the notice says Police Operation. That was the earlier problem. #MetroTrains #VLine
# ['police', 'problem', 'earlier', 'operation', 'notice', 'metrotrains', 'vline']
#
# OMG @metrotrains. You can't be serious with replacement buses on Lilydale/Belgrave lines on Grand Prix weekend. That's a joke, right??
# ['joke', 'grand', 'weekend', 'lines', 'omg', 'prix', 'buses', 'replacement']
#
# @metrotrains 20 minute gap from  5:50pm for trains to Hawthorn makes no sense. Fix it.
# ['fix', 'minute', 'gap', 'hawthorn', 'sense', 'makes', 'trains']
#
# Daaaaammnn @metrotrains, back at it again with the delays! #damn
# ['daammnn', 'damn', 'back']
#
# @metrotrains sthn cross, missed 5.56 FSS service, was my last train to get my 6.36 Keilor Plains bus, have to wait over 1/2hr for bus (2/2)
# ['train', 'service', 'cross', 'sthn', 'missed', 'plains', 'keilor', 'wait', 'bus', 'fss']
#
# @metrotrains next time u could let passengers know the train will change from watergardens to craigieburn before we get to FSS from (1/2)
# ['craigieburn', 'train', 'passengers', 'change', 'time', 'watergardens', 'fss']
#
# @metrotrains - Why is Notify a liar? My train is not on time to 5 minutes.
# ['train', 'minutes', 'liar', 'time', 'notify']
#
# Fix your useless system @metrotrains
# ['fix', 'system', 'useless']
#
# @nudge87 @metrotrains it sounds like it 🤓
# ['sounds']
#
# @SidebySide @metrotrains frustrated haha. Im an hour late.
# ['haha', 'late', 'frustrated', 'hour', 'im']
#
# @nudge87 @metrotrains tell them what you really think of them, don't hold back 😉😉
# ['hold', 'back']
#
# @metrotrains thanks I've submitted my enquiry
# ['enquiry', 'submitted']
#
# 8 min wait at caulfield for next Frankston bound train.... Definitely more than 1 train cancelled @metrotrains
# ['caulfield', 'train', 'min', 'wait', 'cancelled', 'frankston', 'bound']
#
# Fuck you @metrotrains fuck you in the ear hole #delays
# ['delays', 'fuck', 'hole', 'ear']
#
# Make that 3 full Sunbury/watergardens trains at north Melbourne station! #metrofail @metrotrains
# ['metrofail', 'trains', 'north', 'full', 'melbourne', 'make']
#
# Am I going to have to take the 4:55 PM Upfield from Coburg to make the 5:39PM Dandenong from Southern Cross in future?  @metrotrains
# ['future', 'southern', 'cross', 'coburg', 'pm', 'dandenong', 'make', 'upfield']
#
# How long till those high capacity trains are in operation? Sick of having to watch full trains go by! @metrotrains
# ['full', 'operation', 'sick', 'capacity', 'high', 'long', 'watch', 'trains', 'till']
#
# Asshole move @metrotrains when the doors of your train dont open, you'd think to stop at the next station right? Nope. 2 stops? Nope. 7?
# ['asshole', 'dont', 'stop', 'train', 'doors', 'nope', 'station', 'stops', 'open', 'move']
#
# It would be nice if I could make my connecting train once this year #metrotrains.  Thanks for ruining my day constantly
# ['nice', 'train', 'year', 'ruining', 'constantly', 'connecting', 'metrotrains', 'day', 'make']
#
# @metrotrains stuck on a train between north Melbourne and southern cross for nearly ten mins. No announcements. What's happening please?
# ['train', 'southern', 'happening', 'cross', 'mins', 'announcements', 'north', 'ten', 'melbourne', 'stuck']
#
# Aaand now @metrotrains  update the status 10 mins later....
# ['status', 'update', 'aand', 'mins']
#
# At least one train on Frankston line from city cancelled. @metrotrains lists service as "good" #normal
# ['train', 'normal', 'service', 'line', 'city', 'good', 'lists', 'cancelled', 'frankston']
#
# Thanks for nothing @metrotrains cancelling the 5.10 to Sunbury 10 mins after it was supposed to depart is pretty damn poor.
# ['depart', 'pretty', 'sunbury', 'damn', 'mins', 'supposed', 'cancelling', 'poor']
#
# @metrotrains the 512 Sunbury disappears, 5 minutes late, no info on why or if...
# ['info', 'late', 'minutes', 'sunbury', 'disappears']
#
# Metro 5.15pm Update: meh.
#
# #MetroTrains
# ['metrotrains', 'meh', 'metro']
#
# @metrotrains ticket machines at West Footscray won't let me purchase more than 1 week or 7 days as a Myki pass. Other options all greyed out
# ['west', 'days', 'greyed', 'options', 'myki', 'week', 'pass', 'machines', 'footscray', 'purchase', 'ticket']
#
# @metrotrains it is cold inside the westall bound train right now at Carnegie
# ['carnegie', 'cold', 'train', 'inside', 'westall', 'bound']
#
# On @metrotrains listening to couple debate the finer details of banana bread temp to butter consistency. Missing @mX right now.
# ['debate', 'bread', 'couple', 'details', 'finer', 'consistency', 'butter', 'missing', 'banana', 'temp', 'listening']
#
# @teganvictoria @metrotrains oh perfect 😒😒
# ['perfect']
#
# @sassypastry @metrotrains day I left work early specifically to make it to an appointment on time 😤
# ['early', 'work', 'specifically', 'appointment', 'left', 'time', 'day', 'make']
#
# @sassypastry @metrotrains I'm alive since it did indeed cancel, along with the next, on line that only runs every 20 mins in peak and on a
# ['peak', 'runs', 'line', 'mins', 'alive', 'cancel']
#
# @teganvictoria @metrotrains damn are you dead now or...
# ['damn', 'dead']
#
# The secret of happiness is the determination to be happy always, regardless of how many trains are cancelled. #MetroTrains 15:85
# ['happy', 'happiness', 'secret', 'metrotrains', 'determination', 'trains', 'cancelled']
#
# Notification from @metrotrains saying the 4.02 Upfield train is cancelled, aka the train I'm on and which is running, umm?
# ['train', 'umm', 'notification', 'cancelled', 'aka', 'running', 'upfield']
#
# I'm at Southern Cross Station - @metrotrains in Melbourne, VIC https://t.co/P9XENrEUrz
# ['vic', 'southern', 'url', 'cross', 'station', 'melbourne']
#
# Our greatest weakness lies in giving up. The most certain way to succeed is always to wait for just one more train. #MetroTrains 15:84
# ['weakness', 'lies', 'train', 'succeed', 'metrotrains', 'wait', 'greatest', 'giving']
#
# Any chance of a train running on time today? @metrotrains
# ['train', 'chance', 'time', 'today', 'running']
#
# @mymyki @metrotrains #Myki machine on platform 2 Hawthorn not allowing topup of myki. Myki reader on platform 2 not reading #metrotrains
# ['reading', 'myki', 'topup', 'allowing', 'hawthorn', 'reader', 'metrotrains', 'machine', 'platform']
#
# &lt; Time to merge @metrotrains @VLine AOs, PSOs, @VicTrack_Vic et al back into revitalized Victorian Railways. End bullshit excuses.
# ['end', 'al', 'merge', 'railways', 'psos', 'back', 'revitalized', 'aos', 'time', 'victorian', 'excuses', 'bullshit']
#
# Despite what @ptv_official said on Faine this morning @metrotrains pull 3:30 Keilor Park to Sunbury out at Watergardens for "Operatioal &gt;
# ['morning', 'sunbury', 'park', 'pull', 'keilor', 'operatioal', 'faine', 'watergardens']
#
# @metrotrains It'd be nice if metro drivers explained why there are delays. I don't mind waiting, but it'd be nice to know why.
# ['nice', 'delays', 'metro', 'drivers', 'waiting', 'explained', 'mind']
#
# @metrotrains what's the hold up on the Hurtsbridge line? Train due at 3:09. Two trains passed through (not in service). PID says 3:30 now..
# ['hurtsbridge', 'pid', 'train', 'line', 'passed', 'trains', 'hold', 'due']
#
# @metrotrains the train that just left from Caulfield FKN bound has its headlights on at the back for some reason. Shouldn't it be the red?
# ['caulfield', 'reason', 'fkn', 'train', 'headlights', 'red', 'back', 'left', 'bound']
#
# @Juz1093 @CptnTwinkleToes Hi Justin, we've received confirmation that all myki devices are in good working condition at South Yarra. Thanks.
# ['yarra', 'myki', 'justin', 'condition', 'good', 'south', 'devices', 'confirmation', 'received', 'working']
#
# @metrotrains @CptnTwinkleToes readers facing platform 6, if you're entering the paid area it's the second reader from the left.
# ['readers', 'paid', 'facing', 'reader', 'left', 'entering', 'platform', 'area']
#
# @CptnTwinkleToes @Donna_Lee_G @Juz1093 @ptv_official @JacintaAllanMP Hi James, can you tell us about the exact spot of this myki reader?
# ['spot', 'exact', 'myki', 'reader', 'james']
#
# what the heck is wrong with the pakenham line today @metrotrains
# ['heck', 'line', 'pakenham', 'wrong', 'today']
#
# @metrotrains worst services from Caulfield - consistently late. Currently 10 mins + late &amp; I'm going to miss my job interview. Thanks.
# ['caulfield', 'job', 'late', 'mins', 'worst', 'services', 'miss', 'consistently', 'interview']
#
# The moment you quit waiting is usually just before the next train arrives. #MetroTrains 15:83
# ['quit', 'train', 'waiting', 'moment', 'arrives', 'metrotrains']
#
# What is it w people &amp; loud music on trains? Twice today - I don't want to hear your music! #notpoliced #rant #gettingold @metrotrains
# ['rant', 'loud', 'hear', 'notpoliced', 'gettingold', 'people', 'trains', 'music', 'today']
#
# I'm at Camberwell Station - @metrotrains in Camberwell, Victoria https://t.co/AJ9KZstJH0
# ['camberwell', 'url', 'station', 'victoria']
#
# @metrotrains being in the loop truly does help.
# ['loop']
#
# @jforjustin It does restrict the ability to have more trains. Hope this at least helps to explain. 2/2
# ['hope', 'restrict', 'helps', 'ability', 'explain', 'trains']
#
# @jforjustin Hi Justin, unfortunately the line is a single track between Dandenong &amp; Cranbourne (with a crossing loop). 1/2
# ['track', 'cranbourne', 'line', 'justin', 'dandenong', 'single', 'crossing']
#
# @metrotrains why do you hate the Cranbourne line? Timetable a train every 20 min but really send one every 40. #metronotokay
# ['train', 'line', 'min', 'timetable', 'send', 'metronotokay', 'hate', 'cranbourne']
#
# @metrotrains Earth to Moon.....
# ['moon', 'earth']
#
# @Froggar5 @metrotrains Yeah, fun fun fun. How about having toilets at the train station? #madness
# ['toilets', 'train', 'fun', 'yeah', 'madness', 'station']
#
# Earth to Moon....
# #metrotrains
# ['moon', 'earth', 'metrotrains']
#
# @ToeGuitar @metrotrains people pee in there all the time, eliminating any possibility of it actually serving it's intended function.
# ['pee', 'possibility', 'serving', 'function', 'people', 'eliminating', 'time', 'intended']
#
# @jesssicaef Ok, thanks for the info/photo, we will get it checked/cleaned.
# []
#
# @metrotrains broken glass on the floor of the 9.58 south morang leaving from Parliament. Carriage no. is 124m 😊 https://t.co/4Peh3isFC6
# ['glass', 'url', 'south', 'floor', 'parliament', 'carriage', 'morang', 'broken', 'leaving']
#
# @missaliciao Hi Alicia, we suggest the following link: https://t.co/qMaHtdrwqY be completed for a more detailed response. Hope this helps.
# ['hope', 'alicia', 'url', 'detailed', 'response', 'helps', 'suggest', 'completed']
#
# Balls in your court to answer this @metrotrains
# ['answer', 'balls', 'court']
#
# @metrotrains #myki MYKI your system is just the worst!!!!! Just terrible...
# ['terrible', 'myki', 'system']
#
# @Dave_Zammit Hi Dave, sorry for your issue, can you give us the station/platform so we can get @ptv_official to check the machine.
# ['dave', 'check', 'issue', 'give', 'machine']
#
# @itsachipndip , you must be on the train platform 4? at Burnley, sorry for delays. 2/2
# ['platform', 'burnley', 'delays', 'train']
#
# @itsachipndip Hi Sarah, unfortunately we have a track fault, we just updated the metroNotify app. 1/2
# ['updated', 'sarah', 'track', 'app', 'metronotify', 'fault']
#
# our train broke? or the track broke?? either way we had to get off at a station at which we weren't even supposed to stop @metrotrains
# ['stop', 'train', 'track', 'supposed', 'station', 'broke']
#
# When you miss your train that you were 5 mins early for because the miki top up isn't working properly.. Yeah thanks @metrotrains
# ['miki', 'train', 'early', 'top', 'properly', 'yeah', 'mins', 'miss', 'working']
#
# "Burnley's got a bit of a problem, so we're going to sit here for about 10 minutes."
#
# at least the driver's enjoying himself @metrotrains
# ['problem', 'minutes', 'bit', 'enjoying', 'sit']
#
# RT @fakemetrotrains: Solutions cost money. Excuses are free. #MetroTrains
#
# RT @RLGod: @metrotrains @ptv_official Solutions, not excuses. I…
# ['solutions', 'money', 'rt', 'cost', 'metrotrains', 'excuses', 'free']
#
# @missaliciao @metrotrains Hi Alicia, again, Metro controls the signalling in the area. We operate under their instructions in the area.
# ['signalling', 'metro', 'alicia', 'operate', 'instructions', 'area', 'controls']
#
# @metrotrains thank you!
# []
#
# @VLine @metrotrains ok but why are the trains all of a sudden late and holding up the morning rush?
# ['morning', 'rush', 'late', 'holding', 'trains', 'sudden']
#
# @Azzmang Hi Aaron, the driver has already reported this fault on inspection. This will be fixed shortly. Thanks for your feedback and pic.
# ['reported', 'shortly', 'fixed', 'feedback', 'pic', 'aaron', 'fault', 'driver', 'inspection']
#
# .@metrotrains, stop diverting already late city loop trains from Caulfield straight to Flinders daily so you hit your KPI's! @9NewsMelb
# ['caulfield', 'diverting', 'daily', 'stop', 'late', 'straight', 'flinders', 'trains', 'city', 'hit', 'loop']
#
# And how about mopping up the wee left in the corner of the little waiting building? @metrotrains eish.
# ['mopping', 'waiting', 'eish', 'left', 'corner', 'wee', 'building']
#
# @ToeGuitar Thanks Lachlan for your feedback. We'll pass on the message to those concerned for necessary rectification.
# ['message', 'feedback', 'lachlan', 'pass', 'concerned', 'rectification']
#
# @metrotrains this is the train at noble park station at at 9:07 or so. Just letting you know the lights are out 😊 https://t.co/krTahmhE1l
# ['train', 'lights', 'url', 'noble', 'park', 'station', 'letting']
#
# Like this thing @metrotrains yuk https://t.co/yT9dB0aJYQ
# ['thing', 'yuk', 'url']
#
# Hey @metrotrains could someone please clean out the grates at ringwood east station? They've been smelling nasty for months.
# ['ringwood', 'grates', 'smelling', 'hey', 'months', 'clean', 'nasty', 'station', 'east']
#
# @metrotrains I think there's a better chance of hell freezing over than you running a service on time.... 👎🏻💩
# ['service', 'chance', 'freezing', 'time', 'hell', 'running']
#
# RT @fakemetrotrains: Solutions cost money. Excuses are free. #MetroTrains
#
# RT @RLGod: @metrotrains @ptv_official Solutions, not excuses. I…
# ['solutions', 'money', 'rt', 'cost', 'metrotrains', 'excuses', 'free']
#
# @metrotrains altered services 2 days in a row. why can't you cope with the city loop?
# ['days', 'altered', 'city', 'cope', 'row', 'loop', 'services']
#
# Who picks the music at Parliament Station @metrotrains? Digging Jessie's Girl on the way to work!
# ['picks', 'parliament', 'station', 'girl', 'digging', 'music']
#
# @jpoc_19 Thanks for your feedback! We don’t allow them. Cyclists are selfish cunts who think of no one but themselves. #MetroTrains
# ['cyclists', 'cunts', 'selfish', 'metrotrains']
#
# @metrotrains maybe, but they usually fly by fast and not stop. Since then 2 more have flown past, still sitting here waiting.
# ['fly', 'stop', 'waiting', 'past', 'sitting', 'flown', 'fast']
#
# @rodstraks Thanks for your feedback! Shit’s fucked. #MetroTrains
# ['metrotrains', 'fucked']
#
# @bazscott Baz, this was a scheduled express service from Williamstown, which would not stop at South Kensington.
# ['scheduled', 'stop', 'kensington', 'williamstown', 'service', 'express', 'south', 'baz']
#
# @oferzelig Thanks for your feedback! This won’t be accepted as a valid excuse. Fines will be issued. #MetroTrains
# ['excuse', 'valid', 'fines', 'issued', 'metrotrains', 'accepted']
#
# Solutions cost money. Excuses are free. #MetroTrains
#
# RT @RLGod: @metrotrains @ptv_official Solutions, not excuses. It can be done
# ['solutions', 'money', 'rt', 'cost', 'metrotrains', 'excuses', 'free']
#
# @metrotrains at South Kensington heading to the city. Train was on time at 0901
# ['kensington', 'train', 'city', 'south', 'heading', 'time']
#
# @missaliciao @metrotrains Hi Alicia, Metro controls the signalling in that area. So I believe we run though there on their decision.
# ['signalling', 'metro', 'run', 'alicia', 'decision', 'area', 'controls']
#
# @bazscott Where were you waiting? Travelling in which direction and time please.
# ['travelling', 'waiting', 'direction', 'time']
#
# Good work @metrotrains train that just pulled up at the station, didn’t open doors, headed off again
# ['train', 'open', 'work', 'doors', 'good', 'headed', 'station', 'pulled']
#
# Really @metrotrains? Really?🖕🏼
# []
#
# @metrotrains a huge thanks to Andrew at FSS lost property for the callback and very friendly service...
# ['service', 'andrew', 'callback', 'lost', 'property', 'huge', 'friendly', 'fss']
#
# @perrynfowler This is due to a power failure. The information has been passed on to those concerned. Thanks.
# ['power', 'information', 'concerned', 'passed', 'failure', 'due']
#
# @rodstraks Ok, thanks for the additional info and again sorry for any delays. We will check why no announcements.
# ['delays', 'info', 'check', 'announcements', 'additional']
#
# @metrotrains all myki readers at elsternwick are stuck like this https://t.co/bqb0dRdx07
# ['readers', 'url', 'myki', 'elsternwick', 'stuck']
#
# @_MLeighW No worries Megan. This power failure has been reported. Our guys at destination are aware of it. Sorry again for the inconvenience
# ['reported', 'power', 'inconvenience', 'aware', 'destination', 'worries', 'megan', 'failure', 'guys']
#
# @metrotrains no announcements made on the station PA.
# ['station', 'made', 'announcements', 'pa']
#
# @rodstraks not the 8:41am from Cranbourne as advertised, we are checking why  wrong info was posted, did station announcements get made? 2/2
# ['advertised', 'info', 'posted', 'announcements', 'made', 'checking', 'station', 'cranbourne', 'wrong']
#
# @metrotrains yeah all good now. Thanks for following it up. Just got the proper notification now.
# ['yeah', 'proper', 'notification', 'good']
#
# Not a good look by @Copperfieldco with their students sitting on @metrotrains seats and full fare paying patrons standing #backinmyday
# ['students', 'seats', 'backinmyday', 'sitting', 'fare', 'good', 'paying', 'standing', 'full', 'patrons']
#
# @rodstraks Hi again Rod, you should now be on a train, the wrong info was sent to the app. 8:21am from Cranbourne started from Dandenong 1/2
# ['info', 'train', 'app', 'rod', 'started', 'dandenong', 'cranbourne', 'wrong']
#
# @oferzelig Thanks for the information. The Authorised Officers are already aware of this power failure.
# ['authorised', 'power', 'aware', 'information', 'officers', 'failure']
#
# @metrotrains @_MLeighW thanks. There seemed to be about 30 of us at the station who couldnt scan on
# ['scan', 'couldnt', 'station']
#
# @_MLeighW If it is the case, he/she would have already advised the Authorised Officers of this fault.
# ['authorised', 'advised', 'fault', 'officers', 'case']
#
# No power at Elsternwick station, can't touch on. Everyone taking photos of Myki devices - they know officers will nail them. @metrotrains
# ['power', 'photos', 'taking', 'myki', 'nail', 'elsternwick', 'touch', 'devices', 'officers', 'station']
#
# @metrotrains just 20 minutes late. No worries m
# ['late', 'worries', 'minutes']
#
# @metrotrains if ur going 2 inconvenience us by going straight to flinders then actually go there,dont stop right b4 the station 4 now 10mins
# ['stop', 'straight', 'flinders', 'inconvenience', 'b4', 'ur', 'station']
#
# @metrotrains elsterwick station myki readers not working. Station worker told us we wont get fined.... confirm?
# ['fined', 'readers', 'told', 'confirm', 'wont', 'myki', 'worker', 'elsterwick', 'station', 'working']
#
# @metrotrains why don't AM express svcs to Craigieburn stop @ business hub Moonee Ponds &amp; not Essendon ?
# ['craigieburn', 'stop', 'hub', 'svcs', 'essendon', 'express', 'moonee', 'ponds', 'business']
#
# @metrotrains merinda park. Nothing on the app
# ['merinda', 'app', 'park']
#
# @rodstraks Hi again, station from?
# ['station']
#
# @rodstraks Hi Rod, can you give us the train time you are waiting for and station, we will check it out.
# ['train', 'check', 'waiting', 'rod', 'give', 'station', 'time']
#
# @metrotrains another train bypassing the loop, every day it's the same.Joke!Then you slow down and wait before flinders so your not early
# ['bypassing', 'train', 'early', 'flinders', 'wait', 'loop', 'day', 'slow']
#
# @metrotrains @mark_melb Yeah but it arrived Flinders St mins late and left 10 mins late. But the Laverton train opposite left on time.
# ['laverton', 'late', 'train', 'flinders', 'yeah', 'mins', 'arrived', 'opposite', 'left', 'st', 'time']
#
# @metrotrains care to let us know what's happening on the Cranbourne line or are we mind readers? #useless #metrotrains
# ['readers', 'useless', 'happening', 'line', 'care', 'metrotrains', 'cranbourne', 'mind']
#
# 3 train loads of people now waiting for a loop train at Richmond. 2 Flinders st direct trains here now. Absolute incompetence @metrotrains
# ['train', 'flinders', 'loads', 'trains', 'waiting', 'st', 'absolute', 'richmond', 'people', 'loop', 'incompetence', 'direct']
#
# @mark_melb Ok, we did have an ill customer earlier that has delayed select services, sorry for any delays.
# ['delays', 'earlier', 'ill', 'select', 'delayed', 'customer', 'services']
#
# @metrotrains @ptv_official Solutions, not excuses. It can be done
# ['solutions', 'excuses']
#
# @metrotrains yet again. 2/2 morning trains this wk skipping the loop. Your reliability stats are clearly pure fiction
# ['morning', 'reliability', 'stats', 'wk', 'loop', 'fiction', 'trains', 'skipping', 'pure']
#
# @metrotrains @mark_melb North Melbourne but it was Flinders to Southern Cross
# ['southern', 'flinders', 'cross', 'north', 'melbourne']
#
# @RLGod @ptv_official Hi Again, the alterations happen very quickly, platform alterations are not sent via app, would arrive to late.
# ['late', 'app', 'alterations', 'arrive', 'platform', 'quickly', 'happen']
#
# @mark_melb Hi Mark, can you tell us which station/time and direction? and we will check it out.
# ['direction', 'mark', 'check']
#
# @metrotrains why do we allow bikes on at peak when every other capital has restrictions? #bikesofftrains #bikesareforriding #stopthecrush
# ['peak', 'bikes', 'bikesareforriding', 'stopthecrush', 'restrictions', 'bikesofftrains', 'capital']
#
# @metrotrains @ptv_official Just highlights the need for push updates on the app. They did but by the time I heard it on a platform too late.
# ['updates', 'push', 'late', 'heard', 'app', 'highlights', 'platform', 'time']
#
# @metrotrains 8.11 is scheduled to depart 10 mins ago.
# ['scheduled', 'ago', 'mins', 'depart']
#
# @metrotrains your train service never fails to disappoint. At least every week the Pakenham line is screwed up. It's a joke.
# ['joke', 'train', 'service', 'fails', 'line', 'disappoint', 'week', 'pakenham', 'screwed']
#
# @metrotrains wouldn't it make more sense to make the direct to flinders people get off?
# ['flinders', 'sense', 'people', 'direct', 'make']
#
# @RLGod @ptv_official to depart from an altered platform, did staff at Flinders Street make any announcements? 2/2
# ...
# ['patience', 'earlier', 'fault', 'delay', 'recover', 'signal', 'move']
#
# @regan_23 @marissa_sc @theage We had an earlier signal issue that has been fixed now. Sorry for the delay.
# ['fixed', 'earlier', 'issue', 'signal', 'delay']
#
# @kellyjmatthews I am so mcgrumpy #metrotrains it is so lame arriving at work late with the 'train delays' excuse
# ['delays', 'excuse', 'late', 'train', 'work', 'arriving', 'metrotrains', 'mcgrumpy', 'lame']
#
# @marissa_sc @theage @metrotrains I can't even get off the train to walk back home because we're stopped between stations!
# ['train', 'home', 'back', 'stopped', 'walk']
#
# @metrotrains frankston not moving. Any news?
# ['frankston', 'news', 'moving']
#
# @marissa_sc @theage @metrotrains delays on the Frankston line are more than 20 min now
# ['frankston', 'delays', 'line', 'min']
#
# Honestly, even we’ve lost count. Lots? #MetroTrains
#
# RT @Biancahatesyouu: @metrotrains how many defective trains do you have?
# ['honestly', 'rt', 'trains', 'defective', 'lost', 'metrotrains', 'lots', 'count']
#
# @sophia_lagastes I'm on the same train...wonderful being 45 minutes late to work isn't it?  #metrotrains
# ['work', 'metrotrains', 'late', 'minutes']
#
# RT @fakemetrotrains: We’re pleased to announce the launch of our Bring Your Own Seat initiative. #MetroTrains https://t.co/b3PtV1zgDp
# ['rt', 'pleased', 'url', 'launch', 'bring', 'initiative', 'metrotrains', 'announce', 'seat']
#
# @tarkynntayte Thanks for your feedback! *we’re #MetroTrains
# ['metrotrains']
#
# @metrotrains might want to update your site because pakenham line is NOT running a good service esp if you were due on 7.33 Beaconsfield
# ['beaconsfield', 'update', 'service', 'esp', 'line', 'good', 'pakenham', 'due', 'running', 'site']
#
# RT @fakemetrotrains: We’re pleased to announce the launch of our Bring Your Own Seat initiative. #MetroTrains https://t.co/b3PtV1zgDp
# ['rt', 'pleased', 'url', 'launch', 'bring', 'initiative', 'metrotrains', 'announce', 'seat']
#
# @metrotrains you should be disgusted with yourselves the amount of people you have just allowed to get on a train at Narre Warren. So wrong
# ['train', 'disgusted', 'allowed', 'warren', 'people', 'narre', 'amount', 'wrong']
#
# @kane_elias Thanks for your feedback! Because it costs money to fix them properly. #MetroTrains
# ['costs', 'fix', 'money', 'properly', 'metrotrains']
#
# RT @arismiluard: @metrotrains first train canceled, second train faulty doors. How are people supposed to trust your services? Now we no ro…
# ['train', 'rt', 'doors', 'supposed', 'faulty', 'people', 'services', 'trust', 'canceled']
#
# RT @itsruthbarker: @metrotrains every single day...late, delayed, cancelled or diverted...it's a bit tedious
# ['rt', 'delayed', 'tedious', 'bit', 'cancelled', 'single']
#
# RT @Emma80040653: @metrotrains what's the deal with the train not moving at narre warren? one before this was cancelled and now this.
# ['train', 'rt', 'deal', 'moving', 'warren', 'cancelled', 'narre']
#
# @metrotrains first train canceled, second train faulty doors. How are people supposed to trust your services? Now we no room to breath #fail
# ['train', 'doors', 'supposed', 'fail', 'faulty', 'people', 'services', 'trust', 'canceled', 'room', 'breath']
#
# RT @anatee20: TWO FAULTY PAKENHAM TRAINS IN ROW IN PEAK HOUR. WE SHOULD GET A FREE TRANSPORT DAY METRO FOOLS. EXPLAIN @metrotrains
# ['peak', 'rt', 'transport', 'metro', 'fools', 'pakenham', 'faulty', 'hour', 'row', 'explain', 'trains', 'day', 'free']
#
# RT @iaspinall: Ahhh, you have to love the modern technologies employed by @metrotrains #DefectiveTrain #Sandringham line #cancelled https:/…
# ['rt', 'love', 'modern', 'employed', 'line', 'defectivetrain', 'sandringham', 'cancelled', 'ahh', 'technologies']
#
# @metrotrains every single day...late, delayed, cancelled or diverted...it's a bit tedious
# ['delayed', 'tedious', 'bit', 'cancelled', 'single']
#
# @El_Shauno_Aus @metrotrains that is "Good Service" for metro trains! #metrotrainspathetic
# ['metrotrainspathetic', 'service', 'metro', 'good']
#
# @metrotrains 80+ decibel high pitch whine on Pakenham / Line. #misery #needsfixing carriage 593m
# ['decibel', 'pitch', 'whine', 'line', 'high', 'pakenham', 'needsfixing', 'carriage', 'misery']
#
# @metrotrains @ptv_official any idea why parking is so crazy at Eltham station. Last week or so it's been mad trying to find a spot.
# ['spot', 'parking', 'find', 'week', 'eltham', 'station', 'mad', 'crazy', 'idea']
#
# Thanks for the free coffee ☕️ @metrotrains
# ['coffee', 'free']
#
# Really looking forward to seeing how @metrotrains fails tonight in 37 degree heat. They have enough trouble when the weather is nice
# ['tonight', 'nice', 'weather', 'trouble', 'fails', 'degree', 'heat', 'forward']
#
# RT @fakemetrotrains: Does anyone know how to operate a reliable yet highly profitable metropolitan train network? Asking for a friend. #Met…
# ['network', 'highly', 'rt', 'train', 'friend', 'reliable', 'profitable', 'operate', 'metropolitan']
#
# Current situation on @metrotrains Frankston line. Ping @fakemetrotrains https://t.co/4pzRdNxBCl
# ['situation', 'url', 'line', 'ping', 'frankston', 'current']
#
# @metrotrains people, vent your frustrations @JacintaAllanMP
# ['vent', 'frustrations', 'people']
#
# Frankston line passengers should just sleep in today. "Major delays" into the city. #metrotrains
# ['sleep', 'delays', 'passengers', 'line', 'city', 'major', 'metrotrains', 'frankston', 'today']
#
# RT @regan_23: @marissa_sc @theage @metrotrains yay, 20 minutes delay on the Frankston line due to a signal issue. Is equipment not maintain…
# ['rt', 'yay', 'minutes', 'equipment', 'line', 'issue', 'frankston', 'signal', 'delay', 'due']
#
# RT @regan_23: @metrotrains please update your notify app: 10 minutes and more delay on the Frankston line due to signalling issues.
# ['rt', 'signalling', 'minutes', 'update', 'line', 'issues', 'frankston', 'delay', 'due', 'notify']
#
# Cursed were t' signals upon t' #Frankston line that morning. Dismayed were t' passengers. #MetroTrains 15:47 https://t.co/eCdkU3ZbkQ
# ['cursed', 'morning', 'dismayed', 'passengers', 'url', 'line', 'metrotrains', 'signals', 'frankston']
#
# RT @Alexalee76: @metrotrains stuck outside Mordialloc for 20mins nth bound. What is going on!? Sick of this useless service #whenwillitend …
# ['whenwillitend', 'rt', 'useless', 'service', 'mordialloc', 'sick', 'nth', 'stuck', 'bound']
#
# I hate you #metrotrains Have travelled half a stop between Aspendale and Mordialloc &amp; just sitting here. Goodbye to all my morning mtgs
# ['travelled', 'stop', 'morning', 'mordialloc', 'sitting', 'mtgs', 'metrotrains', 'half', 'goodbye', 'hate', 'aspendale']
#
# @metrotrains stuck outside Mordialloc for 20mins nth bound. What is going on!? Sick of this useless service #whenwillitend #fixthesystem
# ['whenwillitend', 'useless', 'service', 'mordialloc', 'sick', 'fixthesystem', 'nth', 'stuck', 'bound']
#
# Ahhh, you have to love the modern technologies employed by @metrotrains #DefectiveTrain #Sandringham line #cancelled https://t.co/7AFvXLLZex
# ['love', 'url', 'modern', 'employed', 'line', 'defectivetrain', 'sandringham', 'cancelled', 'ahh', 'technologies']
#
# RT @MelbPTUser: This guy is the best!!! The golden tonsils of Richmond! @metrotrains https://t.co/22ucBljlY7
# ['rt', 'url', 'tonsils', 'guy', 'golden']
#
# @marissa_sc @theage @metrotrains yay, 20 minutes delay on the Frankston line due to a signal issue. Is equipment not maintained??
# ['maintained', 'yay', 'minutes', 'equipment', 'line', 'issue', 'frankston', 'signal', 'delay', 'due']
#
# Rejoice in the darkness, for only then can the headlights of the Lord Metro's trains illuminate our lives. #MetroTrains 15:46
# ['darkness', 'headlights', 'rejoice', 'lord', 'metrotrains', 'illuminate', 'trains', 'lives']
#
# @metrotrains signal faults on Frankston line. Happens almost weekly.  Surely you can fix it permanently. Or is that too hard!
# ['fix', 'line', 'permanently', 'weekly', 'faults', 'frankston', 'signal', 'surely']
#
# Seriously @metrotrains every time there's a signal fault it is Mordialloc. Why are these faults constantly occurring &amp; have never been fixed
# ['fixed', 'constantly', 'occurring', 'mordialloc', 'fault', 'time', 'faults', 'signal']
#
# We’re pleased to announce the launch of our Bring Your Own Seat initiative. #MetroTrains https://t.co/b3PtV1zgDp
# ['pleased', 'url', 'launch', 'bring', 'initiative', 'metrotrains', 'announce', 'seat']
#
# Touch off, touch off! Alighting from the train is such sweet sorrow, that I shall say good day till it be afternoon peak. #MetroTrains 15:45
# ['peak', 'alighting', 'sorrow', 'train', 'till', 'sweet', 'touch', 'good', 'afternoon', 'metrotrains', 'day']
#
# @metrotrains and now where all stuck at Narre Warren station - great job excellent service #patheticmetro
# ['great', 'job', 'excellent', 'service', 'warren', 'station', 'narre', 'stuck', 'patheticmetro']
#
# @EllenSceneay oh no! Doesn't make for a great start to the day does it? #overcrowded @metrotrains
# ['great', 'start', 'overcrowded', 'day', 'make']
#
# You cannot find peace by avoiding train travel. #MetroTrains 15:44
# ['peace', 'train', 'travel', 'avoiding', 'metrotrains', 'find']
#
# @metrotrains please update your notify app: 10 minutes and more delay on the Frankston line due to signalling issues.
# ['signalling', 'minutes', 'update', 'line', 'issues', 'frankston', 'delay', 'due', 'notify']
#
# @metrotrains update on frankston delays?
# ['update', 'delays', 'frankston']
#
# Good one @metrotrains - another total fail. And to boot train took off fine. Wtf? https://t.co/4GVLPCu2IV
# ['train', 'total', 'url', 'fine', 'good', 'boot', 'fail', 'wtf']
#
# So I live 7km from @RMIT but to make an 830am class how long do you think I need to commute @metrotrains ? So sick of signal failures
# ['class', 'commute', 'live', 'sick', 'long', 'failures', 'signal', 'make']
#
# @metrotrains It's going to be 35c today and as usual no air-con on the Broadmeadows train city bound. Carriage 474M. Thank you.
# ['train', 'bound', 'city', 'broadmeadows', 'usual', 'carriage', 'today']
#
# @metrotrains Have you considered installing handrails that are accessible to, you know, short people? Just about dislocated my shoulder.
# ['handrails', 'installing', 'considered', 'shoulder', 'dislocated', 'people', 'accessible', 'short']
#
# @metrotrains please turn on Aircon in carriage 540M.
# ['aircon', 'carriage', 'turn']
#
# Stuck on a train outside Mordialloc for 10 mins or so, watching other trains go past. The @metrotrains driver doesn't know what's going on.
# ['train', 'past', 'mordialloc', 'mins', 'driver', 'watching', 'trains', 'stuck']
#
# @metrotrains how many defective trains do you have?
# ['trains', 'defective']
#
# @metrotrains skipping the loop again so you can meet your on time quota. A favourite "loop hole" of yours.
# ['meet', 'quota', 'favourite', 'loop', 'time', 'skipping', 'hole']
#
# TWO FAULTY PAKENHAM TRAINS IN ROW IN PEAK HOUR. WE SHOULD GET A FREE TRANSPORT DAY METRO FOOLS. EXPLAIN @metrotrains
# ['peak', 'transport', 'metro', 'fools', 'pakenham', 'faulty', 'hour', 'row', 'explain', 'trains', 'day', 'free']
#
# 7.35 Carrum stuck between aspendale and mordi. Might wanna turn the aircon on at least. 👍 @metrotrains
# ['carrum', 'mordi', 'aircon', 'wanna', 'stuck', 'turn', 'aspendale']
#
# @metrotrains why is the 7.47 Frankston to Flinders St stopped outside Edithvale with no information?
# ['flinders', 'information', 'edithvale', 'stopped', 'st', 'frankston']
#
# @metrotrains what the is going on with Frankston trains outside or Mordialloc?
# ['trains', 'frankston', 'mordialloc']
#
# @metrotrains what's the deal with the train not moving at narre warren? one before this was cancelled and now this.
# ['train', 'deal', 'moving', 'warren', 'cancelled', 'narre']
#
# @metrotrains There’s only like another 8 stations this train is supposed to be stopping at and picking up passengers.
# ['stations', 'train', 'picking', 'passengers', 'supposed', 'stopping']
#
# @metrotrains suggest you dont notify when a train will terminate at dandenong 7.44 from berwick overcrowded and only at narre warren
# ['dont', 'train', 'berwick', 'suggest', 'terminate', 'dandenong', 'warren', 'overcrowded', 'narre', 'notify']
#
# Dear #rmitjournos  while I have left a small child at home early to make the 830am class, it seems @metrotrains has other plans #late
# ['dear', 'small', 'class', 'late', 'early', 'child', 'home', 'left', 'plans', 'rmitjournos', 'make']
#
# @metrotrains Good work on meeting 100% passenger capacity on the 7:32 Heidelberg train at Dennis station this morning! 👍👍👍👍
# ['passenger', 'train', 'work', 'capacity', 'good', 'heidelberg', 'station', 'dennis', 'meeting']
#
# "Your 7:44am service has been delayed &amp; is now expected in 10 minutes." Great, 3 train-loads worth of delay. #MetroTrains
# ['great', 'minutes', 'expected', 'service', 'delayed', 'worth', 'metrotrains', 'delay']
#
# @metrotrains is there a reason to why there is no staff to help on Hoppers Crossing Station
# ['reason', 'station', 'hoppers', 'crossing', 'staff']
#
# @metrotrains 15 min to get from Footscray to Sth kensIngton. Sharp l, dangerous stopping = track faults. 😬
# ['kensington', 'track', 'sharp', 'min', 'sth', 'stopping', 'faults', 'footscray', 'dangerous']
#
# Doesn't seem that hard for the train to take you where it said it would. @metrotrains
# ['train', 'hard']
#
# Good work @metrotrains should make this more regular #lynbrookstation https://t.co/0XYgnqPmV1
# ['lynbrookstation', 'work', 'url', 'good', 'regular', 'make']
#
# Sharp uptick recently in the number of @metrotrains I've been on that get diverted from City Loop direct to Flinders.
# ['flinders', 'number', 'sharp', 'city', 'diverted', 'recently', 'loop', 'direct', 'uptick']
#
# @EllenSceneay @vline_geelong So does @metrotrains
# []
#
# Some signal issues causing Werribee line trains delays @metrotrains ;(
# ['delays', 'causing', 'line', 'issues', 'trains', 'signal', 'werribee']
#
# #Melbourne! Where you must allow an extra hour b4 work, coz #MetroTrains WANTS you to be late. #EvilMotives #YesComplainingOnTwitterAgain
# ['evilmotives', 'late', 'b4', 'work', 'coz', 'yescomplainingontwitteragain', 'hour', 'metrotrains', 'extra']
#
# @NotMetroNotify @metrotrains don't you dare cancel trains
# ['trains', 'cancel', 'dare']
#
# @metrotrains another cancelled train on the Pakenham line what a tremendous service you provide #patheticmetrotrains
# ['tremendous', 'train', 'service', 'line', 'provide', 'patheticmetrotrains', 'pakenham', 'cancelled']
#
# @metrotrains why is the air con never on? Just b/c there are clouds? Squashing ppl on a train without air con is cruel! Turn it on!!!!
# ['train', 'air', 'clouds', 'ppl', 'squashing', 'turn', 'con']
#
# RT @Camwhite51: @metrotrains how can this keep happening?you closed the line down for weeks this year and a couple years back for maintenan…
# ['rt', 'couple', 'year', 'line', 'back', 'weeks', 'years', 'closed']
#
# RT @metrotrains: UPDATE Glen Waverley line: Line suspended between Burnley and Darling. Check https://t.co/NUBM4OMjRl for more information.
# ['burnley', 'glen', 'rt', 'check', 'update', 'url', 'line', 'suspended', 'darling', 'information', 'waverley']
#
# @metrotrains well that came to an end fairly quickly.  Are you aware of how hot it is today? Do you suppose the morning might be a bit warm?
# ['end', 'morning', 'fairly', 'hot', 'warm', 'aware', 'suppose', 'bit', 'quickly', 'today']
#
# @vline_ballarat maybe it's time that @metrotrains stepped in, the line was meant to be electrified 30years ago and population is &gt; Sunbury
# ['ago', 'stepped', 'sunbury', 'meant', 'line', 'time', 'population', 'electrified']
#
# Does the GW line even run any more @metrotrains !? Trains were cancelled last night and now again this morning. Not impressed. #Melbourne
# ['melbourne', 'morning', 'run', 'gw', 'night', 'line', 'impressed', 'trains', 'cancelled']
#
# RT @blacklmb: Desperately need more services on the South Morang line @metrotrains packed carriages every morning by Preston and getting wo…
# ['morning', 'rt', 'preston', 'line', 'carriages', 'desperately', 'south', 'services', 'morang', 'packed']

# %% [markdown]
# Similar to counting the frequencies of emoticons, we can also count the frequencies of words in the pre-processed tweets:

# %%
f_list = []
for t in tweets_text:
    f_list += getFeatureVector(processTweet(t))

f_counter = collections.Counter(f_list)
pt = PrettyTable(field_names=['Words','Count'])
[pt.add_row(kv) for kv in f_counter.most_common()[:10]] #kv is a tuple: (key, value) 

pt.align['Words'], pt.align['Count'] = 'l', 'r'
print (pt)
# Out:
# +-------------+-------+
# | Words       | Count |
# +-------------+-------+
# | url         |   486 |
# | train       |   479 |
# | rt          |   330 |
# | line        |   300 |
# | metrotrains |   286 |
# | trains      |   238 |
# | frankston   |   192 |
# | station     |   160 |
# | service     |   150 |
# | good        |   135 |
# +-------------+-------+

# %% [markdown]
# It is not surprising that "train" was the most frequent word, as all the tweets are about metrotrains.
# "rt" was a very common token, which implies that there were a number of retweets.
# Finally, let's save the pre-processed tweets as one column in the dataframe.

# %%
feature_list = []
for tweet in tweets_text:
    preprocessed = processTweet(tweet)
    FeatureVector = getFeatureVector(preprocessed)
    feature_list.append(FeatureVector)

tweets_pddf['feature_words'] = feature_list

# %%
tweets_pddf.head(50)
# Out:
#                     id     user_id            user_name       user_sname  \
# 0   710240637497380864   534729059        Luke Sabatini    luke_sabatini
# 1   710240382311731200   215322466       Sina Marandian          myCroon
# 2   710239778554257408   947522706        Brett Keleher  thebrickcleaner
# 3   710238746688364545   215322466       Sina Marandian          myCroon
# 4   710238698428706816    94544311                  Ant           AntB77
# 5   710237588318085120    94544311                  Ant           AntB77
# 6   710234915384590336   310818887            Brad Cook         PkmtBrad
# 7   710233767881748480   182766018          Mark Stilve          stilves
# 8   710232721625206784   387479230                Emily          emtoone
# 9   710229717870186496    93570145    Fake Metro Trains  fakemetrotrains
# 10  710226759044562944    24331633              esayche          esayche
# 11  710226086659895297    93570145    Fake Metro Trains  fakemetrotrains
# 12  710225750482223104  2849186803              allyboo  littlesandieago
# 13  710224901131505664  3254244876          Megh Shetty        Megshetty
# 14  710222822719639552  2440721072          Kat Ritchie      kattritchie
# 15  710221833757298688  3308204684              PTV HUB           PTVHUB
# 16  710221762424733696  3308204684              PTV HUB           PTVHUB
# 17  710221042837381121    59771697             Guru Rao          raoguru
# 18  710220563029950464   397171390         Rhiannon Rak   rhiannonkatexo
# 19  710220278547087360    94444054     Bobby Przesmycki         bolekprz
# 20  710218790856839168   489088556          Biren Joshi       JoshiBiren
# 21  710218105033662464   718022906         Matthew John     thethorpstar
# 22  710217951077486592  1591227588         clear qualia       aspicacity
# 23  710217846572261376   138196049     Suburban Tourism        NoHeDaily
# 24  710217581584457728   320078797      Lissanne Oliver   LissanneOliver
# 25  710217553524563968     8303822         Daniel Bowen      danielbowen
# 26  710217542292213761    93570145    Fake Metro Trains  fakemetrotrains
# 27  710217290562703360    26199526         Dan Nicholas           nnwave
# 28  710217227857858560   324890519                Amzzz          amzzz13
# 29  710216956247298048   489088556          Biren Joshi       JoshiBiren
# 30  710216866430455809    59771697             Guru Rao          raoguru
# 31  710216624490414081  3028803219    The Book of Metro      BookOfMetro
# 32  710216370525319168   132868605           Kaz Healey        kazhealey
# 33  710215652527583232   393958473        Jeremy Bugeja           JezBug
# 34  710215609695350788    35676912  City of Maribyrnong    MaribyrnongCC
# 35  710214953299390464  3031845428        Melissa Tandy    melissa_tandy
# 36  710214946114502658   155139936       Megan Mitchell  meganetmitchell
# 37  710214703872520192   245663474       Amanda Bullock        nettyhawk
# 38  710214619025920000  2279805739                 Alex      AlexAllylaw
# 39  710214617545347072    94895312                 Omar        Omarsette
# 40  710214425815306241    19674129  Christopher Welldon    chrisopotamia
# 41  710214399315685376    36862191               Mark K        mark_melb
# 42  710214169115537409  3657454632                 Emma     Emma80040653
# 43  710214149381304320  3028803219    The Book of Metro      BookOfMetro
# 44  710214081349701633   489088556          Biren Joshi       JoshiBiren
# 45  710214080972230656    55503609       Michael George        PdGeorges
# 46  710214056204828673    14639177               Tyrell     tyrellperera
# 47  710213994968010752  3181366183                  TW8           tw8_69
# 48  710213855893270528   489088556          Biren Joshi       JoshiBiren
# 49  710213777082351616  3657454632                 Emma     Emma80040653
#
#                         created_at  \
# 0   Wed Mar 16 23:05:38 +0000 2016
# 1   Wed Mar 16 23:04:37 +0000 2016
# 2   Wed Mar 16 23:02:13 +0000 2016
# 3   Wed Mar 16 22:58:07 +0000 2016
# 4   Wed Mar 16 22:57:55 +0000 2016
# 5   Wed Mar 16 22:53:31 +0000 2016
# 6   Wed Mar 16 22:42:54 +0000 2016
# 7   Wed Mar 16 22:38:20 +0000 2016
# 8   Wed Mar 16 22:34:10 +0000 2016
# 9   Wed Mar 16 22:22:14 +0000 2016
# 10  Wed Mar 16 22:10:29 +0000 2016
# 11  Wed Mar 16 22:07:49 +0000 2016
# 12  Wed Mar 16 22:06:28 +0000 2016
# 13  Wed Mar 16 22:03:06 +0000 2016
# 14  Wed Mar 16 21:54:50 +0000 2016
# 15  Wed Mar 16 21:50:55 +0000 2016
# 16  Wed Mar 16 21:50:38 +0000 2016
# 17  Wed Mar 16 21:47:46 +0000 2016
# 18  Wed Mar 16 21:45:52 +0000 2016
# 19  Wed Mar 16 21:44:44 +0000 2016
# 20  Wed Mar 16 21:38:49 +0000 2016
# 21  Wed Mar 16 21:36:06 +0000 2016
# 22  Wed Mar 16 21:35:29 +0000 2016
# 23  Wed Mar 16 21:35:04 +0000 2016
# 24  Wed Mar 16 21:34:01 +0000 2016
# 25  Wed Mar 16 21:33:54 +0000 2016
# 26  Wed Mar 16 21:33:51 +0000 2016
# 27  Wed Mar 16 21:32:51 +0000 2016
# 28  Wed Mar 16 21:32:36 +0000 2016
# 29  Wed Mar 16 21:31:32 +0000 2016
# 30  Wed Mar 16 21:31:10 +0000 2016
# 31  Wed Mar 16 21:30:13 +0000 2016
# 32  Wed Mar 16 21:29:12 +0000 2016
# 33  Wed Mar 16 21:26:21 +0000 2016
# 34  Wed Mar 16 21:26:11 +0000 2016
# 35  Wed Mar 16 21:23:34 +0000 2016
# 36  Wed Mar 16 21:23:32 +0000 2016
# 37  Wed Mar 16 21:22:35 +0000 2016
# 38  Wed Mar 16 21:22:14 +0000 2016
# 39  Wed Mar 16 21:22:14 +0000 2016
# 40  Wed Mar 16 21:21:28 +0000 2016
# 41  Wed Mar 16 21:21:22 +0000 2016
# 42  Wed Mar 16 21:20:27 +0000 2016
# 43  Wed Mar 16 21:20:23 +0000 2016
# 44  Wed Mar 16 21:20:06 +0000 2016
# 45  Wed Mar 16 21:20:06 +0000 2016
# 46  Wed Mar 16 21:20:00 +0000 2016
# 47  Wed Mar 16 21:19:46 +0000 2016
# 48  Wed Mar 16 21:19:13 +0000 2016
# 49  Wed Mar 16 21:18:54 +0000 2016
#
#                                                  text emoticons  \
# 0   .@metrotrains, another day another diverted la...       NaN
# 1   @metrotrains 12 mins delay YET AGAIN on Flinde...       NaN
# 2   @danielbowen @VLine @jimbob_prod @metrotrains ...       NaN
# 3   @metrotrains not sure if guys who run Melbourn...       NaN
# 4             @metrotrains and we're away 10 min late       NaN
# 5   Amateur hr by @metrotrains  Flinders st, 9:49 ...       NaN
# 6   @danielbowen @jimbob_prod @metrotrains @VLine ...       NaN
# 7   @metrotrains hope our train driver's day gets ...       NaN
# 8   @metrotrains can you ever have trains running ...       NaN
# 9   @esayche Thanks for your feedback! Just do wha...       NaN
# 10  .@metrotrains should subsidise this for Lilyda...       NaN
# 11  @littlesandieago Thanks for your feedback! You...       NaN
# 12  @metrotrains Thnx for delivering an express tr...       NaN
# 13  @metrotrains very poor service blgrave line. T...       NaN
# 14  @metrotrains you'd think you'd be able to resp...       NaN
# 15  RT @metrotrains: Werribee line delays: Please ...       NaN
# 16  RT @metrotrains: Cranbourne/Pakenham line dela...       NaN
# 17  @metrotrains @ptv_official @DanielAndrewsMP th...       NaN
# 18  RT @fakemetrotrains: Good morning Melbourne! I...       NaN
# 19  @metrotrains is without a doubt is the worst P...       NaN
# 20  @ptv_official @metrotrains are worst then conn...       NaN
# 21  @metrotrains @CityLinkMelb to cost @DanielAndr...       NaN
# 22  RT @fakemetrotrains: Good morning Melbourne! I...       NaN
# 23  RT @LissanneOliver: Sweet @metrotrains blokes ...       NaN
# 24  Sweet @metrotrains blokes offering hot drinks ...       NaN
# 25  @jimbob_prod @metrotrains Seems like odd place...       NaN
# 26  @othiSA Thanks for your feedback! We’re so sca...       NaN
# 27  @metrotrains 3/3 trains for me this week skipp...       NaN
# 28  Train is going direct to flinders and skipping...       NaN
# 29  @metrotrains previously connex used to get fro...       NaN
# 30  @metrotrains why not u run a train as per sche...       NaN
# 31  A touch of red did suffuse the Line Informatio...       NaN
# 32  RT @fakemetrotrains: Good morning Melbourne! I...       NaN
# 33  RT @fakemetrotrains: Good morning Melbourne! I...       NaN
# 34  RT @metrotrains: Werribee line delays: Please ...       NaN
# 35  @metrotrains great idea free coffees at random...       NaN
# 36  RT @fakemetrotrains: Good morning Melbourne! I...       NaN
# 37  @mmmhotbreakfast surely on a massive weekend i...       NaN
# 38  Hey @metrotrains stickers on handrails to show...       NaN
# 39  Just another city loop service diverted to Fli...       NaN
# 40  @metrotrains Carriage 97M on the South Morang ...       NaN
# 41  @metrotrains When you say 2-3mins late, do you...       NaN
# 42  @metrotrains @tw8_69 @JacintaAllanMP @3AW693 i...       NaN
# 43  The Lord V/Line did seek to subvert the servic...       NaN
# 44  @metrotrains consistently late since last week...       NaN
# 45  @metrotrains why are the trains so cold? Airco...       NaN
# 46  RT @JoshiBiren: @metrotrains please please tur...       NaN
# 47  @metrotrains @JacintaAllanMP @3AW693 BOOM righ...       NaN
# 48  @metrotrains please please turn on AC on train...       NaN
# 49  @metrotrains could have told us 30 mins ago si...       NaN
#
#                                         feature_words
# 0   [caulfield, late, train, straight, cheers, cit...
# 1   [flinders, service, initially, line, mins, sup...
# 2           [lmao, run, deary, trains, skyrail, make]
# 3   [train, run, late, shame, apologizing, sick, d...
# 4                                         [late, min]
# 5   [train, southern, hr, flinders, cross, driver,...
# 6   [ago, happened, good, decade, narre, time, rec...
# 7   [hope, notcool, clear, train, angryman, spray,...
# 8                             [trains, time, running]
# 9                     [metrotrains, vandalise, train]
# 10      [subsidise, lilydale, passengers, url, today]
# 11                                      [metrotrains]
# 12  [train, late, work, express, missed, deliverin...
# 13      [service, meet, line, regular, poor, blgrave]
# 14                           [tweet, respond, simple]
# 15      [rt, check, url, line, information, werribee]
# 16                [rt, check, url, line, information]
# 17  [point, ordering, infrastructure, handle, trai...
# 18  [morning, rt, spirit, things, train, drivers, ...
# 19  [doubt, experienced, url, system, worst, pt, o...
# 20  [stations, approaching, flinders, travel, conn...
# 21        [total, cost, mismanagement, caused, chaos]
# 22  [morning, rt, spirit, things, train, drivers, ...
# 23  [morning, rt, hot, biscuits, url, drinks, swee...
# 24  [morning, biscuits, hot, url, drinks, sweet, d...
# 25              [place, change, explain, driver, odd]
# 26    [scared, totes, shat, metrotrains, pants, fear]
# 27  [unlucky, stats, extremely, week, wks, loop, t...
# 28  [train, flinders, city, row, loop, skipping, d...
# 29      [connex, city, mins, previously, huntingdale]
# 30  [game, train, run, altered, schedule, pick, ur...
# 31  [morning, red, reflecting, sky, url, line, pag...
# 32  [morning, rt, spirit, things, train, drivers, ...
# 33  [morning, rt, spirit, things, train, drivers, ...
# 34      [rt, check, url, line, information, werribee]
# 35  [great, free, stations, random, coffees, schoo...
# 36  [morning, rt, spirit, things, train, drivers, ...
# 37  [weekend, massive, fail, trains, melbourne, su...
# 38  [hands, handrails, hey, show, butts, stickers,...
# 39          [flinders, service, city, diverted, loop]
# 40     [line, south, oven, carriage, morang, inbound]
# 41                        [departing, arriving, late]
# 42            [late, idiots, paid, work, expect, pay]
# 43  [metro, lord, url, subvert, metrotrains, seek,...
# 44  [late, benchmark, week, performance, consisten...
# 45                [cold, full, power, aircon, trains]
# 46     [carnegie, train, rt, city, reached, ac, turn]
# 47  [train, run, flinders, muppets, street, boom, ...
# 48         [carnegie, train, city, reached, ac, turn]
# 49       [ago, train, told, pace, mins, snails, long]

# %% [markdown]
# ## 3. Conclusion
# We started this chapter by learning how to create an authenticated connection and then progressed through a series example code that illustrated how to pre-process tweets and make them ready for analysis.
# Beside, there are a couple of good tutorials on handling tweets, which are useful for review. They
# are listed in the following sections.

# %% [markdown]
# ## 4. Referece reading materials
# 1. "[Mining Twetter: Exploring Trending Topics, Discovering What People Are Talking About, and More](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/ipynb/Chapter%201%20-%20Mining%20Twitter.ipynb)" in "Mining the Social Web". 📖
# 2. "[Mining Twitter Data with Python](http://marcobonzanini.com/2015/03/02/mining-twitter-data-with-python-part-1/)", a tutorial by Marco Bonzanini. 📖
# 3. "[Twitter API tutorial](http://socialmedia-class.org/twittertutorial.html)" by Wei Xu, which give a quick tutorial
# on making API requests through two types of Twitter APIs 📖
# 4. "[Sentiment Expression via Emoticons on Social Media](http://arxiv.org/pdf/1511.02556.pdf)" bu Hao Wang and Jorge A. Castanon (Read this paper is optional)
# 5. "[How to Build a Twitter Sentiment Analyzer](http://ravikiranj.net/posts/2012/code/how-build-twitter-sentiment-analyzer/)" by Ravikiran Janardhana. Read two subsections, which are "Preprocess tweets" and "Filtering tweet words" 📖 .
#
# ## 5. Exercises
# 1. Extract all the conventional emoticons that are represented by punctuation marks, numbers and letters. Hint: you might need to construct your own regular expressions that can handle the following emoticons: :), :-), :(, :O, :-(, and so on.
