# %% [markdown]
# # Task B. MongoDB Data Model

# %%
import csv
import bson
import pymongo
import re
from bson.son import SON
from datetime import datetime
from datetime import timedelta
from pprint import pprint
from pymongo import MongoClient
import multiprocessing as mp

# %% [markdown]
# ## Task B.1
# The following is the structure we designed, using referencing instead of embeding document inside document.
# ### pros and cons
# **Pro**: Documents stored in this structure can improve memory usage. Every `climate` data only have `id` of the corresponding `fire` data instead of including all related data. In this way, we can avoid retrieving document in a large size which may occupy large proportion of memory. To some extent, it can improve the performance
# **Cons**: Some retrieving work may become complicated against the plain structure.

# %% [markdown]
# ### Model schema:
# Document in `climate` collection:
# ```Python
# {
#     _id:361
#     "Date": '2017-12-27',
#     "Station": '948702',
#     "AirTemperature": 26,
#     "RelativeHumidity": 58.3,
#     "WindSpeed": 9.3,
#     "MaxWindSpeed": 15.9,
#     "MAX" : "93.6*",
#     "MIN": "59.4",
#     "Precipitation": " 0.00I",
#     "Fires": [1, 2, 3, 4]
# }
# ```
# Document in `fire` collection:
# ```Python
# {
#     _id: 2,
#     "Location": {
#         "Latitude": -35.541,
#         "Longitude": 143.311
#     },
#     "SurfaceTemperature": {
#         "Kelvin": 336.3,
#         "Celcius": 63
#     },
#     "Datetime" : '2017-12-27T00:02:15',
#     "Power": 62.0,
#     "Confidence": 82
# }
# ```

# %% [markdown]
# ## Task B.2
#
# The following functions are for formating data into our desire format:

# %%
def date_helper(date_id, date_dict):
    '''
    This function is mainly for format_cln(). 
    It works as extracting matching on date, then put
    the corresponding id of another document in to a set.
    * Arguments:
    date_id: tuple, (date, _id), date is str. _id is int.
    date_dict: dict, where key is date, value is a set of ids
    * Return:
    The updated date_dict
    '''
    date = date_id[0]
    id_value = date_id[1]
    if date in date_dict:
        date_dict[date].add(id_value)
    else:
        date_dict[date] = set()
        date_dict[date].add(id_value)
    return date_dict

def format_cln(data1, data2):
    '''
    This function format the input in to particular BSON structure.
    * Arguments:
    data1,data2: list of lists object
    * Return:
    2 list of multiple dict objects
    '''
    cln1, cln2 = [],[]
    id_value=1 #initialise for _id
    date_dict = dict()
    #for fire
    for doc in data1:
        date = doc[6]
        bson = {
            "_id":id_value,
            "Location": {
                "Latitude": float(doc[0]),
                "Longitude": float(doc[1])
            },
            "SurfaceTemperature": {
                "Kelvin": float(doc[2]),
                "Celcius": int(doc[7])
            },
            "Datetime" : doc[3], #datetime.strptime(doc[3],"%Y-%m-%dT%H:%M:%S"),
            "Power": float(doc[4]),
            "Confidence": int(doc[5])
        }
        date_id = (date, id_value)
        date_dict = date_helper(date_id, date_dict)
        id_value+=1
        cln1.append(bson)
    #for climate   
    id_value = 1 #initialise for _id
    for doc in data2:
        fire_list = []
        if doc[1] in date_dict:
            fire_list = date_dict[doc[1]]
        bson = {
            "_id": id_value,
            "Date": doc[1],
            "Station": doc[0],
            "AirTemperature": int(doc[2]),
            "RelativeHumidity": float(doc[3]),
            "WindSpeed": float(doc[4]),
            "MaxWindSpeed": float(doc[5]),
            "MAX" : doc[6].strip(), # strip spaces
            "MIN": doc[7].strip(), # strip spaces
            "Precipitation": doc[8],
            "Fires": list(fire_list)
        }
        id_value+=1
        cln2.append(bson)
    return cln1, cln2

# %% [markdown]
# Using `Pymongo` to connect database. In this task, we use `fit5148_db` as our default database.
# Let's create new collections for `fire` and `climate`:

# %%
# Connect on the default host and port
client = MongoClient() # connect on the default host and port
db = client.fit5148_db
climateCollection = db.climate
fireCollection = db.fire

# %% [markdown]
# ## Task B.3
#
# First, we need to read `ClimateData-Part1.csv` and `FireData-Part1.csv` into raw data, namely, `fires` and `climate`:

# %%
climates = []
with open('ClimateData-Part1.csv', 'r') as csvfile:
    climates = list(csv.reader(csvfile, delimiter=','))
    climates.pop(0) # strip the title
    
fires = []
with open('FireData-Part1.csv', 'r') as csvfile:
    fires = list(csv.reader(csvfile, delimiter=','))
    fires.pop(0) # strip the title

# %% [markdown]
# Then, we use functions we build from Task B.2 to format data into our designed structure. After that, we use `insert_many()` to add our data:

# %%
#get format in the struture we designed
fire, climate = format_cln(fires, climates)
#insert all the docs into database
fireCollection.insert_many(fire)
climateCollection.insert_many(climate)

# %% [markdown]
# ## Task B.4 Query based on new structure

# %% [markdown]
# ### A2. Find climate data on *15th December 2017*

# %%
result_A2 = climateCollection.find({"Date":"2017-12-15"})
for i in result_A2:
    pprint(i)
# Out:
# {'AirTemperature': 18,
#  'Date': '2017-12-15',
#  'Fires': [24, 25, 26, 23],
#  'MAX': '74.5*',
#  'MIN': '53.1',
#  'MaxWindSpeed': 14.0,
#  'Precipitation': ' 0.00I',
#  'RelativeHumidity': 52.0,
#  'Station': '948702',
#  'WindSpeed': 7.1,
#  '_id': 349}

# %% [markdown]
# ### A3. Find the *latitude, longitude* and *confidence* when the surface temperature (°C) was between *65 °C* and *100 °C*.

# %%
result_A3 = fireCollection.find({"SurfaceTemperature.Celcius":{"$gte":65, "$lte":100}},
                                {"_id":0,"Location.Latitude":1, "Location.Longitude":1, "Confidence":1})
for i in result_A3:
    pprint(i)
# Out:
# {'Confidence': 78, 'Location': {'Latitude': -37.966, 'Longitude': 145.051}}
# {'Confidence': 86, 'Location': {'Latitude': -35.543, 'Longitude': 143.316}}
# {'Confidence': 93, 'Location': {'Latitude': -37.875, 'Longitude': 142.51}}
# {'Confidence': 95, 'Location': {'Latitude': -37.613, 'Longitude': 149.305}}
# {'Confidence': 90, 'Location': {'Latitude': -37.624, 'Longitude': 149.314}}
# {'Confidence': 93, 'Location': {'Latitude': -38.057, 'Longitude': 144.211}}
# {'Confidence': 92, 'Location': {'Latitude': -37.95, 'Longitude': 142.366}}
# {'Confidence': 100, 'Location': {'Latitude': -36.282, 'Longitude': 146.157}}
# {'Confidence': 100, 'Location': {'Latitude': -37.642, 'Longitude': 149.263}}
# {'Confidence': 100, 'Location': {'Latitude': -37.634, 'Longitude': 149.237}}
# {'Confidence': 98, 'Location': {'Latitude': -37.605, 'Longitude': 149.302}}
# {'Confidence': 99, 'Location': {'Latitude': -37.6, 'Longitude': 149.325}}
# {'Confidence': 95, 'Location': {'Latitude': -37.618, 'Longitude': 149.281}}
# {'Confidence': 100, 'Location': {'Latitude': -37.606, 'Longitude': 149.312}}
# {'Confidence': 97, 'Location': {'Latitude': -37.61, 'Longitude': 149.307}}
# {'Confidence': 99, 'Location': {'Latitude': -37.609, 'Longitude': 149.32}}
# {'Confidence': 93, 'Location': {'Latitude': -37.945, 'Longitude': 144.354}}
# {'Confidence': 87, 'Location': {'Latitude': -37.862, 'Longitude': 144.175}}
# {'Confidence': 89, 'Location': {'Latitude': -36.94, 'Longitude': 143.281}}
# {'Confidence': 100, 'Location': {'Latitude': -37.477, 'Longitude': 143.352}}
# {'Confidence': 96, 'Location': {'Latitude': -37.475, 'Longitude': 143.365}}
# {'Confidence': 97, 'Location': {'Latitude': -37.69, 'Longitude': 143.605}}
# {'Confidence': 90, 'Location': {'Latitude': -37.331, 'Longitude': 143.122}}
# {'Confidence': 92, 'Location': {'Latitude': -36.098, 'Longitude': 143.74}}
# {'Confidence': 91, 'Location': {'Latitude': -37.247, 'Longitude': 141.278}}
# {'Confidence': 100, 'Location': {'Latitude': -37.294, 'Longitude': 141.232}}
# {'Confidence': 99, 'Location': {'Latitude': -37.293, 'Longitude': 141.245}}
# {'Confidence': 96, 'Location': {'Latitude': -38.127, 'Longitude': 143.82}}
# {'Confidence': 100, 'Location': {'Latitude': -37.462, 'Longitude': 148.089}}
# {'Confidence': 88, 'Location': {'Latitude': -37.46, 'Longitude': 148.102}}
# {'Confidence': 100, 'Location': {'Latitude': -37.446, 'Longitude': 148.102}}
# {'Confidence': 100, 'Location': {'Latitude': -37.406, 'Longitude': 148.123}}
# {'Confidence': 68, 'Location': {'Latitude': -37.452, 'Longitude': 148.115}}
# {'Confidence': 64, 'Location': {'Latitude': -37.45, 'Longitude': 148.126}}
# {'Confidence': 86, 'Location': {'Latitude': -37.436, 'Longitude': 148.088}}
# {'Confidence': 73, 'Location': {'Latitude': -37.444, 'Longitude': 148.101}}
# {'Confidence': 61, 'Location': {'Latitude': -37.562, 'Longitude': 148.05}}
# {'Confidence': 58, 'Location': {'Latitude': -37.379, 'Longitude': 148.126}}
# {'Confidence': 62, 'Location': {'Latitude': -37.379, 'Longitude': 148.132}}
# {'Confidence': 100, 'Location': {'Latitude': -37.396, 'Longitude': 148.086}}
# {'Confidence': 100, 'Location': {'Latitude': -37.399, 'Longitude': 148.081}}
# {'Confidence': 100, 'Location': {'Latitude': -37.401, 'Longitude': 148.067}}
# {'Confidence': 94, 'Location': {'Latitude': -37.4796, 'Longitude': 141.9403}}
# {'Confidence': 89, 'Location': {'Latitude': -38.3998, 'Longitude': 147.064}}
# {'Confidence': 91, 'Location': {'Latitude': -37.8644, 'Longitude': 143.4263}}
# {'Confidence': 91, 'Location': {'Latitude': -36.3774, 'Longitude': 143.7079}}
# {'Confidence': 100, 'Location': {'Latitude': -36.3756, 'Longitude': 143.7243}}
# {'Confidence': 97, 'Location': {'Latitude': -36.369, 'Longitude': 143.7132}}
# {'Confidence': 100, 'Location': {'Latitude': -36.3799, 'Longitude': 143.7149}}
# {'Confidence': 94, 'Location': {'Latitude': -36.2693, 'Longitude': 143.1768}}
# {'Confidence': 96, 'Location': {'Latitude': -36.1002, 'Longitude': 142.3405}}
# {'Confidence': 90, 'Location': {'Latitude': -36.4325, 'Longitude': 144.3142}}
# {'Confidence': 91, 'Location': {'Latitude': -36.7685, 'Longitude': 142.7134}}
# {'Confidence': 91, 'Location': {'Latitude': -36.7801, 'Longitude': 142.7151}}
# {'Confidence': 91, 'Location': {'Latitude': -36.7746, 'Longitude': 146.6642}}
# {'Confidence': 96, 'Location': {'Latitude': -36.8359, 'Longitude': 146.6448}}
# {'Confidence': 98, 'Location': {'Latitude': -37.9085, 'Longitude': 141.1038}}
# {'Confidence': 100, 'Location': {'Latitude': -38.4349, 'Longitude': 146.3122}}
# {'Confidence': 89, 'Location': {'Latitude': -38.4792, 'Longitude': 146.3081}}
# {'Confidence': 100, 'Location': {'Latitude': -37.9047, 'Longitude': 141.0945}}
# {'Confidence': 93, 'Location': {'Latitude': -37.4984, 'Longitude': 142.9739}}
# {'Confidence': 96, 'Location': {'Latitude': -37.253, 'Longitude': 144.3681}}
# {'Confidence': 92, 'Location': {'Latitude': -36.9396, 'Longitude': 143.1462}}
# {'Confidence': 96, 'Location': {'Latitude': -36.3387, 'Longitude': 141.7542}}
# {'Confidence': 100, 'Location': {'Latitude': -36.3433, 'Longitude': 143.4369}}
# {'Confidence': 100, 'Location': {'Latitude': -36.345, 'Longitude': 143.4256}}
# {'Confidence': 90, 'Location': {'Latitude': -36.7032, 'Longitude': 144.0992}}
# {'Confidence': 96, 'Location': {'Latitude': -36.3402, 'Longitude': 141.7429}}
# {'Confidence': 89, 'Location': {'Latitude': -36.5661, 'Longitude': 142.2956}}
# {'Confidence': 85, 'Location': {'Latitude': -36.5023, 'Longitude': 143.6038}}
# {'Confidence': 90, 'Location': {'Latitude': -36.8616, 'Longitude': 142.8025}}
# {'Confidence': 90, 'Location': {'Latitude': -38.0372, 'Longitude': 146.0616}}
# {'Confidence': 94, 'Location': {'Latitude': -38.049, 'Longitude': 146.0513}}
# {'Confidence': 89, 'Location': {'Latitude': -35.4666, 'Longitude': 142.0749}}
# {'Confidence': 95, 'Location': {'Latitude': -36.0396, 'Longitude': 141.7183}}
# {'Confidence': 94, 'Location': {'Latitude': -36.2775, 'Longitude': 146.1026}}
# {'Confidence': 100, 'Location': {'Latitude': -38.0361, 'Longitude': 146.0567}}
# {'Confidence': 95, 'Location': {'Latitude': -36.3254, 'Longitude': 144.3638}}
# {'Confidence': 100, 'Location': {'Latitude': -36.0816, 'Longitude': 145.859}}
# {'Confidence': 100, 'Location': {'Latitude': -36.1532, 'Longitude': 143.5527}}
# {'Confidence': 100, 'Location': {'Latitude': -36.0077, 'Longitude': 141.7747}}
# {'Confidence': 94, 'Location': {'Latitude': -36.0828, 'Longitude': 145.873}}
# {'Confidence': 91, 'Location': {'Latitude': -36.5541, 'Longitude': 144.1321}}
# {'Confidence': 91, 'Location': {'Latitude': -35.6819, 'Longitude': 143.5275}}
# {'Confidence': 90, 'Location': {'Latitude': -35.6871, 'Longitude': 143.5235}}
# {'Confidence': 100, 'Location': {'Latitude': -36.1506, 'Longitude': 143.5671}}
# {'Confidence': 93, 'Location': {'Latitude': -37.4671, 'Longitude': 145.9962}}
# {'Confidence': 90, 'Location': {'Latitude': -36.2911, 'Longitude': 141.1664}}
# {'Confidence': 96, 'Location': {'Latitude': -36.2842, 'Longitude': 141.1741}}
# {'Confidence': 89, 'Location': {'Latitude': -36.7218, 'Longitude': 141.6411}}
# {'Confidence': 84, 'Location': {'Latitude': -37.3656, 'Longitude': 141.3903}}
# {'Confidence': 94, 'Location': {'Latitude': -36.4179, 'Longitude': 144.2924}}
# {'Confidence': 92, 'Location': {'Latitude': -36.3207, 'Longitude': 140.9737}}
# {'Confidence': 99, 'Location': {'Latitude': -36.2882, 'Longitude': 141.1821}}
# {'Confidence': 91, 'Location': {'Latitude': -36.3153, 'Longitude': 140.9789}}
# {'Confidence': 97, 'Location': {'Latitude': -36.4169, 'Longitude': 144.2994}}
# {'Confidence': 96, 'Location': {'Latitude': -36.8094, 'Longitude': 142.8885}}
# {'Confidence': 84, 'Location': {'Latitude': -37.8323, 'Longitude': 147.2232}}
# {'Confidence': 98, 'Location': {'Latitude': -38.2853, 'Longitude': 145.9519}}
# {'Confidence': 98, 'Location': {'Latitude': -38.2375, 'Longitude': 142.8363}}
# {'Confidence': 92, 'Location': {'Latitude': -37.4463, 'Longitude': 142.7829}}
# {'Confidence': 95, 'Location': {'Latitude': -37.6854, 'Longitude': 143.4543}}
# {'Confidence': 99, 'Location': {'Latitude': -38.0881, 'Longitude': 143.9391}}
# {'Confidence': 96, 'Location': {'Latitude': -38.0866, 'Longitude': 143.9534}}
# {'Confidence': 92, 'Location': {'Latitude': -38.2391, 'Longitude': 142.82}}
# {'Confidence': 100, 'Location': {'Latitude': -38.5123, 'Longitude': 146.4007}}
# {'Confidence': 96, 'Location': {'Latitude': -36.3438, 'Longitude': 141.5832}}
# {'Confidence': 94, 'Location': {'Latitude': -37.4357, 'Longitude': 142.7813}}
# {'Confidence': 99, 'Location': {'Latitude': -37.5867, 'Longitude': 143.6256}}
# {'Confidence': 93, 'Location': {'Latitude': -36.2306, 'Longitude': 143.6408}}
# {'Confidence': 91, 'Location': {'Latitude': -36.4168, 'Longitude': 141.6939}}
# {'Confidence': 97, 'Location': {'Latitude': -36.4211, 'Longitude': 141.6875}}
# {'Confidence': 91, 'Location': {'Latitude': -35.6138, 'Longitude': 143.8666}}
# {'Confidence': 95, 'Location': {'Latitude': -36.0885, 'Longitude': 145.0359}}
# {'Confidence': 96, 'Location': {'Latitude': -36.3193, 'Longitude': 145.9162}}
# {'Confidence': 98, 'Location': {'Latitude': -36.0652, 'Longitude': 146.0764}}
# {'Confidence': 100, 'Location': {'Latitude': -36.0682, 'Longitude': 146.0602}}
# {'Confidence': 92, 'Location': {'Latitude': -37.7889, 'Longitude': 143.1324}}
# {'Confidence': 95, 'Location': {'Latitude': -36.6139, 'Longitude': 143.501}}
# {'Confidence': 95, 'Location': {'Latitude': -37.9509, 'Longitude': 143.9599}}
# {'Confidence': 97, 'Location': {'Latitude': -36.6224, 'Longitude': 143.5092}}
# {'Confidence': 96, 'Location': {'Latitude': -38.0933, 'Longitude': 143.9824}}
# {'Confidence': 92, 'Location': {'Latitude': -36.663, 'Longitude': 142.8567}}
# {'Confidence': 94, 'Location': {'Latitude': -37.6982, 'Longitude': 143.0549}}
# {'Confidence': 95, 'Location': {'Latitude': -36.7187, 'Longitude': 143.805}}
# {'Confidence': 100, 'Location': {'Latitude': -36.7742, 'Longitude': 145.1991}}
# {'Confidence': 91, 'Location': {'Latitude': -36.5061, 'Longitude': 144.5675}}
# {'Confidence': 100, 'Location': {'Latitude': -36.4035, 'Longitude': 140.9935}}
# {'Confidence': 99, 'Location': {'Latitude': -36.4286, 'Longitude': 141.1567}}
# {'Confidence': 91, 'Location': {'Latitude': -36.3635, 'Longitude': 142.2809}}
# {'Confidence': 100, 'Location': {'Latitude': -36.664, 'Longitude': 142.8802}}
# {'Confidence': 91, 'Location': {'Latitude': -36.6564, 'Longitude': 142.8615}}
# {'Confidence': 93, 'Location': {'Latitude': -36.6657, 'Longitude': 143.1675}}
# {'Confidence': 98, 'Location': {'Latitude': -36.8742, 'Longitude': 142.7177}}
# {'Confidence': 91, 'Location': {'Latitude': -36.7751, 'Longitude': 145.1696}}
# {'Confidence': 91, 'Location': {'Latitude': -36.3961, 'Longitude': 140.9781}}
# {'Confidence': 100, 'Location': {'Latitude': -36.7708, 'Longitude': 145.1908}}
# {'Confidence': 98, 'Location': {'Latitude': -37.758, 'Longitude': 143.179}}
# {'Confidence': 94, 'Location': {'Latitude': -37.7609, 'Longitude': 143.1633}}
# {'Confidence': 89, 'Location': {'Latitude': -36.5116, 'Longitude': 144.562}}
# {'Confidence': 92, 'Location': {'Latitude': -36.803, 'Longitude': 142.9261}}
# {'Confidence': 89, 'Location': {'Latitude': -36.4143, 'Longitude': 143.272}}
# {'Confidence': 99, 'Location': {'Latitude': -36.7153, 'Longitude': 143.8226}}
# {'Confidence': 100, 'Location': {'Latitude': -36.8791, 'Longitude': 142.7261}}
# {'Confidence': 100, 'Location': {'Latitude': -36.7309, 'Longitude': 142.3633}}
# {'Confidence': 92, 'Location': {'Latitude': -36.882, 'Longitude': 142.7108}}
# {'Confidence': 93, 'Location': {'Latitude': -37.5135, 'Longitude': 142.7238}}
# {'Confidence': 94, 'Location': {'Latitude': -36.2121, 'Longitude': 144.6885}}
# {'Confidence': 97, 'Location': {'Latitude': -36.2206, 'Longitude': 144.6856}}
# {'Confidence': 88, 'Location': {'Latitude': -38.0132, 'Longitude': 146.5269}}
# {'Confidence': 87, 'Location': {'Latitude': -38.0148, 'Longitude': 146.5413}}
# {'Confidence': 100, 'Location': {'Latitude': -37.8412, 'Longitude': 147.2536}}
# {'Confidence': 96, 'Location': {'Latitude': -37.8429, 'Longitude': 147.2691}}
# {'Confidence': 100, 'Location': {'Latitude': -36.5454, 'Longitude': 144.7402}}
# {'Confidence': 92, 'Location': {'Latitude': -36.7593, 'Longitude': 142.895}}
# {'Confidence': 90, 'Location': {'Latitude': -36.3435, 'Longitude': 141.5513}}
# {'Confidence': 93, 'Location': {'Latitude': -36.6942, 'Longitude': 143.8021}}
# {'Confidence': 100, 'Location': {'Latitude': -36.3459, 'Longitude': 141.5586}}
# {'Confidence': 93, 'Location': {'Latitude': -36.4046, 'Longitude': 141.1534}}
# {'Confidence': 96, 'Location': {'Latitude': -36.0594, 'Longitude': 141.5907}}
# {'Confidence': 100, 'Location': {'Latitude': -36.0576, 'Longitude': 141.6122}}
# {'Confidence': 93, 'Location': {'Latitude': -36.388, 'Longitude': 141.8309}}
# {'Confidence': 90, 'Location': {'Latitude': -36.094, 'Longitude': 145.7646}}
# {'Confidence': 99, 'Location': {'Latitude': -36.5438, 'Longitude': 144.7548}}
# {'Confidence': 95, 'Location': {'Latitude': -36.6537, 'Longitude': 143.8781}}
# {'Confidence': 100, 'Location': {'Latitude': -38.1917, 'Longitude': 147.0745}}
# {'Confidence': 95, 'Location': {'Latitude': -38.1987, 'Longitude': 147.0666}}
# {'Confidence': 70, 'Location': {'Latitude': -36.9303, 'Longitude': 143.1034}}
# {'Confidence': 83, 'Location': {'Latitude': -36.3195, 'Longitude': 146.0601}}
# {'Confidence': 100, 'Location': {'Latitude': -36.5839, 'Longitude': 143.0588}}
# {'Confidence': 100, 'Location': {'Latitude': -36.5854, 'Longitude': 143.0462}}
# {'Confidence': 95, 'Location': {'Latitude': -36.3014, 'Longitude': 143.203}}
# {'Confidence': 87, 'Location': {'Latitude': -36.3332, 'Longitude': 145.8594}}
# {'Confidence': 86, 'Location': {'Latitude': -37.6775, 'Longitude': 148.5131}}
# {'Confidence': 93, 'Location': {'Latitude': -36.9111, 'Longitude': 142.692}}
# {'Confidence': 99, 'Location': {'Latitude': -37.5115, 'Longitude': 143.14}}
# {'Confidence': 93, 'Location': {'Latitude': -37.769, 'Longitude': 147.94}}
# {'Confidence': 90, 'Location': {'Latitude': -36.1303, 'Longitude': 146.3606}}
# {'Confidence': 98, 'Location': {'Latitude': -36.1345, 'Longitude': 146.351}}
# {'Confidence': 99, 'Location': {'Latitude': -36.1586, 'Longitude': 145.6666}}
# {'Confidence': 96, 'Location': {'Latitude': -36.5847, 'Longitude': 145.1968}}
# {'Confidence': 89, 'Location': {'Latitude': -37.876, 'Longitude': 143.7804}}
# {'Confidence': 88, 'Location': {'Latitude': -36.1546, 'Longitude': 141.8146}}
# {'Confidence': 87, 'Location': {'Latitude': -37.9091, 'Longitude': 143.5105}}
# {'Confidence': 80, 'Location': {'Latitude': -36.1559, 'Longitude': 141.8102}}
# {'Confidence': 100, 'Location': {'Latitude': -37.9071, 'Longitude': 143.538}}
# {'Confidence': 100, 'Location': {'Latitude': -37.3902, 'Longitude': 148.2955}}
# {'Confidence': 100, 'Location': {'Latitude': -37.5027, 'Longitude': 146.347}}
# {'Confidence': 100, 'Location': {'Latitude': -37.5043, 'Longitude': 146.3299}}
# {'Confidence': 93, 'Location': {'Latitude': -36.1964, 'Longitude': 144.5217}}
# {'Confidence': 91, 'Location': {'Latitude': -37.6397, 'Longitude': 142.5968}}
# {'Confidence': 90, 'Location': {'Latitude': -37.6267, 'Longitude': 142.9993}}
# {'Confidence': 93, 'Location': {'Latitude': -36.5871, 'Longitude': 144.4958}}
# {'Confidence': 89, 'Location': {'Latitude': -36.2618, 'Longitude': 141.8783}}
# {'Confidence': 90, 'Location': {'Latitude': -36.6828, 'Longitude': 144.784}}
# {'Confidence': 89, 'Location': {'Latitude': -37.4843, 'Longitude': 143.0592}}
# {'Confidence': 94, 'Location': {'Latitude': -37.7274, 'Longitude': 142.9536}}
# {'Confidence': 91, 'Location': {'Latitude': -37.6964, 'Longitude': 142.8583}}
# {'Confidence': 98, 'Location': {'Latitude': -38.0509, 'Longitude': 143.9423}}
# {'Confidence': 92, 'Location': {'Latitude': -37.9284, 'Longitude': 143.108}}
# {'Confidence': 100, 'Location': {'Latitude': -37.5701, 'Longitude': 142.6497}}
# {'Confidence': 90, 'Location': {'Latitude': -36.7101, 'Longitude': 142.3865}}
# {'Confidence': 93, 'Location': {'Latitude': -38.1693, 'Longitude': 143.0466}}
# {'Confidence': 95, 'Location': {'Latitude': -36.7128, 'Longitude': 142.3717}}
# {'Confidence': 97, 'Location': {'Latitude': -37.4885, 'Longitude': 142.0658}}
# {'Confidence': 77, 'Location': {'Latitude': -36.7101, 'Longitude': 142.981}}
# {'Confidence': 89, 'Location': {'Latitude': -37.0959, 'Longitude': 143.8206}}
# {'Confidence': 100, 'Location': {'Latitude': -37.9594, 'Longitude': 143.5638}}
# {'Confidence': 98, 'Location': {'Latitude': -36.5921, 'Longitude': 144.4905}}
# {'Confidence': 96, 'Location': {'Latitude': -36.6787, 'Longitude': 144.8042}}
# {'Confidence': 84, 'Location': {'Latitude': -38.0423, 'Longitude': 146.4048}}
# {'Confidence': 94, 'Location': {'Latitude': -38.1224, 'Longitude': 143.7553}}
# {'Confidence': 94, 'Location': {'Latitude': -38.0792, 'Longitude': 143.7361}}
# {'Confidence': 93, 'Location': {'Latitude': -37.9157, 'Longitude': 143.3544}}
# {'Confidence': 96, 'Location': {'Latitude': -37.7935, 'Longitude': 143.1606}}
# {'Confidence': 90, 'Location': {'Latitude': -37.7756, 'Longitude': 143.1388}}
# {'Confidence': 91, 'Location': {'Latitude': -37.7171, 'Longitude': 142.9505}}
# {'Confidence': 94, 'Location': {'Latitude': -37.7236, 'Longitude': 142.947}}
# {'Confidence': 100, 'Location': {'Latitude': -37.7002, 'Longitude': 142.9562}}
# {'Confidence': 92, 'Location': {'Latitude': -37.6498, 'Longitude': 142.5997}}
# {'Confidence': 100, 'Location': {'Latitude': -37.5728, 'Longitude': 142.6348}}
# {'Confidence': 100, 'Location': {'Latitude': -37.4352, 'Longitude': 143.1444}}
# {'Confidence': 92, 'Location': {'Latitude': -36.5828, 'Longitude': 144.5775}}
# {'Confidence': 96, 'Location': {'Latitude': -36.5987, 'Longitude': 144.4995}}
# {'Confidence': 98, 'Location': {'Latitude': -36.5262, 'Longitude': 144.5737}}
# {'Confidence': 95, 'Location': {'Latitude': -36.6995, 'Longitude': 142.978}}
# {'Confidence': 93, 'Location': {'Latitude': -36.8879, 'Longitude': 141.6647}}
# {'Confidence': 100, 'Location': {'Latitude': -35.8768, 'Longitude': 145.4627}}
# {'Confidence': 93, 'Location': {'Latitude': -36.4899, 'Longitude': 142.2805}}
# {'Confidence': 93, 'Location': {'Latitude': -36.663, 'Longitude': 141.3038}}
# {'Confidence': 94, 'Location': {'Latitude': -36.092, 'Longitude': 141.7306}}
# {'Confidence': 89, 'Location': {'Latitude': -34.9023, 'Longitude': 142.0557}}
# {'Confidence': 91, 'Location': {'Latitude': -36.2637, 'Longitude': 145.3649}}
# {'Confidence': 89, 'Location': {'Latitude': -37.2609, 'Longitude': 141.7999}}
# {'Confidence': 93, 'Location': {'Latitude': -36.91, 'Longitude': 141.0704}}
# {'Confidence': 92, 'Location': {'Latitude': -36.2652, 'Longitude': 145.3769}}
# {'Confidence': 95, 'Location': {'Latitude': -36.738, 'Longitude': 142.1177}}
# {'Confidence': 95, 'Location': {'Latitude': -36.5199, 'Longitude': 144.7311}}
# {'Confidence': 91, 'Location': {'Latitude': -37.0782, 'Longitude': 145.3625}}
# {'Confidence': 94, 'Location': {'Latitude': -36.3966, 'Longitude': 141.406}}
# {'Confidence': 90, 'Location': {'Latitude': -37.1349, 'Longitude': 141.9491}}
# {'Confidence': 91, 'Location': {'Latitude': -36.7651, 'Longitude': 143.5801}}
# {'Confidence': 98, 'Location': {'Latitude': -36.9329, 'Longitude': 143.7796}}
# {'Confidence': 99, 'Location': {'Latitude': -35.8276, 'Longitude': 143.7549}}
# {'Confidence': 78, 'Location': {'Latitude': -35.9326, 'Longitude': 141.958}}
# {'Confidence': 91, 'Location': {'Latitude': -36.6892, 'Longitude': 145.2775}}
# {'Confidence': 89, 'Location': {'Latitude': -36.73, 'Longitude': 143.935}}
# {'Confidence': 100, 'Location': {'Latitude': -36.8283, 'Longitude': 143.4605}}
# {'Confidence': 97, 'Location': {'Latitude': -36.6527, 'Longitude': 142.7392}}
# {'Confidence': 96, 'Location': {'Latitude': -36.1898, 'Longitude': 145.0922}}
# {'Confidence': 96, 'Location': {'Latitude': -36.8298, 'Longitude': 143.4483}}
# {'Confidence': 100, 'Location': {'Latitude': -36.6615, 'Longitude': 144.6014}}
# {'Confidence': 93, 'Location': {'Latitude': -36.8238, 'Longitude': 143.5724}}
# {'Confidence': 100, 'Location': {'Latitude': -36.1988, 'Longitude': 145.0941}}
# {'Confidence': 75, 'Location': {'Latitude': -36.7499, 'Longitude': 141.3006}}
# {'Confidence': 84, 'Location': {'Latitude': -36.7432, 'Longitude': 141.3296}}
# {'Confidence': 84, 'Location': {'Latitude': -36.7531, 'Longitude': 141.3253}}
# {'Confidence': 99, 'Location': {'Latitude': -36.7943, 'Longitude': 143.9571}}
# {'Confidence': 100, 'Location': {'Latitude': -36.7957, 'Longitude': 143.9652}}
# {'Confidence': 96, 'Location': {'Latitude': -36.9498, 'Longitude': 142.2012}}
# {'Confidence': 93, 'Location': {'Latitude': -36.1941, 'Longitude': 143.1604}}
# {'Confidence': 100, 'Location': {'Latitude': -36.4142, 'Longitude': 143.1077}}
# {'Confidence': 92, 'Location': {'Latitude': -36.1924, 'Longitude': 143.1716}}
# {'Confidence': 89, 'Location': {'Latitude': -36.0295, 'Longitude': 143.6409}}
# {'Confidence': 100, 'Location': {'Latitude': -37.0761, 'Longitude': 141.0574}}
# {'Confidence': 93, 'Location': {'Latitude': -35.0616, 'Longitude': 141.4417}}
# {'Confidence': 100, 'Location': {'Latitude': -36.3999, 'Longitude': 144.737}}
# {'Confidence': 91, 'Location': {'Latitude': -36.1748, 'Longitude': 145.7582}}
# {'Confidence': 99, 'Location': {'Latitude': -36.0691, 'Longitude': 145.7797}}
# {'Confidence': 90, 'Location': {'Latitude': -35.1949, 'Longitude': 141.0622}}
# {'Confidence': 100, 'Location': {'Latitude': -36.91, 'Longitude': 141.2705}}
# {'Confidence': 89, 'Location': {'Latitude': -35.8071, 'Longitude': 142.7318}}
# {'Confidence': 97, 'Location': {'Latitude': -36.7787, 'Longitude': 141.4449}}
# {'Confidence': 98, 'Location': {'Latitude': -36.2948, 'Longitude': 141.3486}}
# {'Confidence': 89, 'Location': {'Latitude': -38.1561, 'Longitude': 143.7846}}
# {'Confidence': 90, 'Location': {'Latitude': -37.8185, 'Longitude': 142.5609}}
# {'Confidence': 100, 'Location': {'Latitude': -36.1771, 'Longitude': 145.7451}}
# {'Confidence': 100, 'Location': {'Latitude': -38.027, 'Longitude': 142.3844}}
# {'Confidence': 89, 'Location': {'Latitude': -35.7642, 'Longitude': 143.3321}}
# {'Confidence': 90, 'Location': {'Latitude': -36.429, 'Longitude': 141.5759}}
# {'Confidence': 92, 'Location': {'Latitude': -36.1346, 'Longitude': 145.2196}}
# {'Confidence': 100, 'Location': {'Latitude': -37.0899, 'Longitude': 141.0238}}
# {'Confidence': 95, 'Location': {'Latitude': -36.3823, 'Longitude': 141.3146}}
# {'Confidence': 90, 'Location': {'Latitude': -36.1462, 'Longitude': 145.2096}}
# {'Confidence': 93, 'Location': {'Latitude': -36.5243, 'Longitude': 142.0839}}
# {'Confidence': 98, 'Location': {'Latitude': -37.618, 'Longitude': 143.0013}}
# {'Confidence': 90, 'Location': {'Latitude': -36.8867, 'Longitude': 142.1873}}
# {'Confidence': 92, 'Location': {'Latitude': -36.9364, 'Longitude': 143.4996}}
# {'Confidence': 100, 'Location': {'Latitude': -37.3847, 'Longitude': 142.8935}}
# {'Confidence': 100, 'Location': {'Latitude': -35.6374, 'Longitude': 142.3787}}
# {'Confidence': 90, 'Location': {'Latitude': -36.8835, 'Longitude': 142.2098}}
# {'Confidence': 100, 'Location': {'Latitude': -36.4125, 'Longitude': 143.1189}}
# {'Confidence': 97, 'Location': {'Latitude': -37.0669, 'Longitude': 141.0556}}
# {'Confidence': 92, 'Location': {'Latitude': -36.0714, 'Longitude': 145.7665}}
# {'Confidence': 94, 'Location': {'Latitude': -36.2933, 'Longitude': 141.36}}
# {'Confidence': 100, 'Location': {'Latitude': -37.4591, 'Longitude': 144.9492}}
# {'Confidence': 91, 'Location': {'Latitude': -36.3487, 'Longitude': 145.5315}}
# {'Confidence': 90, 'Location': {'Latitude': -36.5399, 'Longitude': 144.678}}
# {'Confidence': 97, 'Location': {'Latitude': -36.8158, 'Longitude': 142.6229}}
# {'Confidence': 100, 'Location': {'Latitude': -36.4518, 'Longitude': 144.7752}}
# {'Confidence': 90, 'Location': {'Latitude': -36.7903, 'Longitude': 141.618}}
# {'Confidence': 97, 'Location': {'Latitude': -36.1067, 'Longitude': 143.7948}}
# {'Confidence': 89, 'Location': {'Latitude': -36.1441, 'Longitude': 145.2221}}
# {'Confidence': 94, 'Location': {'Latitude': -36.4816, 'Longitude': 141.6635}}
# {'Confidence': 100, 'Location': {'Latitude': -36.0837, 'Longitude': 144.2448}}
# {'Confidence': 90, 'Location': {'Latitude': -36.782, 'Longitude': 141.8851}}
# {'Confidence': 92, 'Location': {'Latitude': -36.5586, 'Longitude': 144.0423}}
# {'Confidence': 90, 'Location': {'Latitude': -36.5568, 'Longitude': 144.0538}}
# {'Confidence': 97, 'Location': {'Latitude': -36.4538, 'Longitude': 144.763}}
# {'Confidence': 91, 'Location': {'Latitude': -36.4612, 'Longitude': 144.7775}}
# {'Confidence': 100, 'Location': {'Latitude': -36.7089, 'Longitude': 143.3518}}
# {'Confidence': 97, 'Location': {'Latitude': -36.601, 'Longitude': 144.6378}}
# {'Confidence': 95, 'Location': {'Latitude': -36.8681, 'Longitude': 143.5186}}
# {'Confidence': 100, 'Location': {'Latitude': -37.1999, 'Longitude': 143.8231}}
# {'Confidence': 91, 'Location': {'Latitude': -37.6171, 'Longitude': 142.9426}}
# {'Confidence': 84, 'Location': {'Latitude': -37.7587, 'Longitude': 142.8521}}
# {'Confidence': 91, 'Location': {'Latitude': -37.4611, 'Longitude': 144.9371}}
# {'Confidence': 100, 'Location': {'Latitude': -38.0254, 'Longitude': 142.3959}}
# {'Confidence': 89, 'Location': {'Latitude': -37.88, 'Longitude': 143.7233}}
# {'Confidence': 99, 'Location': {'Latitude': -37.8885, 'Longitude': 143.9157}}
# {'Confidence': 95, 'Location': {'Latitude': -35.0706, 'Longitude': 141.4435}}
# {'Confidence': 100, 'Location': {'Latitude': -38.0795, 'Longitude': 143.2449}}
# {'Confidence': 100, 'Location': {'Latitude': -35.1857, 'Longitude': 141.0604}}
# {'Confidence': 100, 'Location': {'Latitude': -35.6469, 'Longitude': 142.376}}
# {'Confidence': 91, 'Location': {'Latitude': -35.6453, 'Longitude': 142.387}}
# {'Confidence': 100, 'Location': {'Latitude': -36.4409, 'Longitude': 141.6948}}
# {'Confidence': 100, 'Location': {'Latitude': -37.9174, 'Longitude': 145.8678}}
# {'Confidence': 95, 'Location': {'Latitude': -37.9152, 'Longitude': 145.8808}}
# {'Confidence': 95, 'Location': {'Latitude': -37.8906, 'Longitude': 146.2035}}
# {'Confidence': 100, 'Location': {'Latitude': -35.8182, 'Longitude': 143.8739}}
# {'Confidence': 100, 'Location': {'Latitude': -37.9246, 'Longitude': 146.2464}}
# {'Confidence': 94, 'Location': {'Latitude': -36.3313, 'Longitude': 141.0017}}
# {'Confidence': 90, 'Location': {'Latitude': -36.2857, 'Longitude': 141.3467}}
# {'Confidence': 92, 'Location': {'Latitude': -36.0749, 'Longitude': 143.4058}}
# {'Confidence': 91, 'Location': {'Latitude': -36.4449, 'Longitude': 140.9836}}
# {'Confidence': 100, 'Location': {'Latitude': -36.3972, 'Longitude': 141.6041}}
# {'Confidence': 90, 'Location': {'Latitude': -36.5532, 'Longitude': 142.5349}}
# {'Confidence': 92, 'Location': {'Latitude': -36.1367, 'Longitude': 145.2071}}
# {'Confidence': 96, 'Location': {'Latitude': -36.1518, 'Longitude': 144.0233}}
# {'Confidence': 95, 'Location': {'Latitude': -36.1418, 'Longitude': 144.0261}}
# {'Confidence': 94, 'Location': {'Latitude': -37.5812, 'Longitude': 142.7374}}
# {'Confidence': 100, 'Location': {'Latitude': -37.5949, 'Longitude': 142.6857}}
# {'Confidence': 95, 'Location': {'Latitude': -37.8247, 'Longitude': 143.6243}}
# {'Confidence': 95, 'Location': {'Latitude': -37.4028, 'Longitude': 143.6932}}
# {'Confidence': 92, 'Location': {'Latitude': -37.4033, 'Longitude': 143.6884}}
# {'Confidence': 100, 'Location': {'Latitude': -37.8249, 'Longitude': 143.6174}}
# {'Confidence': 93, 'Location': {'Latitude': -36.6823, 'Longitude': 142.5024}}
# {'Confidence': 93, 'Location': {'Latitude': -36.4489, 'Longitude': 144.7685}}
# {'Confidence': 67, 'Location': {'Latitude': -37.34, 'Longitude': 149.3668}}
# {'Confidence': 99, 'Location': {'Latitude': -36.7287, 'Longitude': 142.6017}}
# {'Confidence': 91, 'Location': {'Latitude': -35.2363, 'Longitude': 143.0004}}
# {'Confidence': 100, 'Location': {'Latitude': -35.2378, 'Longitude': 142.9864}}
# {'Confidence': 98, 'Location': {'Latitude': -35.2381, 'Longitude': 142.994}}
# {'Confidence': 66, 'Location': {'Latitude': -37.3493, 'Longitude': 149.3691}}
# {'Confidence': 90, 'Location': {'Latitude': -36.7165, 'Longitude': 142.6155}}
# {'Confidence': 100, 'Location': {'Latitude': -37.2168, 'Longitude': 147.4748}}
# {'Confidence': 96, 'Location': {'Latitude': -37.222, 'Longitude': 147.4689}}
# {'Confidence': 92, 'Location': {'Latitude': -37.2063, 'Longitude': 147.4713}}
# {'Confidence': 92, 'Location': {'Latitude': -37.2082, 'Longitude': 147.4368}}
# {'Confidence': 95, 'Location': {'Latitude': -37.224, 'Longitude': 147.4347}}
# {'Confidence': 84, 'Location': {'Latitude': -37.5816, 'Longitude': 148.5862}}
# {'Confidence': 92, 'Location': {'Latitude': -36.6334, 'Longitude': 142.2244}}
# {'Confidence': 76, 'Location': {'Latitude': -37.7966, 'Longitude': 142.3196}}
# {'Confidence': 100, 'Location': {'Latitude': -35.805, 'Longitude': 142.1326}}
# {'Confidence': 100, 'Location': {'Latitude': -37.8429, 'Longitude': 143.8366}}
# {'Confidence': 77, 'Location': {'Latitude': -37.8062, 'Longitude': 143.3598}}
# {'Confidence': 100, 'Location': {'Latitude': -36.9918, 'Longitude': 141.8667}}
# {'Confidence': 90, 'Location': {'Latitude': -36.1104, 'Longitude': 145.9829}}
# {'Confidence': 100, 'Location': {'Latitude': -37.782, 'Longitude': 148.3844}}
# {'Confidence': 89, 'Location': {'Latitude': -36.9902, 'Longitude': 141.879}}
# {'Confidence': 89, 'Location': {'Latitude': -37.745, 'Longitude': 142.993}}
# {'Confidence': 92, 'Location': {'Latitude': -36.0157, 'Longitude': 145.9414}}
# {'Confidence': 99, 'Location': {'Latitude': -37.777, 'Longitude': 148.4128}}
# {'Confidence': 93, 'Location': {'Latitude': -37.5888, 'Longitude': 148.5949}}
# {'Confidence': 89, 'Location': {'Latitude': -34.3943, 'Longitude': 141.7567}}
# {'Confidence': 81, 'Location': {'Latitude': -36.0844, 'Longitude': 141.4934}}
# {'Confidence': 91, 'Location': {'Latitude': -36.031, 'Longitude': 145.6824}}
# {'Confidence': 86, 'Location': {'Latitude': -37.5814, 'Longitude': 148.5777}}
# {'Confidence': 90, 'Location': {'Latitude': -37.5788, 'Longitude': 148.592}}
# {'Confidence': 90, 'Location': {'Latitude': -36.6384, 'Longitude': 142.4075}}
# {'Confidence': 94, 'Location': {'Latitude': -35.811, 'Longitude': 142.1403}}
# {'Confidence': 100, 'Location': {'Latitude': -36.9034, 'Longitude': 141.0013}}
# {'Confidence': 88, 'Location': {'Latitude': -37.7746, 'Longitude': 148.3673}}
# {'Confidence': 83, 'Location': {'Latitude': -37.803, 'Longitude': 142.3151}}
# {'Confidence': 96, 'Location': {'Latitude': -37.7542, 'Longitude': 142.9949}}
# {'Confidence': 91, 'Location': {'Latitude': -37.3803, 'Longitude': 145.611}}
# {'Confidence': 97, 'Location': {'Latitude': -37.7617, 'Longitude': 143.081}}
# {'Confidence': 92, 'Location': {'Latitude': -37.8161, 'Longitude': 142.9286}}
# {'Confidence': 90, 'Location': {'Latitude': -36.0387, 'Longitude': 145.6787}}
# {'Confidence': 94, 'Location': {'Latitude': -36.6349, 'Longitude': 142.2125}}
# {'Confidence': 100, 'Location': {'Latitude': -36.9018, 'Longitude': 141.0146}}
# {'Confidence': 86, 'Location': {'Latitude': -36.6986, 'Longitude': 142.7259}}
# {'Confidence': 94, 'Location': {'Latitude': -38.0052, 'Longitude': 142.6179}}
# {'Confidence': 87, 'Location': {'Latitude': -37.6387, 'Longitude': 142.9032}}
# {'Confidence': 93, 'Location': {'Latitude': -37.6439, 'Longitude': 142.913}}
# {'Confidence': 93, 'Location': {'Latitude': -37.3165, 'Longitude': 147.4932}}
# {'Confidence': 95, 'Location': {'Latitude': -37.3158, 'Longitude': 147.4986}}
# {'Confidence': 89, 'Location': {'Latitude': -37.4471, 'Longitude': 147.6331}}
# {'Confidence': 90, 'Location': {'Latitude': -37.7835, 'Longitude': 148.4138}}
# {'Confidence': 89, 'Location': {'Latitude': -37.4449, 'Longitude': 147.6594}}
# {'Confidence': 95, 'Location': {'Latitude': -37.4323, 'Longitude': 147.6583}}
# {'Confidence': 100, 'Location': {'Latitude': -37.4343, 'Longitude': 147.6327}}
# {'Confidence': 90, 'Location': {'Latitude': -35.4033, 'Longitude': 143.267}}
# {'Confidence': 64, 'Location': {'Latitude': -36.6281, 'Longitude': 142.4349}}
# {'Confidence': 85, 'Location': {'Latitude': -36.111, 'Longitude': 145.124}}
# {'Confidence': 90, 'Location': {'Latitude': -36.1615, 'Longitude': 141.8728}}
# {'Confidence': 90, 'Location': {'Latitude': -36.1122, 'Longitude': 142.1491}}
# {'Confidence': 100, 'Location': {'Latitude': -37.3735, 'Longitude': 145.8384}}
# {'Confidence': 89, 'Location': {'Latitude': -35.4255, 'Longitude': 143.6306}}
# {'Confidence': 96, 'Location': {'Latitude': -36.1955, 'Longitude': 145.914}}
# {'Confidence': 85, 'Location': {'Latitude': -35.4533, 'Longitude': 143.2029}}
# {'Confidence': 92, 'Location': {'Latitude': -36.5989, 'Longitude': 141.9771}}
# {'Confidence': 66, 'Location': {'Latitude': -36.6299, 'Longitude': 142.4234}}
# {'Confidence': 97, 'Location': {'Latitude': -36.1925, 'Longitude': 145.93}}
# {'Confidence': 98, 'Location': {'Latitude': -36.095, 'Longitude': 141.7699}}
# {'Confidence': 96, 'Location': {'Latitude': -36.6006, 'Longitude': 141.9657}}
# {'Confidence': 93, 'Location': {'Latitude': -37.0769, 'Longitude': 141.042}}
# {'Confidence': 79, 'Location': {'Latitude': -36.883, 'Longitude': 142.1637}}
# {'Confidence': 87, 'Location': {'Latitude': -36.0973, 'Longitude': 143.4279}}
# {'Confidence': 100, 'Location': {'Latitude': -36.1819, 'Longitude': 145.9269}}
# {'Confidence': 87, 'Location': {'Latitude': -37.3735, 'Longitude': 145.886}}
# {'Confidence': 93, 'Location': {'Latitude': -37.7465, 'Longitude': 143.3806}}
# {'Confidence': 95, 'Location': {'Latitude': -37.8072, 'Longitude': 145.9738}}
# {'Confidence': 96, 'Location': {'Latitude': -37.3704, 'Longitude': 145.8942}}
# {'Confidence': 100, 'Location': {'Latitude': -37.297, 'Longitude': 143.5753}}
# {'Confidence': 100, 'Location': {'Latitude': -37.2988, 'Longitude': 143.5487}}
# {'Confidence': 100, 'Location': {'Latitude': -37.3025, 'Longitude': 143.5714}}
# {'Confidence': 100, 'Location': {'Latitude': -37.383, 'Longitude': 145.9089}}
# {'Confidence': 89, 'Location': {'Latitude': -37.7446, 'Longitude': 143.4085}}
# {'Confidence': 98, 'Location': {'Latitude': -37.7509, 'Longitude': 143.4023}}
# {'Confidence': 87, 'Location': {'Latitude': -37.7974, 'Longitude': 145.9535}}
# {'Confidence': 90, 'Location': {'Latitude': -35.7657, 'Longitude': 142.0906}}
# {'Confidence': 99, 'Location': {'Latitude': -37.7236, 'Longitude': 143.3995}}
# {'Confidence': 93, 'Location': {'Latitude': -37.3046, 'Longitude': 143.5448}}
# {'Confidence': 95, 'Location': {'Latitude': -36.4312, 'Longitude': 141.2064}}
# {'Confidence': 89, 'Location': {'Latitude': -36.1556, 'Longitude': 141.5904}}
# {'Confidence': 89, 'Location': {'Latitude': -35.7647, 'Longitude': 142.0858}}
# {'Confidence': 92, 'Location': {'Latitude': -36.4557, 'Longitude': 142.2434}}
# {'Confidence': 95, 'Location': {'Latitude': -36.8009, 'Longitude': 142.7259}}
# {'Confidence': 93, 'Location': {'Latitude': -36.8099, 'Longitude': 142.728}}
# {'Confidence': 94, 'Location': {'Latitude': -36.7806, 'Longitude': 141.5597}}
# {'Confidence': 98, 'Location': {'Latitude': -34.3526, 'Longitude': 141.6458}}
# {'Confidence': 97, 'Location': {'Latitude': -37.0924, 'Longitude': 141.897}}
# {'Confidence': 97, 'Location': {'Latitude': -37.9452, 'Longitude': 143.5834}}
# {'Confidence': 99, 'Location': {'Latitude': -34.351, 'Longitude': 141.6567}}
# {'Confidence': 100, 'Location': {'Latitude': -37.5012, 'Longitude': 142.5853}}
# {'Confidence': 97, 'Location': {'Latitude': -37.9247, 'Longitude': 142.8999}}
# {'Confidence': 97, 'Location': {'Latitude': -35.0805, 'Longitude': 142.4642}}
# {'Confidence': 71, 'Location': {'Latitude': -37.522, 'Longitude': 143.3874}}
# {'Confidence': 91, 'Location': {'Latitude': -38.0674, 'Longitude': 142.965}}
# {'Confidence': 92, 'Location': {'Latitude': -38.0715, 'Longitude': 142.9591}}
# {'Confidence': 100, 'Location': {'Latitude': -38.0693, 'Longitude': 142.9722}}
# {'Confidence': 82, 'Location': {'Latitude': -37.8973, 'Longitude': 143.4754}}
# {'Confidence': 95, 'Location': {'Latitude': -37.7805, 'Longitude': 143.5003}}
# {'Confidence': 95, 'Location': {'Latitude': -37.8774, 'Longitude': 145.8213}}
# {'Confidence': 100, 'Location': {'Latitude': -37.8881, 'Longitude': 145.8229}}
# {'Confidence': 96, 'Location': {'Latitude': -37.6622, 'Longitude': 142.1001}}
# {'Confidence': 90, 'Location': {'Latitude': -37.4523, 'Longitude': 147.0175}}
# {'Confidence': 98, 'Location': {'Latitude': -37.4261, 'Longitude': 147.0323}}
# {'Confidence': 100, 'Location': {'Latitude': -37.3949, 'Longitude': 147.0175}}
# {'Confidence': 92, 'Location': {'Latitude': -37.6625, 'Longitude': 144.287}}
# {'Confidence': 97, 'Location': {'Latitude': -37.0155, 'Longitude': 148.1432}}
# {'Confidence': 94, 'Location': {'Latitude': -36.7152, 'Longitude': 141.3853}}
# {'Confidence': 90, 'Location': {'Latitude': -34.357, 'Longitude': 141.5361}}
# {'Confidence': 93, 'Location': {'Latitude': -34.3539, 'Longitude': 141.5547}}
# {'Confidence': 90, 'Location': {'Latitude': -36.9939, 'Longitude': 148.2244}}
# {'Confidence': 95, 'Location': {'Latitude': -36.9959, 'Longitude': 148.2118}}
# {'Confidence': 89, 'Location': {'Latitude': -34.3654, 'Longitude': 141.543}}
# {'Confidence': 96, 'Location': {'Latitude': -34.3554, 'Longitude': 141.5413}}
# {'Confidence': 94, 'Location': {'Latitude': -34.3555, 'Longitude': 141.5495}}
# {'Confidence': 84, 'Location': {'Latitude': -37.0193, 'Longitude': 148.1459}}
# {'Confidence': 100, 'Location': {'Latitude': -37.4229, 'Longitude': 147.027}}
# {'Confidence': 80, 'Location': {'Latitude': -37.0055, 'Longitude': 148.1582}}
# {'Confidence': 85, 'Location': {'Latitude': -37.4128, 'Longitude': 147.0242}}
# {'Confidence': 94, 'Location': {'Latitude': -37.2284, 'Longitude': 147.9187}}
# {'Confidence': 97, 'Location': {'Latitude': -37.6572, 'Longitude': 142.0703}}

# %% [markdown]
# ### A4. Find *surface temperature (°C), air temperature (°C), relative humidity* and *maximum wind speed* on *15th and 16th of December 2017*.

# %%
pipline =[{"$unwind":"$Fires"},
          {"$match":{"$or": [{"Date":{"$eq":"2017-12-15"} },
                             {"Date":{"$eq":"2017-12-16"} }]}},
          {"$lookup":{"from":"fire",
                      "localField":"Fires",
                      "foreignField":"_id",
                      "as": "Fire_data"}},
          {"$project":{"_id":0, "Date":1, "Fire_data.SurfaceTemperature.Celcius":1, "AirTemperature":1,
                       "RelativeHumidity":1, "MaxWindSpeed":1}} #-deltele for checking-,"Fire_data.Datetime":1}}
          ]
result_A4 = climateCollection.aggregate(pipline)
for i in result_A4:
    pprint(i)
# Out:
# {'AirTemperature': 18,
#  'Date': '2017-12-15',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 36}}],
#  'MaxWindSpeed': 14.0,
#  'RelativeHumidity': 52.0}
# {'AirTemperature': 18,
#  'Date': '2017-12-15',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 38}}],
#  'MaxWindSpeed': 14.0,
#  'RelativeHumidity': 52.0}
# {'AirTemperature': 18,
#  'Date': '2017-12-15',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 40}}],
#  'MaxWindSpeed': 14.0,
#  'RelativeHumidity': 52.0}
# {'AirTemperature': 18,
#  'Date': '2017-12-15',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 42}}],
#  'MaxWindSpeed': 14.0,
#  'RelativeHumidity': 52.0}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 43}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 33}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 54}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 73}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 55}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 75}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 55}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 66}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 56}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 60}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 73}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 48}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 55}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 64}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}
# {'AirTemperature': 18,
#  'Date': '2017-12-16',
#  'Fire_data': [{'SurfaceTemperature': {'Celcius': 57}}],
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7}

# %% [markdown]
# ### A5. Find *datetime, air temperature (°C), surface temperature (°C)* and *confidence* when the *confidence* is between *80* and *100*.

# %%
pipline =[{"$unwind":"$Fires"},
          {"$lookup":{"from":"fire",
                      "localField":"Fires",
                      "foreignField":"_id",
                      "as": "Fire_data"}},
          {"$match":{"$and": [{"Fire_data.Confidence":{"$gte":80} },
                              {"Fire_data.Confidence":{"$lte":100} }]}},
          {"$project":{"_id":0, #delete to check "Date":1,  
                       "Fire_data.Datetime":1, "AirTemperature":1,
                       "Fire_data.SurfaceTemperature.Celcius":1, "Fire_data.Confidence":1
                       }} #-deltele for checking-,"Fire_data.Datetime":1}}
          ]
result_A5 = climateCollection.aggregate(pipline)
for i in result_A5:
    pprint(i)
# Out:
# {'AirTemperature': 20,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-03-06T05:06:30',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 20,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-03-06T05:06:20',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-03-07T04:16:10',
#                 'SurfaceTemperature': {'Celcius': 64}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-03-09T13:23:40',
#                 'SurfaceTemperature': {'Celcius': 41}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 97,
#                 'Datetime': '2017-03-10T04:45:30',
#                 'SurfaceTemperature': {'Celcius': 80}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-03-10T04:43:50',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-10T04:48:40',
#                 'SurfaceTemperature': {'Celcius': 105}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-10T04:46:20',
#                 'SurfaceTemperature': {'Celcius': 109}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 94,
#                 'Datetime': '2017-03-10T04:45:30',
#                 'SurfaceTemperature': {'Celcius': 73}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 94,
#                 'Datetime': '2017-03-12T04:33:50',
#                 'SurfaceTemperature': {'Celcius': 105}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-03-12T04:29:50',
#                 'SurfaceTemperature': {'Celcius': 71}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-12T04:28:20',
#                 'SurfaceTemperature': {'Celcius': 99}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-03-12T04:28:00',
#                 'SurfaceTemperature': {'Celcius': 68}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-03-12T04:27:20',
#                 'SurfaceTemperature': {'Celcius': 98}}]}
# {'AirTemperature': 25,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-03-14T04:24:40',
#                 'SurfaceTemperature': {'Celcius': 67}}]}
# {'AirTemperature': 25,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-03-14T04:22:20',
#                 'SurfaceTemperature': {'Celcius': 72}}]}
# {'AirTemperature': 25,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-03-14T04:20:50',
#                 'SurfaceTemperature': {'Celcius': 68}}]}
# {'AirTemperature': 25,
#  'Fire_data': [{'Confidence': 95,
#                 'Datetime': '2017-03-14T04:16:30',
#                 'SurfaceTemperature': {'Celcius': 75}}]}
# {'AirTemperature': 25,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-03-14T04:16:20',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 25,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-03-14T04:14:40',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 25,
#  'Fire_data': [{'Confidence': 96,
#                 'Datetime': '2017-03-14T04:14:30',
#                 'SurfaceTemperature': {'Celcius': 79}}]}
# {'AirTemperature': 25,
#  'Fire_data': [{'Confidence': 94,
#                 'Datetime': '2017-03-14T04:14:30',
#                 'SurfaceTemperature': {'Celcius': 75}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 94,
#                 'Datetime': '2017-03-17T04:48:20',
#                 'SurfaceTemperature': {'Celcius': 74}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-03-17T04:45:10',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-03-17T04:45:00',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-18T03:50:50',
#                 'SurfaceTemperature': {'Celcius': 121}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 97,
#                 'Datetime': '2017-03-18T03:50:40',
#                 'SurfaceTemperature': {'Celcius': 80}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-03-19T04:39:50',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 96,
#                 'Datetime': '2017-03-19T04:39:20',
#                 'SurfaceTemperature': {'Celcius': 79}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-03-19T04:36:00',
#                 'SurfaceTemperature': {'Celcius': 66}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 98,
#                 'Datetime': '2017-03-19T04:33:00',
#                 'SurfaceTemperature': {'Celcius': 83}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-19T04:32:50',
#                 'SurfaceTemperature': {'Celcius': 91}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-03-19T04:32:50',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-19T04:32:40',
#                 'SurfaceTemperature': {'Celcius': 113}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-03-19T04:32:40',
#                 'SurfaceTemperature': {'Celcius': 70}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-19T04:32:40',
#                 'SurfaceTemperature': {'Celcius': 106}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 95,
#                 'Datetime': '2017-03-25T03:57:10',
#                 'SurfaceTemperature': {'Celcius': 77}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-25T03:56:40',
#                 'SurfaceTemperature': {'Celcius': 99}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-03-25T03:59:50',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-03-25T03:58:10',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 95,
#                 'Datetime': '2017-03-25T03:58:10',
#                 'SurfaceTemperature': {'Celcius': 75}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-03-25T03:57:10',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-25T03:57:10',
#                 'SurfaceTemperature': {'Celcius': 111}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-03-26T04:43:20',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-03-26T04:40:50',
#                 'SurfaceTemperature': {'Celcius': 53}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-03-26T04:39:50',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 91,
#                 'Datetime': '2017-03-26T04:39:10',
#                 'SurfaceTemperature': {'Celcius': 68}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-03-26T04:39:10',
#                 'SurfaceTemperature': {'Celcius': 70}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-26T04:39:10',
#                 'SurfaceTemperature': {'Celcius': 89}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-03-26T04:39:10',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-03-26T04:39:10',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-03-26T04:39:10',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 97,
#                 'Datetime': '2017-03-28T04:26:50',
#                 'SurfaceTemperature': {'Celcius': 81}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-03-28T04:26:50',
#                 'SurfaceTemperature': {'Celcius': 57}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-03-28T04:26:50',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-03-28T04:38:00',
#                 'SurfaceTemperature': {'Celcius': 64}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-03-28T04:33:40',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-03-28T04:33:30',
#                 'SurfaceTemperature': {'Celcius': 71}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 95,
#                 'Datetime': '2017-03-28T04:33:30',
#                 'SurfaceTemperature': {'Celcius': 76}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-03-28T04:32:20',
#                 'SurfaceTemperature': {'Celcius': 73}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-03-28T04:30:50',
#                 'SurfaceTemperature': {'Celcius': 56}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-03-28T04:30:20',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 94,
#                 'Datetime': '2017-03-28T04:30:10',
#                 'SurfaceTemperature': {'Celcius': 74}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 98,
#                 'Datetime': '2017-03-28T04:30:10',
#                 'SurfaceTemperature': {'Celcius': 82}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-03-28T04:30:10',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 97,
#                 'Datetime': '2017-03-28T04:30:10',
#                 'SurfaceTemperature': {'Celcius': 80}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-03-28T04:28:30',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-03-28T04:28:30',
#                 'SurfaceTemperature': {'Celcius': 63}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-03-28T04:28:30',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 97,
#                 'Datetime': '2017-03-28T04:27:40',
#                 'SurfaceTemperature': {'Celcius': 80}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-28T04:27:20',
#                 'SurfaceTemperature': {'Celcius': 107}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-28T04:27:10',
#                 'SurfaceTemperature': {'Celcius': 108}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-03-28T04:27:00',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 99,
#                 'Datetime': '2017-03-28T04:27:00',
#                 'SurfaceTemperature': {'Celcius': 86}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-03-28T04:26:50',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-03-28T04:26:50',
#                 'SurfaceTemperature': {'Celcius': 53}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-03-28T04:26:50',
#                 'SurfaceTemperature': {'Celcius': 57}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-28T04:26:50',
#                 'SurfaceTemperature': {'Celcius': 90}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-03-28T04:26:50',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 97,
#                 'Datetime': '2017-03-28T04:26:50',
#                 'SurfaceTemperature': {'Celcius': 81}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-03-28T04:26:50',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-03-28T04:26:50',
#                 'SurfaceTemperature': {'Celcius': 63}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-03-28T04:26:50',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-03-28T04:26:50',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-03-31T05:07:10',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-03-31T05:01:20',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-03-31T04:58:30',
#                 'SurfaceTemperature': {'Celcius': 56}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-03-31T04:58:00',
#                 'SurfaceTemperature': {'Celcius': 53}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-03-31T04:57:10',
#                 'SurfaceTemperature': {'Celcius': 61}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-03-31T00:36:30',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-04-03T03:52:10',
#                 'SurfaceTemperature': {'Celcius': 61}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-03T03:52:10',
#                 'SurfaceTemperature': {'Celcius': 98}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-03T03:52:10',
#                 'SurfaceTemperature': {'Celcius': 89}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-04-03T03:52:10',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-04-03T03:51:30',
#                 'SurfaceTemperature': {'Celcius': 63}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-04-03T03:51:30',
#                 'SurfaceTemperature': {'Celcius': 66}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-04-03T03:51:10',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-03T03:51:00',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 98,
#                 'Datetime': '2017-04-03T03:51:00',
#                 'SurfaceTemperature': {'Celcius': 82}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-04-03T03:51:00',
#                 'SurfaceTemperature': {'Celcius': 53}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-03T03:51:00',
#                 'SurfaceTemperature': {'Celcius': 103}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-04-03T03:50:50',
#                 'SurfaceTemperature': {'Celcius': 97}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-04-03T03:50:50',
#                 'SurfaceTemperature': {'Celcius': 66}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-04-03T03:50:40',
#                 'SurfaceTemperature': {'Celcius': 61}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 99,
#                 'Datetime': '2017-04-03T03:50:40',
#                 'SurfaceTemperature': {'Celcius': 86}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-04-03T03:50:40',
#                 'SurfaceTemperature': {'Celcius': 72}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 95,
#                 'Datetime': '2017-04-03T03:50:40',
#                 'SurfaceTemperature': {'Celcius': 76}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-04-03T03:50:40',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-04-03T03:50:40',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-04-03T03:50:40',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-04-03T03:50:40',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-03T01:07:20',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 91,
#                 'Datetime': '2017-04-03T13:17:00',
#                 'SurfaceTemperature': {'Celcius': 43}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-04-03T13:15:30',
#                 'SurfaceTemperature': {'Celcius': 40}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-03T13:15:10',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 96,
#                 'Datetime': '2017-04-03T13:15:10',
#                 'SurfaceTemperature': {'Celcius': 45}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-04-03T03:59:10',
#                 'SurfaceTemperature': {'Celcius': 96}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-04-03T03:57:50',
#                 'SurfaceTemperature': {'Celcius': 72}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-04-03T03:56:20',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-04-03T03:55:10',
#                 'SurfaceTemperature': {'Celcius': 64}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 95,
#                 'Datetime': '2017-04-03T03:55:10',
#                 'SurfaceTemperature': {'Celcius': 77}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 96,
#                 'Datetime': '2017-04-03T03:54:00',
#                 'SurfaceTemperature': {'Celcius': 78}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-03T03:53:50',
#                 'SurfaceTemperature': {'Celcius': 93}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-04-03T03:53:30',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-04-03T03:52:30',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-03T03:52:30',
#                 'SurfaceTemperature': {'Celcius': 90}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-03T03:52:20',
#                 'SurfaceTemperature': {'Celcius': 115}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-04-04T15:31:00',
#                 'SurfaceTemperature': {'Celcius': 44}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-04T15:30:40',
#                 'SurfaceTemperature': {'Celcius': 64}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-04-04T04:41:50',
#                 'SurfaceTemperature': {'Celcius': 63}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-04-04T04:41:10',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-04-04T04:41:00',
#                 'SurfaceTemperature': {'Celcius': 64}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-04-04T04:41:00',
#                 'SurfaceTemperature': {'Celcius': 61}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-04T04:40:00',
#                 'SurfaceTemperature': {'Celcius': 120}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-04-04T04:39:50',
#                 'SurfaceTemperature': {'Celcius': 67}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-04-04T04:39:50',
#                 'SurfaceTemperature': {'Celcius': 66}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-04-04T04:39:40',
#                 'SurfaceTemperature': {'Celcius': 66}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-04T04:39:40',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-04T04:39:20',
#                 'SurfaceTemperature': {'Celcius': 107}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-04-04T04:37:10',
#                 'SurfaceTemperature': {'Celcius': 64}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-04-04T04:36:10',
#                 'SurfaceTemperature': {'Celcius': 63}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-04-04T04:36:10',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-04-04T04:36:00',
#                 'SurfaceTemperature': {'Celcius': 76}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-04T04:35:00',
#                 'SurfaceTemperature': {'Celcius': 95}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-04-04T04:34:50',
#                 'SurfaceTemperature': {'Celcius': 57}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-04-04T04:34:20',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 96,
#                 'Datetime': '2017-04-04T04:34:20',
#                 'SurfaceTemperature': {'Celcius': 78}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-04-04T04:34:20',
#                 'SurfaceTemperature': {'Celcius': 66}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-04-04T04:34:00',
#                 'SurfaceTemperature': {'Celcius': 57}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-04-04T04:33:50',
#                 'SurfaceTemperature': {'Celcius': 81}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-04T04:33:40',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-04T04:33:30',
#                 'SurfaceTemperature': {'Celcius': 113}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-04-04T04:33:30',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-04-04T04:33:30',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-04-04T04:33:10',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-04-04T04:33:10',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 97,
#                 'Datetime': '2017-04-04T04:33:00',
#                 'SurfaceTemperature': {'Celcius': 79}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-04-04T04:33:00',
#                 'SurfaceTemperature': {'Celcius': 61}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 98,
#                 'Datetime': '2017-04-04T04:32:50',
#                 'SurfaceTemperature': {'Celcius': 82}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-04-04T04:32:50',
#                 'SurfaceTemperature': {'Celcius': 61}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-04-04T04:32:50',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-04-04T04:32:50',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-04T04:32:50',
#                 'SurfaceTemperature': {'Celcius': 123}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-04-04T04:32:50',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-04T04:32:50',
#                 'SurfaceTemperature': {'Celcius': 118}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-04-04T04:32:40',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 96,
#                 'Datetime': '2017-04-04T04:32:40',
#                 'SurfaceTemperature': {'Celcius': 78}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-04-04T04:32:40',
#                 'SurfaceTemperature': {'Celcius': 72}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-04T04:32:40',
#                 'SurfaceTemperature': {'Celcius': 120}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-04-04T04:32:40',
#                 'SurfaceTemperature': {'Celcius': 92}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-04T04:32:40',
#                 'SurfaceTemperature': {'Celcius': 101}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-04T04:32:40',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-04T04:32:40',
#                 'SurfaceTemperature': {'Celcius': 98}}]}
# {'AirTemperature': 16,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-04-04T00:12:50',
#                 'SurfaceTemperature': {'Celcius': 53}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-04-05T03:39:10',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-04-05T03:39:10',
#                 'SurfaceTemperature': {'Celcius': 64}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 95,
#                 'Datetime': '2017-04-05T03:39:10',
#                 'SurfaceTemperature': {'Celcius': 76}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-05T03:39:10',
#                 'SurfaceTemperature': {'Celcius': 92}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-04-05T03:39:10',
#                 'SurfaceTemperature': {'Celcius': 63}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-04-05T03:39:10',
#                 'SurfaceTemperature': {'Celcius': 64}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-05T13:09:00',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-05T13:09:00',
#                 'SurfaceTemperature': {'Celcius': 39}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-04-05T13:08:40',
#                 'SurfaceTemperature': {'Celcius': 44}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-05T13:08:40',
#                 'SurfaceTemperature': {'Celcius': 47}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-04-05T13:07:00',
#                 'SurfaceTemperature': {'Celcius': 40}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-05T13:04:20',
#                 'SurfaceTemperature': {'Celcius': 49}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-05T13:03:20',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 98,
#                 'Datetime': '2017-04-05T13:03:00',
#                 'SurfaceTemperature': {'Celcius': 45}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-05T13:03:00',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-05T13:03:00',
#                 'SurfaceTemperature': {'Celcius': 39}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-04-05T13:02:40',
#                 'SurfaceTemperature': {'Celcius': 42}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-04-05T13:02:40',
#                 'SurfaceTemperature': {'Celcius': 39}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-04-05T05:16:50',
#                 'SurfaceTemperature': {'Celcius': 88}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-04-05T05:15:30',
#                 'SurfaceTemperature': {'Celcius': 83}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-04-05T03:40:50',
#                 'SurfaceTemperature': {'Celcius': 72}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 95,
#                 'Datetime': '2017-04-05T03:40:30',
#                 'SurfaceTemperature': {'Celcius': 76}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-05T03:40:20',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-04-05T03:39:30',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-04-05T03:39:30',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-04-05T03:39:20',
#                 'SurfaceTemperature': {'Celcius': 66}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-04-05T03:39:20',
#                 'SurfaceTemperature': {'Celcius': 56}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 97,
#                 'Datetime': '2017-04-06T13:45:30',
#                 'SurfaceTemperature': {'Celcius': 45}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-04-06T04:32:20',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-04-06T04:31:10',
#                 'SurfaceTemperature': {'Celcius': 69}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-06T04:27:50',
#                 'SurfaceTemperature': {'Celcius': 95}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-06T04:27:50',
#                 'SurfaceTemperature': {'Celcius': 88}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-06T04:27:10',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-06T04:27:00',
#                 'SurfaceTemperature': {'Celcius': 97}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-04-06T04:27:00',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-04-06T04:27:00',
#                 'SurfaceTemperature': {'Celcius': 76}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-06T04:27:00',
#                 'SurfaceTemperature': {'Celcius': 99}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-04-06T04:27:00',
#                 'SurfaceTemperature': {'Celcius': 57}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-04-06T04:24:40',
#                 'SurfaceTemperature': {'Celcius': 64}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-04-06T04:24:20',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-04-06T04:24:20',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-04-06T04:24:00',
#                 'SurfaceTemperature': {'Celcius': 64}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-04-06T04:23:50',
#                 'SurfaceTemperature': {'Celcius': 70}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 99,
#                 'Datetime': '2017-04-06T04:23:50',
#                 'SurfaceTemperature': {'Celcius': 85}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-04-06T04:23:30',
#                 'SurfaceTemperature': {'Celcius': 72}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-04-06T04:23:10',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-04-06T04:23:00',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-04-06T04:22:40',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-04-06T04:22:20',
#                 'SurfaceTemperature': {'Celcius': 56}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-06T04:22:20',
#                 'SurfaceTemperature': {'Celcius': 71}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-04-06T04:22:20',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-06T04:22:20',
#                 'SurfaceTemperature': {'Celcius': 103}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 91,
#                 'Datetime': '2017-04-06T04:22:20',
#                 'SurfaceTemperature': {'Celcius': 69}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-04-06T04:22:10',
#                 'SurfaceTemperature': {'Celcius': 68}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-04-06T04:22:10',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-04-06T04:22:10',
#                 'SurfaceTemperature': {'Celcius': 67}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-04-06T04:21:30',
#                 'SurfaceTemperature': {'Celcius': 66}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 94,
#                 'Datetime': '2017-04-06T04:21:10',
#                 'SurfaceTemperature': {'Celcius': 96}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-06T04:21:00',
#                 'SurfaceTemperature': {'Celcius': 115}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-04-06T04:21:00',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-06T04:20:50',
#                 'SurfaceTemperature': {'Celcius': 95}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-04-06T04:20:50',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-04-06T04:20:50',
#                 'SurfaceTemperature': {'Celcius': 63}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 78}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 96,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 77}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 91,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 68}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 97,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 81}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 56}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 94,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 104}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 71}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 61}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 53}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 67}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 94,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 86}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 57}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 100}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 72}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 57}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 94,
#                 'Datetime': '2017-04-06T04:20:40',
#                 'SurfaceTemperature': {'Celcius': 89}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-04-07T12:56:50',
#                 'SurfaceTemperature': {'Celcius': 41}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-04-07T12:56:30',
#                 'SurfaceTemperature': {'Celcius': 39}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 94,
#                 'Datetime': '2017-04-07T12:56:30',
#                 'SurfaceTemperature': {'Celcius': 49}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-04-07T12:53:40',
#                 'SurfaceTemperature': {'Celcius': 41}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-04-07T12:52:10',
#                 'SurfaceTemperature': {'Celcius': 41}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 97,
#                 'Datetime': '2017-04-07T12:51:20',
#                 'SurfaceTemperature': {'Celcius': 45}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-07T12:51:00',
#                 'SurfaceTemperature': {'Celcius': 49}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-04-07T12:50:50',
#                 'SurfaceTemperature': {'Celcius': 43}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-04-07T12:50:40',
#                 'SurfaceTemperature': {'Celcius': 42}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-04-07T05:09:50',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-04-07T05:03:10',
#                 'SurfaceTemperature': {'Celcius': 53}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-07T05:03:10',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-07T03:31:40',
#                 'SurfaceTemperature': {'Celcius': 89}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 96,
#                 'Datetime': '2017-04-07T03:28:20',
#                 'SurfaceTemperature': {'Celcius': 78}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-04-07T03:27:30',
#                 'SurfaceTemperature': {'Celcius': 70}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-04-07T03:27:20',
#                 'SurfaceTemperature': {'Celcius': 70}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 95,
#                 'Datetime': '2017-04-07T03:27:20',
#                 'SurfaceTemperature': {'Celcius': 76}}]}
# {'AirTemperature': 21,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-07T03:27:10',
#                 'SurfaceTemperature': {'Celcius': 106}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 99,
#                 'Datetime': '2017-04-08T04:14:00',
#                 'SurfaceTemperature': {'Celcius': 85}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 91,
#                 'Datetime': '2017-04-08T04:12:50',
#                 'SurfaceTemperature': {'Celcius': 69}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-08T04:12:20',
#                 'SurfaceTemperature': {'Celcius': 94}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-04-08T04:12:00',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 98,
#                 'Datetime': '2017-04-08T04:08:50',
#                 'SurfaceTemperature': {'Celcius': 83}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-04-08T04:08:30',
#                 'SurfaceTemperature': {'Celcius': 66}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-04-08T04:08:30',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-04-08T04:08:30',
#                 'SurfaceTemperature': {'Celcius': 53}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-04-08T04:08:30',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-04-11T04:39:20',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-04-11T04:39:00',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-04-11T04:39:00',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-04-12T03:44:40',
#                 'SurfaceTemperature': {'Celcius': 71}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-04-12T03:44:40',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 93,
# ...
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-10-01T04:10:28',
#                 'SurfaceTemperature': {'Celcius': 52}}]}
# {'AirTemperature': 12,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-10-01T04:10:28',
#                 'SurfaceTemperature': {'Celcius': 61}}]}
# {'AirTemperature': 11,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-10-02T04:53:10',
#                 'SurfaceTemperature': {'Celcius': 50}}]}
# {'AirTemperature': 11,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-10-02T04:53:09',
#                 'SurfaceTemperature': {'Celcius': 61}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-10-03T13:23:43',
#                 'SurfaceTemperature': {'Celcius': 42}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-10-03T03:58:15',
#                 'SurfaceTemperature': {'Celcius': 63}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-10-03T03:58:15',
#                 'SurfaceTemperature': {'Celcius': 48}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-10-03T03:58:15',
#                 'SurfaceTemperature': {'Celcius': 49}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-10-03T03:58:15',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-10-03T03:58:15',
#                 'SurfaceTemperature': {'Celcius': 63}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-10-03T03:58:14',
#                 'SurfaceTemperature': {'Celcius': 90}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-10-03T03:58:14',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-10-03T03:58:14',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-10-04T04:41:02',
#                 'SurfaceTemperature': {'Celcius': 46}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-10-04T04:41:00',
#                 'SurfaceTemperature': {'Celcius': 46}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-10-04T04:41:00',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 19,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-10-04T04:41:00',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 91,
#                 'Datetime': '2017-10-07T12:59:33',
#                 'SurfaceTemperature': {'Celcius': 42}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 96,
#                 'Datetime': '2017-10-10T04:04:19',
#                 'SurfaceTemperature': {'Celcius': 77}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-10-15T04:23:01',
#                 'SurfaceTemperature': {'Celcius': 87}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 99,
#                 'Datetime': '2017-10-15T04:23:01',
#                 'SurfaceTemperature': {'Celcius': 85}}]}
# {'AirTemperature': 22,
#  'Fire_data': [{'Confidence': 94,
#                 'Datetime': '2017-10-17T13:36:12',
#                 'SurfaceTemperature': {'Celcius': 43}}]}
# {'AirTemperature': 22,
#  'Fire_data': [{'Confidence': 91,
#                 'Datetime': '2017-10-17T04:10:45',
#                 'SurfaceTemperature': {'Celcius': 68}}]}
# {'AirTemperature': 22,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-10-17T04:10:32',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-10-18T00:39:02',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-10-18T00:39:02',
#                 'SurfaceTemperature': {'Celcius': 56}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-10-20T04:41:19',
#                 'SurfaceTemperature': {'Celcius': 46}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-10-20T04:41:19',
#                 'SurfaceTemperature': {'Celcius': 50}}]}
# {'AirTemperature': 12,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-10-21T01:09:54',
#                 'SurfaceTemperature': {'Celcius': 67}}]}
# {'AirTemperature': 12,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-10-21T01:09:55',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-10-26T13:30:31',
#                 'SurfaceTemperature': {'Celcius': 48}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-10-26T13:30:31',
#                 'SurfaceTemperature': {'Celcius': 53}}]}
# {'AirTemperature': 22,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-10-27T04:47:31',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-10-28T03:52:17',
#                 'SurfaceTemperature': {'Celcius': 56}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-11-05T04:41:19',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-11-05T04:41:19',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 13,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-11-05T04:41:34',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-11-09T04:16:48',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-11-09T04:16:48',
#                 'SurfaceTemperature': {'Celcius': 93}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 96,
#                 'Datetime': '2017-11-09T04:16:48',
#                 'SurfaceTemperature': {'Celcius': 77}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-11-09T04:16:44',
#                 'SurfaceTemperature': {'Celcius': 62}}]}
# {'AirTemperature': 14,
#  'Fire_data': [{'Confidence': 97,
#                 'Datetime': '2017-11-09T04:16:44',
#                 'SurfaceTemperature': {'Celcius': 80}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-11-11T13:30:08',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-11-11T04:04:25',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-11-11T13:30:08',
#                 'SurfaceTemperature': {'Celcius': 37}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 89,
#                 'Datetime': '2017-11-12T00:33:15',
#                 'SurfaceTemperature': {'Celcius': 69}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-11-13T03:52:15',
#                 'SurfaceTemperature': {'Celcius': 61}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-11-13T03:52:14',
#                 'SurfaceTemperature': {'Celcius': 53}}]}
# {'AirTemperature': 28,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-11-14T04:35:04',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 85,
#                 'Datetime': '2017-11-21T00:27:21',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-11-22T03:46:00',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 23,
#  'Fire_data': [{'Confidence': 88,
#                 'Datetime': '2017-11-22T03:46:00',
#                 'SurfaceTemperature': {'Celcius': 64}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-11-23T04:28:59',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 24,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-11-23T04:28:59',
#                 'SurfaceTemperature': {'Celcius': 73}}]}
# {'AirTemperature': 28,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-11-29T13:17:24',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 28,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-11-29T03:52:10',
#                 'SurfaceTemperature': {'Celcius': 87}}]}
# {'AirTemperature': 28,
#  'Fire_data': [{'Confidence': 97,
#                 'Datetime': '2017-11-29T03:52:10',
#                 'SurfaceTemperature': {'Celcius': 80}}]}
# {'AirTemperature': 28,
#  'Fire_data': [{'Confidence': 99,
#                 'Datetime': '2017-11-29T03:52:10',
#                 'SurfaceTemperature': {'Celcius': 84}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-11-30T15:38:36',
#                 'SurfaceTemperature': {'Celcius': 53}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-11-30T15:38:35',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-11-30T15:38:35',
#                 'SurfaceTemperature': {'Celcius': 49}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-11-30T12:22:15',
#                 'SurfaceTemperature': {'Celcius': 38}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-11-30T12:22:15',
#                 'SurfaceTemperature': {'Celcius': 42}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-11-30T12:22:15',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-11-30T12:22:15',
#                 'SurfaceTemperature': {'Celcius': 65}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-11-30T12:22:14',
#                 'SurfaceTemperature': {'Celcius': 71}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-11-30T04:35:00',
#                 'SurfaceTemperature': {'Celcius': 59}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 98,
#                 'Datetime': '2017-11-30T04:34:57',
#                 'SurfaceTemperature': {'Celcius': 83}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-11-30T04:34:57',
#                 'SurfaceTemperature': {'Celcius': 57}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-11-30T04:34:57',
#                 'SurfaceTemperature': {'Celcius': 61}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 99,
#                 'Datetime': '2017-11-30T04:34:57',
#                 'SurfaceTemperature': {'Celcius': 86}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-11-30T00:20:53',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-11-30T00:20:53',
#                 'SurfaceTemperature': {'Celcius': 63}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 95,
#                 'Datetime': '2017-11-30T00:20:53',
#                 'SurfaceTemperature': {'Celcius': 76}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-11-30T00:20:53',
#                 'SurfaceTemperature': {'Celcius': 56}}]}
# {'AirTemperature': 26,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-11-30T00:20:53',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-12-08T13:11:44',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-12-08T13:11:44',
#                 'SurfaceTemperature': {'Celcius': 71}}]}
# {'AirTemperature': 15,
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-12-08T13:11:43',
#                 'SurfaceTemperature': {'Celcius': 52}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 87,
#                 'Datetime': '2017-12-09T00:14:34',
#                 'SurfaceTemperature': {'Celcius': 61}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 81,
#                 'Datetime': '2017-12-09T00:14:34',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-12-09T00:14:33',
#                 'SurfaceTemperature': {'Celcius': 58}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-12-09T00:14:33',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 28,
#  'Fire_data': [{'Confidence': 83,
#                 'Datetime': '2017-12-13T04:04:19',
#                 'SurfaceTemperature': {'Celcius': 60}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-12-14T04:47:25',
#                 'SurfaceTemperature': {'Celcius': 70}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 92,
#                 'Datetime': '2017-12-15T13:17:17',
#                 'SurfaceTemperature': {'Celcius': 42}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 94,
#                 'Datetime': '2017-12-16T15:38:39',
#                 'SurfaceTemperature': {'Celcius': 43}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-12-16T04:35:13',
#                 'SurfaceTemperature': {'Celcius': 73}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 84,
#                 'Datetime': '2017-12-16T04:34:58',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 95,
#                 'Datetime': '2017-12-16T04:34:58',
#                 'SurfaceTemperature': {'Celcius': 75}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 90,
#                 'Datetime': '2017-12-16T04:34:57',
#                 'SurfaceTemperature': {'Celcius': 66}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 93,
#                 'Datetime': '2017-12-16T00:21:12',
#                 'SurfaceTemperature': {'Celcius': 73}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-12-16T00:21:11',
#                 'SurfaceTemperature': {'Celcius': 55}}]}
# {'AirTemperature': 18,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-12-16T00:20:53',
#                 'SurfaceTemperature': {'Celcius': 64}}]}
# {'AirTemperature': 17,
#  'Fire_data': [{'Confidence': 80,
#                 'Datetime': '2017-12-25T04:29:08',
#                 'SurfaceTemperature': {'Celcius': 54}}]}
# {'AirTemperature': 28,
#  'Fire_data': [{'Confidence': 82,
#                 'Datetime': '2017-12-27T00:02:15',
#                 'SurfaceTemperature': {'Celcius': 63}}]}
# {'AirTemperature': 28,
#  'Fire_data': [{'Confidence': 86,
#                 'Datetime': '2017-12-27T00:02:14',
#                 'SurfaceTemperature': {'Celcius': 67}}]}

# %% [markdown]
# ### A6. Find top 10 records with highest surface temperature (°C).

# %%
pipline =[{"$unwind":"$Fires"},
          {"$lookup":{"from":"fire",
                      "localField":"Fires",
                      "foreignField":"_id",
                      "as": "Fire_data"}},
          {"$project":{"Fires":0}},
          {"$sort": SON([{"Fire_data.SurfaceTemperature.Celcius", pymongo.DESCENDING}])},
          {"$limit": 10}
          ]
result_A6 = climateCollection.aggregate(pipline)
for i in result_A6:
    pprint(i)
# Out:
# {'AirTemperature': 15,
#  'Date': '2017-04-18',
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-18T04:52:00',
#                 'Location': {'Latitude': -38.1665, 'Longitude': 143.062},
#                 'Power': 239.8,
#                 'SurfaceTemperature': {'Celcius': 124, 'Kelvin': 397.5},
#                 '_id': 1188}],
#  'MAX': '69.8*',
#  'MIN': '46.8',
#  'MaxWindSpeed': 9.9,
#  'Precipitation': ' 0.00I',
#  'RelativeHumidity': 56.1,
#  'Station': '948701',
#  'WindSpeed': 5.1,
#  '_id': 108}
# {'AirTemperature': 16,
#  'Date': '2017-04-04',
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-04T04:32:50',
#                 'Location': {'Latitude': -36.343, 'Longitude': 142.1986},
#                 'Power': 233.4,
#                 'SurfaceTemperature': {'Celcius': 123, 'Kelvin': 396.3},
#                 '_id': 2382}],
#  'MAX': '73.4*',
#  'MIN': '46.8',
#  'MaxWindSpeed': 12.0,
#  'Precipitation': ' 0.00I',
#  'RelativeHumidity': 47.5,
#  'Station': '948701',
#  'WindSpeed': 5.4,
#  '_id': 94}
# {'AirTemperature': 14,
#  'Date': '2017-05-01',
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-05-01T04:14:20',
#                 'Location': {'Latitude': -36.9318, 'Longitude': 143.0907},
#                 'Power': 236.0,
#                 'SurfaceTemperature': {'Celcius': 122, 'Kelvin': 396.0},
#                 '_id': 1046}],
#  'MAX': '67.5*',
#  'MIN': '51.3*',
#  'MaxWindSpeed': 20.0,
#  'Precipitation': ' 0.12G',
#  'RelativeHumidity': 49.2,
#  'Station': '948701',
#  'WindSpeed': 10.5,
#  '_id': 121}
# {'AirTemperature': 21,
#  'Date': '2017-03-18',
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-03-18T03:50:50',
#                 'Location': {'Latitude': -37.017, 'Longitude': 148.1297},
#                 'Power': 224.3,
#                 'SurfaceTemperature': {'Celcius': 121, 'Kelvin': 394.3},
#                 '_id': 2621}],
#  'MAX': '84.9*',
#  'MIN': '51.6',
#  'MaxWindSpeed': 11.1,
#  'Precipitation': ' 0.00I',
#  'RelativeHumidity': 52.8,
#  'Station': '948701',
#  'WindSpeed': 4.1,
#  '_id': 77}
# {'AirTemperature': 16,
#  'Date': '2017-04-04',
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-04T04:40:00',
#                 'Location': {'Latitude': -36.1057, 'Longitude': 141.7608},
#                 'Power': 212.5,
#                 'SurfaceTemperature': {'Celcius': 120, 'Kelvin': 393.8},
#                 '_id': 2325}],
#  'MAX': '73.4*',
#  'MIN': '46.8',
#  'MaxWindSpeed': 12.0,
#  'Precipitation': ' 0.00I',
#  'RelativeHumidity': 47.5,
#  'Station': '948701',
#  'WindSpeed': 5.4,
#  '_id': 94}
# {'AirTemperature': 16,
#  'Date': '2017-04-04',
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-04T04:32:40',
#                 'Location': {'Latitude': -36.3521, 'Longitude': 142.2008},
#                 'Power': 218.7,
#                 'SurfaceTemperature': {'Celcius': 120, 'Kelvin': 394.0},
#                 '_id': 2389}],
#  'MAX': '73.4*',
#  'MIN': '46.8',
#  'MaxWindSpeed': 12.0,
#  'Precipitation': ' 0.00I',
#  'RelativeHumidity': 47.5,
#  'Station': '948701',
#  'WindSpeed': 5.4,
#  '_id': 94}
# {'AirTemperature': 9,
#  'Date': '2017-05-13',
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-05-13T04:40:20',
#                 'Location': {'Latitude': -34.9938, 'Longitude': 141.876},
#                 'Power': 223.8,
#                 'SurfaceTemperature': {'Celcius': 120, 'Kelvin': 394.0},
#                 '_id': 552}],
#  'MAX': '58.5*',
#  'MIN': '41.4*',
#  'MaxWindSpeed': 8.0,
#  'Precipitation': ' 0.00I',
#  'RelativeHumidity': 44.0,
#  'Station': '948701',
#  'WindSpeed': 2.8,
#  '_id': 133}
# {'AirTemperature': 16,
#  'Date': '2017-04-13',
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-13T04:28:10',
#                 'Location': {'Latitude': -37.0745, 'Longitude': 141.0692},
#                 'Power': 218.7,
#                 'SurfaceTemperature': {'Celcius': 120, 'Kelvin': 393.7},
#                 '_id': 1728}],
#  'MAX': '69.1*',
#  'MIN': '48.2',
#  'MaxWindSpeed': 9.9,
#  'Precipitation': ' 0.00I',
#  'RelativeHumidity': 54.9,
#  'Station': '948701',
#  'WindSpeed': 5.9,
#  '_id': 103}
# {'AirTemperature': 15,
#  'Date': '2017-04-18',
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-04-18T04:44:50',
#                 'Location': {'Latitude': -37.8326, 'Longitude': 143.4999},
#                 'Power': 220.4,
#                 'SurfaceTemperature': {'Celcius': 120, 'Kelvin': 393.8},
#                 '_id': 1341}],
#  'MAX': '69.8*',
#  'MIN': '46.8',
#  'MaxWindSpeed': 9.9,
#  'Precipitation': ' 0.00I',
#  'RelativeHumidity': 56.1,
#  'Station': '948701',
#  'WindSpeed': 5.1,
#  '_id': 108}
# {'AirTemperature': 10,
#  'Date': '2017-05-04',
#  'Fire_data': [{'Confidence': 100,
#                 'Datetime': '2017-05-04T04:44:50',
#                 'Location': {'Latitude': -36.4057, 'Longitude': 140.9806},
#                 'Power': 214.4,
#                 'SurfaceTemperature': {'Celcius': 119, 'Kelvin': 392.2},
#                 '_id': 876}],
#  'MAX': '59.7*',
#  'MIN': '39.4',
#  'MaxWindSpeed': 7.0,
#  'Precipitation': ' 0.00I',
#  'RelativeHumidity': 43.3,
#  'Station': '948701',
#  'WindSpeed': 2.6,
#  '_id': 124}

# %% [markdown]
# ### A7. Find the number of fire in each day. You are required to only display total number of fire and the date in the output.

# %%
pipline = [{"$project":{"_id":0,
                        "Date":1, 
                        "numberOfFires":{"$size":"$Fires"}}},
           {"$sort":{"numberOfFires":-1}}]
result_A7 = climateCollection.aggregate(pipline)
for i in result_A7:
    pprint(i)
# Out:
# {'Date': '2017-04-13', 'numberOfFires': 357}
# {'Date': '2017-04-18', 'numberOfFires': 325}
# {'Date': '2017-05-04', 'numberOfFires': 135}
# {'Date': '2017-04-06', 'numberOfFires': 118}
# {'Date': '2017-05-10', 'numberOfFires': 114}
# {'Date': '2017-05-15', 'numberOfFires': 102}
# {'Date': '2017-04-04', 'numberOfFires': 89}
# {'Date': '2017-04-03', 'numberOfFires': 72}
# {'Date': '2017-04-12', 'numberOfFires': 69}
# {'Date': '2017-04-15', 'numberOfFires': 69}
# {'Date': '2017-05-03', 'numberOfFires': 64}
# {'Date': '2017-03-28', 'numberOfFires': 54}
# {'Date': '2017-05-13', 'numberOfFires': 54}
# {'Date': '2017-04-19', 'numberOfFires': 50}
# {'Date': '2017-04-05', 'numberOfFires': 49}
# {'Date': '2017-04-07', 'numberOfFires': 39}
# {'Date': '2017-04-17', 'numberOfFires': 38}
# {'Date': '2017-05-22', 'numberOfFires': 33}
# {'Date': '2017-04-20', 'numberOfFires': 31}
# {'Date': '2017-05-05', 'numberOfFires': 31}
# {'Date': '2017-11-30', 'numberOfFires': 31}
# {'Date': '2017-09-24', 'numberOfFires': 28}
# {'Date': '2017-04-11', 'numberOfFires': 24}
# {'Date': '2017-05-08', 'numberOfFires': 24}
# {'Date': '2017-09-23', 'numberOfFires': 23}
# {'Date': '2017-03-31', 'numberOfFires': 22}
# {'Date': '2017-03-19', 'numberOfFires': 21}
# {'Date': '2017-04-08', 'numberOfFires': 20}
# {'Date': '2017-05-01', 'numberOfFires': 20}
# {'Date': '2017-04-23', 'numberOfFires': 19}
# {'Date': '2017-05-11', 'numberOfFires': 19}
# {'Date': '2017-04-14', 'numberOfFires': 18}
# {'Date': '2017-04-16', 'numberOfFires': 18}
# {'Date': '2017-10-03', 'numberOfFires': 18}
# {'Date': '2017-03-26', 'numberOfFires': 17}
# {'Date': '2017-05-06', 'numberOfFires': 17}
# {'Date': '2017-12-16', 'numberOfFires': 15}
# {'Date': '2017-06-07', 'numberOfFires': 14}
# {'Date': '2017-03-25', 'numberOfFires': 13}
# {'Date': '2017-05-09', 'numberOfFires': 13}
# {'Date': '2017-06-02', 'numberOfFires': 11}
# {'Date': '2017-03-14', 'numberOfFires': 10}
# {'Date': '2017-05-02', 'numberOfFires': 10}
# {'Date': '2017-05-12', 'numberOfFires': 10}
# {'Date': '2017-11-09', 'numberOfFires': 10}
# {'Date': '2017-06-04', 'numberOfFires': 9}
# {'Date': '2017-08-13', 'numberOfFires': 9}
# {'Date': '2017-03-10', 'numberOfFires': 8}
# {'Date': '2017-04-24', 'numberOfFires': 8}
# {'Date': '2017-07-02', 'numberOfFires': 8}
# {'Date': '2017-10-01', 'numberOfFires': 8}
# {'Date': '2017-11-29', 'numberOfFires': 8}
# {'Date': '2017-03-15', 'numberOfFires': 7}
# {'Date': '2017-04-01', 'numberOfFires': 7}
# {'Date': '2017-05-18', 'numberOfFires': 7}
# {'Date': '2017-09-27', 'numberOfFires': 7}
# {'Date': '2017-10-02', 'numberOfFires': 7}
# {'Date': '2017-03-17', 'numberOfFires': 6}
# {'Date': '2017-06-20', 'numberOfFires': 6}
# {'Date': '2017-06-30', 'numberOfFires': 6}
# {'Date': '2017-10-18', 'numberOfFires': 6}
# {'Date': '2017-03-12', 'numberOfFires': 5}
# {'Date': '2017-04-02', 'numberOfFires': 5}
# {'Date': '2017-05-23', 'numberOfFires': 5}
# {'Date': '2017-08-14', 'numberOfFires': 5}
# {'Date': '2017-09-20', 'numberOfFires': 5}
# {'Date': '2017-10-04', 'numberOfFires': 5}
# {'Date': '2017-10-17', 'numberOfFires': 5}
# {'Date': '2017-10-26', 'numberOfFires': 5}
# {'Date': '2017-10-27', 'numberOfFires': 5}
# {'Date': '2017-11-12', 'numberOfFires': 5}
# {'Date': '2017-11-13', 'numberOfFires': 5}
# {'Date': '2017-11-23', 'numberOfFires': 5}
# {'Date': '2017-12-08', 'numberOfFires': 5}
# {'Date': '2017-05-26', 'numberOfFires': 4}
# {'Date': '2017-06-14', 'numberOfFires': 4}
# {'Date': '2017-07-01', 'numberOfFires': 4}
# {'Date': '2017-09-10', 'numberOfFires': 4}
# {'Date': '2017-10-21', 'numberOfFires': 4}
# {'Date': '2017-11-05', 'numberOfFires': 4}
# {'Date': '2017-11-11', 'numberOfFires': 4}
# {'Date': '2017-12-09', 'numberOfFires': 4}
# {'Date': '2017-12-15', 'numberOfFires': 4}
# {'Date': '2017-12-27', 'numberOfFires': 4}
# {'Date': '2017-03-09', 'numberOfFires': 3}
# {'Date': '2017-03-18', 'numberOfFires': 3}
# {'Date': '2017-04-25', 'numberOfFires': 3}
# {'Date': '2017-04-29', 'numberOfFires': 3}
# {'Date': '2017-05-07', 'numberOfFires': 3}
# {'Date': '2017-05-16', 'numberOfFires': 3}
# {'Date': '2017-05-24', 'numberOfFires': 3}
# {'Date': '2017-06-09', 'numberOfFires': 3}
# {'Date': '2017-07-06', 'numberOfFires': 3}
# {'Date': '2017-10-10', 'numberOfFires': 3}
# {'Date': '2017-10-15', 'numberOfFires': 3}
# {'Date': '2017-10-20', 'numberOfFires': 3}
# {'Date': '2017-11-14', 'numberOfFires': 3}
# {'Date': '2017-03-06', 'numberOfFires': 2}
# {'Date': '2017-03-08', 'numberOfFires': 2}
# {'Date': '2017-03-13', 'numberOfFires': 2}
# {'Date': '2017-03-24', 'numberOfFires': 2}
# {'Date': '2017-04-22', 'numberOfFires': 2}
# {'Date': '2017-06-01', 'numberOfFires': 2}
# {'Date': '2017-06-03', 'numberOfFires': 2}
# {'Date': '2017-06-11', 'numberOfFires': 2}
# {'Date': '2017-06-16', 'numberOfFires': 2}
# {'Date': '2017-06-18', 'numberOfFires': 2}
# {'Date': '2017-07-14', 'numberOfFires': 2}
# {'Date': '2017-07-29', 'numberOfFires': 2}
# {'Date': '2017-07-31', 'numberOfFires': 2}
# {'Date': '2017-08-01', 'numberOfFires': 2}
# {'Date': '2017-08-02', 'numberOfFires': 2}
# {'Date': '2017-09-21', 'numberOfFires': 2}
# {'Date': '2017-09-29', 'numberOfFires': 2}
# {'Date': '2017-10-06', 'numberOfFires': 2}
# {'Date': '2017-11-08', 'numberOfFires': 2}
# {'Date': '2017-11-22', 'numberOfFires': 2}
# {'Date': '2017-12-10', 'numberOfFires': 2}
# {'Date': '2017-03-07', 'numberOfFires': 1}
# {'Date': '2017-03-29', 'numberOfFires': 1}
# {'Date': '2017-04-26', 'numberOfFires': 1}
# {'Date': '2017-05-14', 'numberOfFires': 1}
# {'Date': '2017-05-17', 'numberOfFires': 1}
# {'Date': '2017-06-13', 'numberOfFires': 1}
# {'Date': '2017-06-22', 'numberOfFires': 1}
# {'Date': '2017-07-04', 'numberOfFires': 1}
# {'Date': '2017-07-05', 'numberOfFires': 1}
# {'Date': '2017-08-05', 'numberOfFires': 1}
# {'Date': '2017-08-10', 'numberOfFires': 1}
# {'Date': '2017-09-22', 'numberOfFires': 1}
# {'Date': '2017-09-26', 'numberOfFires': 1}
# {'Date': '2017-10-07', 'numberOfFires': 1}
# {'Date': '2017-10-08', 'numberOfFires': 1}
# {'Date': '2017-10-09', 'numberOfFires': 1}
# {'Date': '2017-10-16', 'numberOfFires': 1}
# {'Date': '2017-10-23', 'numberOfFires': 1}
# {'Date': '2017-10-28', 'numberOfFires': 1}
# {'Date': '2017-11-21', 'numberOfFires': 1}
# {'Date': '2017-11-28', 'numberOfFires': 1}
# {'Date': '2017-12-12', 'numberOfFires': 1}
# {'Date': '2017-12-13', 'numberOfFires': 1}
# {'Date': '2017-12-14', 'numberOfFires': 1}
# {'Date': '2017-12-21', 'numberOfFires': 1}
# {'Date': '2017-12-24', 'numberOfFires': 1}
# {'Date': '2017-12-25', 'numberOfFires': 1}
# {'Date': '2016-12-31', 'numberOfFires': 0}
# {'Date': '2017-01-02', 'numberOfFires': 0}
# {'Date': '2017-01-03', 'numberOfFires': 0}
# {'Date': '2017-01-04', 'numberOfFires': 0}
# {'Date': '2017-01-05', 'numberOfFires': 0}
# {'Date': '2017-01-06', 'numberOfFires': 0}
# {'Date': '2017-01-07', 'numberOfFires': 0}
# {'Date': '2017-01-08', 'numberOfFires': 0}
# {'Date': '2017-01-09', 'numberOfFires': 0}
# {'Date': '2017-01-10', 'numberOfFires': 0}
# {'Date': '2017-01-11', 'numberOfFires': 0}
# {'Date': '2017-01-12', 'numberOfFires': 0}
# {'Date': '2017-01-13', 'numberOfFires': 0}
# {'Date': '2017-01-14', 'numberOfFires': 0}
# {'Date': '2017-01-15', 'numberOfFires': 0}
# {'Date': '2017-01-16', 'numberOfFires': 0}
# {'Date': '2017-01-17', 'numberOfFires': 0}
# {'Date': '2017-01-18', 'numberOfFires': 0}
# {'Date': '2017-01-19', 'numberOfFires': 0}
# {'Date': '2017-01-20', 'numberOfFires': 0}
# {'Date': '2017-01-21', 'numberOfFires': 0}
# {'Date': '2017-01-22', 'numberOfFires': 0}
# {'Date': '2017-01-23', 'numberOfFires': 0}
# {'Date': '2017-01-24', 'numberOfFires': 0}
# {'Date': '2017-01-25', 'numberOfFires': 0}
# {'Date': '2017-01-26', 'numberOfFires': 0}
# {'Date': '2017-01-27', 'numberOfFires': 0}
# {'Date': '2017-01-28', 'numberOfFires': 0}
# {'Date': '2017-01-29', 'numberOfFires': 0}
# {'Date': '2017-01-30', 'numberOfFires': 0}
# {'Date': '2017-01-31', 'numberOfFires': 0}
# {'Date': '2017-02-01', 'numberOfFires': 0}
# {'Date': '2017-02-02', 'numberOfFires': 0}
# {'Date': '2017-02-03', 'numberOfFires': 0}
# {'Date': '2017-02-04', 'numberOfFires': 0}
# {'Date': '2017-02-05', 'numberOfFires': 0}
# {'Date': '2017-02-06', 'numberOfFires': 0}
# {'Date': '2017-02-07', 'numberOfFires': 0}
# {'Date': '2017-02-08', 'numberOfFires': 0}
# {'Date': '2017-02-09', 'numberOfFires': 0}
# {'Date': '2017-02-10', 'numberOfFires': 0}
# {'Date': '2017-02-11', 'numberOfFires': 0}
# {'Date': '2017-02-12', 'numberOfFires': 0}
# {'Date': '2017-02-13', 'numberOfFires': 0}
# {'Date': '2017-02-14', 'numberOfFires': 0}
# {'Date': '2017-02-15', 'numberOfFires': 0}
# {'Date': '2017-02-16', 'numberOfFires': 0}
# {'Date': '2017-02-17', 'numberOfFires': 0}
# {'Date': '2017-02-18', 'numberOfFires': 0}
# {'Date': '2017-02-19', 'numberOfFires': 0}
# {'Date': '2017-02-20', 'numberOfFires': 0}
# {'Date': '2017-02-21', 'numberOfFires': 0}
# {'Date': '2017-02-22', 'numberOfFires': 0}
# {'Date': '2017-02-23', 'numberOfFires': 0}
# {'Date': '2017-02-24', 'numberOfFires': 0}
# {'Date': '2017-02-25', 'numberOfFires': 0}
# {'Date': '2017-02-26', 'numberOfFires': 0}
# {'Date': '2017-02-27', 'numberOfFires': 0}
# {'Date': '2017-02-28', 'numberOfFires': 0}
# {'Date': '2017-03-01', 'numberOfFires': 0}
# {'Date': '2017-03-02', 'numberOfFires': 0}
# {'Date': '2017-03-03', 'numberOfFires': 0}
# {'Date': '2017-03-04', 'numberOfFires': 0}
# {'Date': '2017-03-05', 'numberOfFires': 0}
# {'Date': '2017-03-11', 'numberOfFires': 0}
# {'Date': '2017-03-16', 'numberOfFires': 0}
# {'Date': '2017-03-20', 'numberOfFires': 0}
# {'Date': '2017-03-21', 'numberOfFires': 0}
# {'Date': '2017-03-22', 'numberOfFires': 0}
# {'Date': '2017-03-23', 'numberOfFires': 0}
# {'Date': '2017-03-27', 'numberOfFires': 0}
# {'Date': '2017-03-30', 'numberOfFires': 0}
# {'Date': '2017-04-09', 'numberOfFires': 0}
# {'Date': '2017-04-10', 'numberOfFires': 0}
# {'Date': '2017-04-21', 'numberOfFires': 0}
# {'Date': '2017-04-27', 'numberOfFires': 0}
# {'Date': '2017-04-28', 'numberOfFires': 0}
# {'Date': '2017-04-30', 'numberOfFires': 0}
# {'Date': '2017-05-19', 'numberOfFires': 0}
# {'Date': '2017-05-20', 'numberOfFires': 0}
# {'Date': '2017-05-21', 'numberOfFires': 0}
# {'Date': '2017-05-25', 'numberOfFires': 0}
# {'Date': '2017-05-27', 'numberOfFires': 0}
# {'Date': '2017-05-28', 'numberOfFires': 0}
# {'Date': '2017-05-29', 'numberOfFires': 0}
# {'Date': '2017-05-30', 'numberOfFires': 0}
# {'Date': '2017-05-31', 'numberOfFires': 0}
# {'Date': '2017-06-05', 'numberOfFires': 0}
# {'Date': '2017-06-06', 'numberOfFires': 0}
# {'Date': '2017-06-08', 'numberOfFires': 0}
# {'Date': '2017-06-10', 'numberOfFires': 0}
# {'Date': '2017-06-12', 'numberOfFires': 0}
# {'Date': '2017-06-15', 'numberOfFires': 0}
# {'Date': '2017-06-17', 'numberOfFires': 0}
# {'Date': '2017-06-19', 'numberOfFires': 0}
# {'Date': '2017-06-21', 'numberOfFires': 0}
# {'Date': '2017-06-23', 'numberOfFires': 0}
# {'Date': '2017-06-24', 'numberOfFires': 0}
# {'Date': '2017-06-25', 'numberOfFires': 0}
# {'Date': '2017-06-26', 'numberOfFires': 0}
# {'Date': '2017-06-27', 'numberOfFires': 0}
# {'Date': '2017-06-28', 'numberOfFires': 0}
# {'Date': '2017-06-29', 'numberOfFires': 0}
# {'Date': '2017-07-03', 'numberOfFires': 0}
# {'Date': '2017-07-07', 'numberOfFires': 0}
# {'Date': '2017-07-08', 'numberOfFires': 0}
# {'Date': '2017-07-09', 'numberOfFires': 0}
# {'Date': '2017-07-10', 'numberOfFires': 0}
# {'Date': '2017-07-11', 'numberOfFires': 0}
# {'Date': '2017-07-12', 'numberOfFires': 0}
# {'Date': '2017-07-13', 'numberOfFires': 0}
# {'Date': '2017-07-15', 'numberOfFires': 0}
# {'Date': '2017-07-16', 'numberOfFires': 0}
# {'Date': '2017-07-17', 'numberOfFires': 0}
# {'Date': '2017-07-18', 'numberOfFires': 0}
# {'Date': '2017-07-19', 'numberOfFires': 0}
# {'Date': '2017-07-20', 'numberOfFires': 0}
# {'Date': '2017-07-21', 'numberOfFires': 0}
# {'Date': '2017-07-22', 'numberOfFires': 0}
# {'Date': '2017-07-23', 'numberOfFires': 0}
# {'Date': '2017-07-24', 'numberOfFires': 0}
# {'Date': '2017-07-25', 'numberOfFires': 0}
# {'Date': '2017-07-26', 'numberOfFires': 0}
# {'Date': '2017-07-27', 'numberOfFires': 0}
# {'Date': '2017-07-28', 'numberOfFires': 0}
# {'Date': '2017-07-30', 'numberOfFires': 0}
# {'Date': '2017-08-03', 'numberOfFires': 0}
# {'Date': '2017-08-04', 'numberOfFires': 0}
# {'Date': '2017-08-06', 'numberOfFires': 0}
# {'Date': '2017-08-07', 'numberOfFires': 0}
# {'Date': '2017-08-08', 'numberOfFires': 0}
# {'Date': '2017-08-09', 'numberOfFires': 0}
# {'Date': '2017-08-11', 'numberOfFires': 0}
# {'Date': '2017-08-12', 'numberOfFires': 0}
# {'Date': '2017-08-15', 'numberOfFires': 0}
# {'Date': '2017-08-16', 'numberOfFires': 0}
# {'Date': '2017-08-17', 'numberOfFires': 0}
# {'Date': '2017-08-18', 'numberOfFires': 0}
# {'Date': '2017-08-19', 'numberOfFires': 0}
# {'Date': '2017-08-20', 'numberOfFires': 0}
# {'Date': '2017-08-21', 'numberOfFires': 0}
# {'Date': '2017-08-22', 'numberOfFires': 0}
# {'Date': '2017-08-23', 'numberOfFires': 0}
# {'Date': '2017-08-24', 'numberOfFires': 0}
# {'Date': '2017-08-25', 'numberOfFires': 0}
# {'Date': '2017-08-26', 'numberOfFires': 0}
# {'Date': '2017-08-27', 'numberOfFires': 0}
# {'Date': '2017-08-28', 'numberOfFires': 0}
# {'Date': '2017-08-29', 'numberOfFires': 0}
# {'Date': '2017-08-30', 'numberOfFires': 0}
# {'Date': '2017-08-31', 'numberOfFires': 0}
# {'Date': '2017-09-01', 'numberOfFires': 0}
# {'Date': '2017-09-02', 'numberOfFires': 0}
# {'Date': '2017-09-03', 'numberOfFires': 0}
# {'Date': '2017-09-04', 'numberOfFires': 0}
# {'Date': '2017-09-05', 'numberOfFires': 0}
# {'Date': '2017-09-06', 'numberOfFires': 0}
# {'Date': '2017-09-07', 'numberOfFires': 0}
# {'Date': '2017-09-08', 'numberOfFires': 0}
# {'Date': '2017-09-09', 'numberOfFires': 0}
# {'Date': '2017-09-11', 'numberOfFires': 0}
# {'Date': '2017-09-12', 'numberOfFires': 0}
# {'Date': '2017-09-13', 'numberOfFires': 0}
# {'Date': '2017-09-14', 'numberOfFires': 0}
# {'Date': '2017-09-15', 'numberOfFires': 0}
# {'Date': '2017-09-16', 'numberOfFires': 0}
# {'Date': '2017-09-17', 'numberOfFires': 0}
# {'Date': '2017-09-18', 'numberOfFires': 0}
# {'Date': '2017-09-19', 'numberOfFires': 0}
# {'Date': '2017-09-25', 'numberOfFires': 0}
# {'Date': '2017-09-28', 'numberOfFires': 0}
# {'Date': '2017-09-30', 'numberOfFires': 0}
# {'Date': '2017-10-05', 'numberOfFires': 0}
# {'Date': '2017-10-11', 'numberOfFires': 0}
# {'Date': '2017-10-12', 'numberOfFires': 0}
# {'Date': '2017-10-13', 'numberOfFires': 0}
# {'Date': '2017-10-14', 'numberOfFires': 0}
# {'Date': '2017-10-19', 'numberOfFires': 0}
# {'Date': '2017-10-22', 'numberOfFires': 0}
# {'Date': '2017-10-24', 'numberOfFires': 0}
# {'Date': '2017-10-25', 'numberOfFires': 0}
# {'Date': '2017-10-29', 'numberOfFires': 0}
# {'Date': '2017-10-30', 'numberOfFires': 0}
# {'Date': '2017-10-31', 'numberOfFires': 0}
# {'Date': '2017-11-01', 'numberOfFires': 0}
# {'Date': '2017-11-02', 'numberOfFires': 0}
# {'Date': '2017-11-03', 'numberOfFires': 0}
# {'Date': '2017-11-04', 'numberOfFires': 0}
# {'Date': '2017-11-06', 'numberOfFires': 0}
# {'Date': '2017-11-07', 'numberOfFires': 0}
# {'Date': '2017-11-10', 'numberOfFires': 0}
# {'Date': '2017-11-15', 'numberOfFires': 0}
# {'Date': '2017-11-16', 'numberOfFires': 0}
# {'Date': '2017-11-17', 'numberOfFires': 0}
# {'Date': '2017-11-18', 'numberOfFires': 0}
# {'Date': '2017-11-19', 'numberOfFires': 0}
# {'Date': '2017-11-20', 'numberOfFires': 0}
# {'Date': '2017-11-24', 'numberOfFires': 0}
# {'Date': '2017-11-25', 'numberOfFires': 0}
# {'Date': '2017-11-26', 'numberOfFires': 0}
# {'Date': '2017-11-27', 'numberOfFires': 0}
# {'Date': '2017-12-01', 'numberOfFires': 0}
# {'Date': '2017-12-02', 'numberOfFires': 0}
# {'Date': '2017-12-03', 'numberOfFires': 0}
# {'Date': '2017-12-04', 'numberOfFires': 0}
# {'Date': '2017-12-05', 'numberOfFires': 0}
# {'Date': '2017-12-06', 'numberOfFires': 0}
# {'Date': '2017-12-07', 'numberOfFires': 0}
# {'Date': '2017-12-11', 'numberOfFires': 0}
# {'Date': '2017-12-17', 'numberOfFires': 0}
# {'Date': '2017-12-18', 'numberOfFires': 0}
# {'Date': '2017-12-19', 'numberOfFires': 0}
# {'Date': '2017-12-20', 'numberOfFires': 0}
# {'Date': '2017-12-22', 'numberOfFires': 0}
# {'Date': '2017-12-23', 'numberOfFires': 0}
# {'Date': '2017-12-26', 'numberOfFires': 0}
# {'Date': '2017-12-28', 'numberOfFires': 0}
# {'Date': '2017-12-29', 'numberOfFires': 0}
# {'Date': '2017-12-30', 'numberOfFires': 0}
# {'Date': '2017-12-31', 'numberOfFires': 0}
# {'Date': '2018-01-01', 'numberOfFires': 0}

# %% [markdown]
# ### A8. Find the average *surface temperature (°C)* for each day. You are required to only display average surface temperature (°C) and the date in the output.

# %%
pipline = [{"$unwind":"$Fires"},
           {"$lookup":{"from":"fire",
                       "localField":"Fires",
                       "foreignField":"_id",
                       "as": "Fire_data"}},
           {"$unwind":"$Fire_data"},
           { "$group": { "_id": "$Date", "Avg": {"$avg": "$Fire_data.SurfaceTemperature.Celcius"}}},
           { "$project": { "_id": 0, "Date":"$_id", "Avg":1}}
          ]
result_A8 = climateCollection.aggregate(pipline)
for i in result_A8:
    pprint(i)
# Out:
# {'Avg': 62.75, 'Date': '2017-12-27'}
# {'Avg': 32.0, 'Date': '2017-12-24'}
# {'Avg': 39.0, 'Date': '2017-12-15'}
# {'Avg': 70.0, 'Date': '2017-12-14'}
# {'Avg': 44.0, 'Date': '2017-12-12'}
# {'Avg': 46.0, 'Date': '2017-12-10'}
# {'Avg': 58.25, 'Date': '2017-12-09'}
# {'Avg': 60.625, 'Date': '2017-11-29'}
# {'Avg': 42.0, 'Date': '2017-11-28'}
# {'Avg': 58.8, 'Date': '2017-11-23'}
# {'Avg': 61.5, 'Date': '2017-11-22'}
# {'Avg': 52.0, 'Date': '2017-11-14'}
# {'Avg': 47.0, 'Date': '2017-11-13'}
# {'Avg': 46.25, 'Date': '2017-11-11'}
# {'Avg': 61.3, 'Date': '2017-11-09'}
# {'Avg': 58.5, 'Date': '2017-11-05'}
# {'Avg': 50.4, 'Date': '2017-10-27'}
# {'Avg': 52.166666666666664, 'Date': '2017-10-18'}
# {'Avg': 36.0, 'Date': '2017-10-16'}
# {'Avg': 72.66666666666667, 'Date': '2017-10-15'}
# {'Avg': 53.333333333333336, 'Date': '2017-10-10'}
# {'Avg': 44.0, 'Date': '2017-10-09'}
# {'Avg': 51.6, 'Date': '2017-10-17'}
# {'Avg': 42.0, 'Date': '2017-10-07'}
# {'Avg': 50.0, 'Date': '2017-10-03'}
# {'Avg': 50.6, 'Date': '2017-12-08'}
# {'Avg': 38.0, 'Date': '2017-10-23'}
# {'Avg': 43.57142857142857, 'Date': '2017-10-02'}
# {'Avg': 43.0, 'Date': '2017-09-29'}
# {'Avg': 51.25, 'Date': '2017-10-21'}
# {'Avg': 49.714285714285715, 'Date': '2017-09-27'}
# {'Avg': 33.0, 'Date': '2017-09-26'}
# {'Avg': 53.57142857142857, 'Date': '2017-09-24'}
# {'Avg': 44.6, 'Date': '2017-10-26'}
# {'Avg': 50.69230769230769, 'Date': '2017-04-07'}
# {'Avg': 61.71186440677966, 'Date': '2017-04-06'}
# {'Avg': 40.5, 'Date': '2017-09-21'}
# {'Avg': 54.484848484848484, 'Date': '2017-05-22'}
# {'Avg': 63.6, 'Date': '2017-09-20'}
# {'Avg': 52.22222222222222, 'Date': '2017-06-04'}
# {'Avg': 49.0, 'Date': '2017-08-13'}
# {'Avg': 57.8, 'Date': '2017-12-16'}
# {'Avg': 41.0, 'Date': '2017-10-08'}
# {'Avg': 30.5, 'Date': '2017-07-01'}
# {'Avg': 40.0, 'Date': '2017-08-05'}
# {'Avg': 65.6, 'Date': '2017-03-14'}
# {'Avg': 58.0, 'Date': '2017-08-01'}
# {'Avg': 48.0, 'Date': '2017-07-29'}
# {'Avg': 41.5, 'Date': '2017-07-14'}
# {'Avg': 54.0, 'Date': '2017-12-25'}
# {'Avg': 56.0, 'Date': '2017-07-06'}
# {'Avg': 48.72727272727273, 'Date': '2017-03-31'}
# {'Avg': 45.0, 'Date': '2017-07-05'}
# {'Avg': 60.75, 'Date': '2017-04-08'}
# {'Avg': 42.5, 'Date': '2017-06-16'}
# {'Avg': 49.0, 'Date': '2017-03-24'}
# {'Avg': 71.16666666666667, 'Date': '2017-06-20'}
# {'Avg': 53.25, 'Date': '2017-06-14'}
# {'Avg': 41.0, 'Date': '2017-06-13'}
# {'Avg': 51.857142857142854, 'Date': '2017-06-07'}
# {'Avg': 60.0, 'Date': '2017-12-13'}
# {'Avg': 60.5, 'Date': '2017-03-06'}
# {'Avg': 40.333333333333336, 'Date': '2017-05-24'}
# {'Avg': 50.0, 'Date': '2017-10-20'}
# {'Avg': 51.2, 'Date': '2017-05-23'}
# {'Avg': 44.333333333333336, 'Date': '2017-06-30'}
# {'Avg': 52.0, 'Date': '2017-05-17'}
# {'Avg': 39.666666666666664, 'Date': '2017-05-16'}
# {'Avg': 41.5, 'Date': '2017-06-11'}
# {'Avg': 49.0, 'Date': '2017-05-14'}
# {'Avg': 53.142857142857146, 'Date': '2017-04-05'}
# {'Avg': 51.5, 'Date': '2017-05-12'}
# {'Avg': 52.86842105263158, 'Date': '2017-05-10'}
# {'Avg': 40.8, 'Date': '2017-08-14'}
# {'Avg': 45.5, 'Date': '2017-11-08'}
# {'Avg': 46.0, 'Date': '2017-06-22'}
# {'Avg': 42.46153846153846, 'Date': '2017-05-09'}
# {'Avg': 48.25, 'Date': '2017-10-01'}
# {'Avg': 40.0, 'Date': '2017-07-04'}
# {'Avg': 56.291666666666664, 'Date': '2017-05-08'}
# {'Avg': 50.333333333333336, 'Date': '2017-05-07'}
# {'Avg': 46.0, 'Date': '2017-03-15'}
# {'Avg': 57.529411764705884, 'Date': '2017-05-06'}
# {'Avg': 48.666666666666664, 'Date': '2017-04-25'}
# {'Avg': 47.0, 'Date': '2017-06-03'}
# {'Avg': 59.0, 'Date': '2017-11-21'}
# {'Avg': 55.6, 'Date': '2017-05-02'}
# {'Avg': 68.4, 'Date': '2017-05-01'}
# {'Avg': 53.89473684210526, 'Date': '2017-04-23'}
# {'Avg': 54.16, 'Date': '2017-04-19'}
# {'Avg': 51.5, 'Date': '2017-03-08'}
# {'Avg': 53.36615384615384, 'Date': '2017-04-18'}
# {'Avg': 52.73913043478261, 'Date': '2017-09-23'}
# {'Avg': 52.69565217391305, 'Date': '2017-04-12'}
# {'Avg': 59.36842105263158, 'Date': '2017-05-11'}
# {'Avg': 61.94444444444444, 'Date': '2017-04-14'}
# {'Avg': 63.0, 'Date': '2017-08-10'}
# {'Avg': 46.291666666666664, 'Date': '2017-04-11'}
# {'Avg': 47.0, 'Date': '2017-07-31'}
# {'Avg': 45.2, 'Date': '2017-04-02'}
# {'Avg': 58.44444444444444, 'Date': '2017-04-03'}
# {'Avg': 48.72222222222222, 'Date': '2017-04-16'}
# {'Avg': 56.5, 'Date': '2017-09-10'}
# {'Avg': 62.57303370786517, 'Date': '2017-04-04'}
# {'Avg': 59.375, 'Date': '2017-04-24'}
# {'Avg': 63.0, 'Date': '2017-04-29'}
# {'Avg': 59.5, 'Date': '2017-03-17'}
# {'Avg': 49.5, 'Date': '2017-05-26'}
# {'Avg': 51.0, 'Date': '2017-03-29'}
# {'Avg': 47.72727272727273, 'Date': '2017-06-02'}
# {'Avg': 46.714285714285715, 'Date': '2017-04-01'}
# {'Avg': 50.921052631578945, 'Date': '2017-04-17'}
# {'Avg': 56.58064516129032, 'Date': '2017-04-20'}
# {'Avg': 49.0, 'Date': '2017-10-04'}
# {'Avg': 60.925925925925924, 'Date': '2017-03-28'}
# {'Avg': 45.0, 'Date': '2017-09-22'}
# {'Avg': 69.375, 'Date': '2017-03-10'}
# {'Avg': 46.0, 'Date': '2017-12-21'}
# {'Avg': 56.80740740740741, 'Date': '2017-05-04'}
# {'Avg': 43.5, 'Date': '2017-07-02'}
# {'Avg': 51.70967741935484, 'Date': '2017-05-05'}
# {'Avg': 54.5, 'Date': '2017-04-22'}
# {'Avg': 56.0, 'Date': '2017-10-28'}
# {'Avg': 54.0, 'Date': '2017-06-01'}
# {'Avg': 52.41935483870968, 'Date': '2017-11-30'}
# {'Avg': 65.57142857142857, 'Date': '2017-03-19'}
# {'Avg': 53.0, 'Date': '2017-11-12'}
# {'Avg': 58.611111111111114, 'Date': '2017-05-13'}
# {'Avg': 46.666666666666664, 'Date': '2017-03-09'}
# {'Avg': 63.5, 'Date': '2017-08-02'}
# {'Avg': 42.0, 'Date': '2017-06-18'}
# {'Avg': 53.950980392156865, 'Date': '2017-05-15'}
# {'Avg': 59.57971014492754, 'Date': '2017-04-15'}
# {'Avg': 56.796875, 'Date': '2017-05-03'}
# {'Avg': 56.88235294117647, 'Date': '2017-03-26'}
# {'Avg': 79.33333333333333, 'Date': '2017-03-18'}
# {'Avg': 38.5, 'Date': '2017-03-13'}
# {'Avg': 88.2, 'Date': '2017-03-12'}
# {'Avg': 58.57983193277311, 'Date': '2017-04-13'}
# {'Avg': 44.0, 'Date': '2017-10-06'}
# {'Avg': 49.0, 'Date': '2017-06-09'}
# {'Avg': 44.142857142857146, 'Date': '2017-05-18'}
# {'Avg': 66.0, 'Date': '2017-03-25'}
# {'Avg': 64.0, 'Date': '2017-03-07'}
# {'Avg': 34.0, 'Date': '2017-04-26'}

# %% [markdown]
# ### Using Parallelism for A2.

# %%
def rr_partition(data, n):
    result = []
    #Creating partition n as list of lists
    for i in range(n):
        result.append([])
    for index, element in enumerate(data):
        index_bin = (int)(index % n) 
        #Trick: e.g. 1%4=1; 2%4=2; 3%4=3; 4%4=0
        result[index_bin].append(element)
    return result

# %%
def check_climate_date(docs, query):
    results = []
    for doc in docs:        
        if doc['Date'] == query:
            results.append(doc)
    return results

# %%
def parallel_date(query, n_processor):
    try: #validate query
        datetime.strptime(query, '%Y-%m-%d')
    except ValueError:
        print("WARNING: Invaild input.")
    output = []
    docs_list = list(MongoClient().fit5148_db.climate.find())
    docs = rr_partition(docs_list, n_processor)
    pool = mp.Pool(processes=n_processor)
    for doc in docs:
        each = pool.apply_async(check_climate_date, args=(doc, query)).get()
        if each:
            for doc in each:
                output.append(doc)
    return output

# %%
parallel_date('2017-12-15', 5)
# Out:
# [{'AirTemperature': 18,
#   'Date': '2017-12-15',
#   'Fires': [24, 25, 26, 23],
#   'MAX': '74.5*',
#   'MIN': '53.1',
#   'MaxWindSpeed': 14.0,
#   'Precipitation': ' 0.00I',
#   'RelativeHumidity': 52.0,
#   'Station': '948702',
#   'WindSpeed': 7.1,
#   '_id': 349}]
