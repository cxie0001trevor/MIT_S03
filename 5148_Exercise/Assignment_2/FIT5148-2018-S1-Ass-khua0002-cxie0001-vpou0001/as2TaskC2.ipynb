# %% [markdown]
# # Task C. Processing Data Stream
#
# ## Task C.2 Stream Client

# %%
# Import the libraries
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

import sys
import json
from pyspark import SparkContext
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils


# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

if __name__ == "__main__": 
    
    climatesDataset = []
    firesDataset = []

    # If there is an existing spark context, we will reuse it instead of creating a new context.
    sc = SparkContext.getOrCreate()

    # If there is no existing spark context, we now create a new context
    if (sc is None):
        sc = SparkContext(master="local[2]", appName = "StreamClientApp")
        
        
    batch_interval = 5
    ssc = StreamingContext(sc, batch_interval)

    host = "localhost"
    port = 50008
    
    # a. Receive streaming data from the streams generated by the stream server.
    data = ssc.socketTextStream(host, int(port))
    
    data.pprint()
    
    
    # b. Process the streams to ensure the data can be uploaded into the MongoDB 
    # according to the data model you have designed in Task B1.
    
#     data = data.pprint()
#     if data:
#         print("if data")
#         for item in data:
#             print(item)
#             if item[0].strip() == 'cdata':
#                 climatesDataset.append(item)
#                 print("climatesDataset.append")
#             elif item[0].strip() == 'fdata':
#                 firesDataset.append(item)
#                 print("firesDataset.append")
    
#     print("climatesDataset: ", climatesDataset)
    
    
    # c. Upload the result of processing in Task C2b to MongoDB.
    

    ssc.start()
    try: 
        ssc.awaitTermination()
    except KeyboardInterrupt:
        ssc.stop()
        sc.stop()

    ssc.stop()
    sc.stop()
